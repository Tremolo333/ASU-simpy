# %% [markdown]
# # Imports
#
# Please use the provided `hds_stoch` environment for this work.

# %%
import simpy
simpy.__version__
# Out:
# '4.0.1'

# %%
import numpy as np
import pandas as pd
import itertools
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Distribution classes
#
# To help you build your model, the notebook includes some pre-written distribution classes that you may wish to use to setup sampling.  You are free to use these, but you can choose not too if you have an approach you prefer.

# %%
class Exponential:
    '''
    Convenience class for the exponential distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, mean, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        mean: float
            The mean of the exponential distribution
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.mean = mean
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.exponential(self.mean, size=size)

class Lognormal:
    """
    Encapsulates a lognormal distirbution
    """
    def __init__(self, mean, stdev, random_seed=None):
        """
        Params:
        -------
        mean = mean of the lognormal distribution
        stdev = standard dev of the lognormal distribution
        """
        self.rand = np.random.default_rng(seed=random_seed)
        mu, sigma = self.normal_moments_from_lognormal(mean, stdev**2)
        self.mu = mu
        self.sigma = sigma
        
    def normal_moments_from_lognormal(self, m, v):
        '''
        Returns mu and sigma of normal distribution
        underlying a lognormal with mean m and variance v
        source: https://blogs.sas.com/content/iml/2014/06/04/simulate-lognormal
        -data-with-specified-mean-and-variance.html

        Params:
        -------
        m = mean of lognormal distribution
        v = variance of lognormal distribution
                
        Returns:
        -------
        (float, float)
        '''
        phi = math.sqrt(v + m**2)
        mu = math.log(m**2/phi)
        sigma = math.sqrt(math.log(phi**2/m**2))
        return mu, sigma
        
    def sample(self):
        """
        Sample from the normal distribution
        """
        return self.rand.lognormal(self.mu, self.sigma)

# %% [markdown]
# # Utility functions

# %%
def trace(msg):
    '''
    Utility function for printing simulation
    set the TRACE constant to FALSE to 
    turn tracing off.
    
    Params:
    -------
    msg: str
        string to print to screen.
    '''
    if TRACE:
        print(msg)

# %%
def performance(ASU_model):
    '''
    Utility function for final metrics calculation.
    
    Returns numpy.float64 variable containining
    mean waiting time of the bottom 90% of the pts
    formatted to hours.
    
    Params:
    -------
    ASU_model: Class
        refer to the list of Patient objects appended 
        throughout a simulation run to the patients list
        inside of the ASU Class
    '''
    # np array of all queue times to treatment
    patients_queue_times = np.array([patient.queue_time 
                               for patient in model.patients])

    # transform values from days into hours
    patients_queue_times *= 24
    
    # calculate total number of patients
    arr_length = np.size(patients_queue_times)

    # determine the number of values to be dropped
    num_to_drop = int(arr_length * 0.1)

    # sort the array in descending order
    sorted_queue_times = np.sort(patients_queue_times)[::-1]

    # drop top 10%, estimate the mean
    queue_bottom90 = sorted_queue_times[num_to_drop:].mean()
    
    
    #bed utilisation = sum(call durations) / (run length X no. BEDS)
    util = np.array([patient.treat_time 
                 for patient in model.patients]).sum() / (RUN_LENGTH * N_BEDS)
    
    return queue_bottom90, util

# %% [markdown]
# # Model parameters
#
# The constants below provides hard coded data representing the base case or 'as-is' state of the minor injury unit.

# %%
# These are the parameters for a base case model run.
# Note if you change these parameters then your model will run a new 'scenario' 

# resource counts
N_BEDS = 9

# time between arrivals in minutes (exponential)
# for acute stroke, TIA and neuro respectively
MEAN_IATs = [1.2, 9.5, 3.5]

# treatment (lognormal)
# for acute stroke, TIA and neuro respectively
TREAT_MEANs = [7.4, 1.8, 2.0]
TREAT_STDs = [8.5, 2.3, 2.5]

# SEEDS to reproduce results of a single run
REPRODUCIBLE_RUN = False
    
if REPRODUCIBLE_RUN:
    SEEDS = [42, 101, 1066, 1966, 2013, 999, 1444, 2016]
else:
    SEEDS = [None, None, None, None, None, None, None, None]

# %% [markdown]
# # Scenario class
# In the cell below the parameters you will find a `Scenario` class.  This makes use of the default parameters to set up the base case scenario.  Remember that its good practice to pass all of your parameters to your simulation model in a **container**.  A class is a flexible way to achieve this aim.

# %%
class Scenario:
    '''
    Parameter container class for minor injury unit model.
    '''
    def __init__(self, name=None):
        '''
        The init method sets up our defaults. 
        
        Params:
        -------
        
        name - str or None
            optional name for scenario
        '''
        # optional name
        self.name = name
        
        # number of beds
        self.beds = N_BEDS
        
        # inter-arrival distributions
        self.arrival_dist_type1 = Exponential(MEAN_IATs[0], random_seed=SEEDS[0]) 
        self.arrival_dist_type2 = Exponential(MEAN_IATs[1], random_seed=SEEDS[1])
        self.arrival_dist_type3 = Exponential(MEAN_IATs[2], random_seed=SEEDS[2])
        
        
        # treatment distributions
        self.treatment_dist_type1 = Lognormal(TREAT_MEANs[0], TREAT_STDs[0], random_seed=SEEDS[3])
        self.treatment_dist_type2 = Lognormal(TREAT_MEANs[1], TREAT_STDs[1], random_seed=SEEDS[4])
        self.treatment_dist_type3 = Lognormal(TREAT_MEANs[2], TREAT_STDs[2], random_seed=SEEDS[5])

# %% [markdown]
# # Model building

# %%
class Patient:
    '''
    Patient in the minor ED process
    '''
    def __init__(self, identifier, env, args):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env

        # treatment parameters
        self.beds = args.beds
        self.treatment_dist_type1 = args.treatment_dist_type1
        self.treatment_dist_type2 = args.treatment_dist_type2
        self.treatment_dist_type3 = args.treatment_dist_type3
                
        # individual patient metrics
        self.queue_time = 0.0
        self.treat_time = 0.0
        
    
    def treatment_type1(self):

        # record the time that patient entered the system
        arrival_time = self.env.now
     
        # get a bed
        with self.beds.request() as req:
            yield req
            
            # record time to first being seen by a doctor
            self.queue_time = self.env.now - arrival_time

            trace(f'Patient № {self.identifier} started treatment at {self.env.now:.3f};'
                      + f' queue time was {self.queue_time:.3f}')            

            # sample for patient pathway
            self.treat_time = self.treatment_dist_type1.sample()
            
            activity_duration = self.treat_time
          
            # treatment delay
            yield self.env.timeout(activity_duration)
            
            
            
    def treatment_type2(self):

        # record the time that patient entered the system
        arrival_time = self.env.now
     
        # get a bed
        with self.beds.request() as req:
            yield req
            
            # record time to first being seen by a doctor
            self.queue_time = self.env.now - arrival_time
            
            trace(f'Patient № {self.identifier} started treatment at {self.env.now:.3f};'
                      + f' queue time was {self.queue_time:.3f}')            

            # sample for patient pathway
            self.treat_time = self.treatment_dist_type2.sample()
            
            activity_duration = self.treat_time
          
            # treatment delay
            yield self.env.timeout(activity_duration)
                                        
            
    def treatment_type3(self):

        # record the time that patient entered the system
        arrival_time = self.env.now
     
        # get a bed
        with self.beds.request() as req:
            yield req
            
            # record time to first being seen by a doctor
            self.queue_time = self.env.now - arrival_time
            
            trace(f'Patient № {self.identifier} started treatment at {self.env.now:.3f};'
                      + f' queue time was {self.queue_time:.3f}')             

            # sample for patient pathway
            self.treat_time = self.treatment_dist_type3.sample()
            
            activity_duration = self.treat_time
          
            # treatment delay
            yield self.env.timeout(activity_duration)

# %%
class ASU:  
    '''
    Model of an ASU
    '''
    def __init__(self, env, args):
        '''
        Contructor
        
        Params:
        -------
        env: simpy.Environment
        
        args: Scenario
            container class for simulation model inputs.
        '''
        self.env = env
        self.args = args 
        self.init_model_resources(args)
        self.patients = []
        self.patient_count = 0
        
        
    def init_model_resources(self, args):
        '''
        Setup the simpy resource objects
        
        Params:
        ------
        args - Scenario
            Simulation Parameter Container
        '''

        args.beds = simpy.Resource(self.env, 
                                   capacity=args.beds)
        
            
    def arrivals_generator_type1(self):
            
        while True:
            
            
                # PATIENT WITH ACUTE STROKE ARRIVES (TYPE 1)
                inter_arrival_time = self.args.arrival_dist_type1.sample()               
                
                yield self.env.timeout(inter_arrival_time)
                
                self.patient_count += 1
                
                trace(f'Patient № {self.patient_count} (Stroke) arrives at: {self.env.now:.3f}')
                
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)                

                # init the minor injury process for this patient
                self.env.process(new_patient.treatment_type1())                 
            
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)                
                
                
    def arrivals_generator_type2(self):
            
        while True:
            
                            
                # PATIENT WITH TRANSITORY ISCHEMIC ATTACK ARRIVES (TYPE 2)
                inter_arrival_time = self.args.arrival_dist_type2.sample()
           
                yield self.env.timeout(inter_arrival_time)
            
                self.patient_count += 1            
                                
                trace(f'Patient № {self.patient_count} (TIA) arrives at: {self.env.now:.3f}')   
                
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)
            
                # init the minor injury process for this patient
                self.env.process(new_patient.treatment_type2())                
                
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)                
                
    def arrivals_generator_type3(self):
            
        while True:
            
                
                # PATIENT WITH COMPLEX NEUROLOGICAL DIAGNOSIS ARRIVES (TYPE 3)
                inter_arrival_time = self.args.arrival_dist_type3.sample()
                
                yield self.env.timeout(inter_arrival_time)
                
                self.patient_count += 1
                
                trace(f'Patient № {self.patient_count} (Neuro) arrives at: {self.env.now:.3f}')
                
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)
            
                # init the minor injury process for this patient
                self.env.process(new_patient.treatment_type3())                
                
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)

# %% [markdown]
# # Script to run the model

# %%
# run length in days
RUN_LENGTH = 365

# Turn off tracing
TRACE = True #False 

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()

# create the model
model = ASU(env, default_args)

# setup the processes
env.process(model.arrivals_generator_type1())
env.process(model.arrivals_generator_type2())
env.process(model.arrivals_generator_type3())


env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')


# Calculate and printout Performance metrics
mean_queue, util = performance(model)

print('\nSingle run results\n------------------')
print(f'Mean Queue Time of Bottom 90% of the Patients: {mean_queue:.2f} hours!')
print(f'Bed utilisation: {util*100:.2f} %!')

###################################################################
# Out:
# Patient № 1 (Stroke) arrives at: 0.534
# Patient № 1 started treatment at 0.534; queue time was 0.000
# Patient № 2 (Neuro) arrives at: 0.540
# Patient № 2 started treatment at 0.540; queue time was 0.000
# Patient № 3 (TIA) arrives at: 0.908
# Patient № 3 started treatment at 0.908; queue time was 0.000
# Patient № 4 (Neuro) arrives at: 1.725
# Patient № 4 started treatment at 1.725; queue time was 0.000
# Patient № 5 (Neuro) arrives at: 2.443
# Patient № 5 started treatment at 2.443; queue time was 0.000
# Patient № 6 (Stroke) arrives at: 2.823
# Patient № 6 started treatment at 2.823; queue time was 0.000
# Patient № 7 (Stroke) arrives at: 2.880
# Patient № 7 started treatment at 2.880; queue time was 0.000
# Patient № 8 (Stroke) arrives at: 3.643
# Patient № 8 started treatment at 3.643; queue time was 0.000
# Patient № 9 (Stroke) arrives at: 4.152
# Patient № 9 started treatment at 4.152; queue time was 0.000
# Patient № 10 (Stroke) arrives at: 6.058
# Patient № 10 started treatment at 6.058; queue time was 0.000
# Patient № 11 (Stroke) arrives at: 6.429
# Patient № 11 started treatment at 6.429; queue time was 0.000
# Patient № 12 (Stroke) arrives at: 7.187
# Patient № 12 started treatment at 7.187; queue time was 0.000
# Patient № 13 (Stroke) arrives at: 7.823
# Patient № 13 started treatment at 7.823; queue time was 0.000
# Patient № 14 (Stroke) arrives at: 7.938
# Patient № 14 started treatment at 7.938; queue time was 0.000
# Patient № 15 (Neuro) arrives at: 9.615
# Patient № 15 started treatment at 9.615; queue time was 0.000
# Patient № 16 (Stroke) arrives at: 9.866
# Patient № 16 started treatment at 9.866; queue time was 0.000
# Patient № 17 (Stroke) arrives at: 10.095
# Patient № 17 started treatment at 10.095; queue time was 0.000
# Patient № 18 (TIA) arrives at: 11.499
# Patient № 18 started treatment at 11.499; queue time was 0.000
# Patient № 19 (TIA) arrives at: 11.607
# Patient № 19 started treatment at 11.607; queue time was 0.000
# Patient № 20 (Stroke) arrives at: 11.926
# Patient № 20 started treatment at 11.964; queue time was 0.038
# Patient № 21 (TIA) arrives at: 12.605
# Patient № 21 started treatment at 12.605; queue time was 0.000
# Patient № 22 (Stroke) arrives at: 12.820
# Patient № 23 (Neuro) arrives at: 13.111
# Patient № 24 (Stroke) arrives at: 13.222
# Patient № 22 started treatment at 13.618; queue time was 0.798
# Patient № 23 started treatment at 13.795; queue time was 0.684
# Patient № 25 (Neuro) arrives at: 13.864
# Patient № 24 started treatment at 14.078; queue time was 0.856
# Patient № 25 started treatment at 14.134; queue time was 0.270
# Patient № 26 (Neuro) arrives at: 15.820
# Patient № 26 started treatment at 15.820; queue time was 0.000
# Patient № 27 (Stroke) arrives at: 15.899
# Patient № 27 started treatment at 15.899; queue time was 0.000
# Patient № 28 (Stroke) arrives at: 16.061
# Patient № 29 (Stroke) arrives at: 16.448
# Patient № 28 started treatment at 16.908; queue time was 0.847
# Patient № 29 started treatment at 16.916; queue time was 0.468
# Patient № 30 (TIA) arrives at: 17.012
# Patient № 31 (Neuro) arrives at: 17.330
# Patient № 32 (Stroke) arrives at: 17.540
# Patient № 30 started treatment at 17.577; queue time was 0.565
# Patient № 31 started treatment at 18.113; queue time was 0.783
# Patient № 32 started treatment at 18.256; queue time was 0.716
# Patient № 33 (Stroke) arrives at: 19.967
# Patient № 33 started treatment at 19.967; queue time was 0.000
# Patient № 34 (TIA) arrives at: 21.001
# Patient № 34 started treatment at 21.001; queue time was 0.000
# Patient № 35 (Stroke) arrives at: 21.405
# Patient № 35 started treatment at 21.405; queue time was 0.000
# Patient № 36 (Stroke) arrives at: 21.578
# Patient № 36 started treatment at 21.578; queue time was 0.000
# Patient № 37 (Stroke) arrives at: 21.959
# Patient № 37 started treatment at 22.087; queue time was 0.128
# Patient № 38 (Stroke) arrives at: 22.419
# Patient № 38 started treatment at 22.494; queue time was 0.076
# Patient № 39 (Neuro) arrives at: 23.483
# Patient № 39 started treatment at 23.483; queue time was 0.000
# Patient № 40 (Neuro) arrives at: 23.590
# Patient № 40 started treatment at 23.590; queue time was 0.000
# Patient № 41 (Neuro) arrives at: 24.972
# Patient № 41 started treatment at 24.972; queue time was 0.000
# Patient № 42 (Stroke) arrives at: 25.816
# Patient № 42 started treatment at 25.816; queue time was 0.000
# Patient № 43 (Neuro) arrives at: 25.817
# Patient № 43 started treatment at 25.817; queue time was 0.000
# Patient № 44 (Stroke) arrives at: 26.076
# Patient № 44 started treatment at 26.076; queue time was 0.000
# Patient № 45 (Stroke) arrives at: 26.239
# Patient № 45 started treatment at 26.239; queue time was 0.000
# Patient № 46 (Neuro) arrives at: 26.810
# Patient № 46 started treatment at 26.810; queue time was 0.000
# Patient № 47 (Stroke) arrives at: 28.072
# Patient № 47 started treatment at 28.072; queue time was 0.000
# Patient № 48 (Stroke) arrives at: 28.203
# Patient № 48 started treatment at 28.203; queue time was 0.000
# Patient № 49 (Stroke) arrives at: 29.069
# Patient № 49 started treatment at 29.069; queue time was 0.000
# Patient № 50 (TIA) arrives at: 29.071
# Patient № 50 started treatment at 29.071; queue time was 0.000
# Patient № 51 (Neuro) arrives at: 29.243
# Patient № 51 started treatment at 29.243; queue time was 0.000
# Patient № 52 (Stroke) arrives at: 29.693
# Patient № 52 started treatment at 29.889; queue time was 0.197
# Patient № 53 (TIA) arrives at: 30.375
# Patient № 54 (Stroke) arrives at: 30.722
# Patient № 55 (Stroke) arrives at: 30.975
# Patient № 53 started treatment at 31.276; queue time was 0.902
# Patient № 54 started treatment at 31.834; queue time was 1.112
# Patient № 55 started treatment at 31.957; queue time was 0.983
# Patient № 56 (Stroke) arrives at: 32.136
# Patient № 57 (Neuro) arrives at: 32.206
# Patient № 56 started treatment at 32.774; queue time was 0.637
# Patient № 57 started treatment at 32.989; queue time was 0.782
# Patient № 58 (Stroke) arrives at: 34.697
# Patient № 58 started treatment at 34.697; queue time was 0.000
# Patient № 59 (Stroke) arrives at: 38.110
# Patient № 59 started treatment at 38.110; queue time was 0.000
# Patient № 60 (Neuro) arrives at: 38.275
# Patient № 60 started treatment at 38.275; queue time was 0.000
# Patient № 61 (Stroke) arrives at: 38.373
# Patient № 61 started treatment at 38.373; queue time was 0.000
# Patient № 62 (Neuro) arrives at: 39.038
# Patient № 62 started treatment at 39.038; queue time was 0.000
# Patient № 63 (TIA) arrives at: 40.073
# Patient № 63 started treatment at 40.073; queue time was 0.000
# Patient № 64 (Stroke) arrives at: 40.178
# Patient № 64 started treatment at 40.178; queue time was 0.000
# Patient № 65 (Neuro) arrives at: 41.865
# Patient № 65 started treatment at 41.865; queue time was 0.000
# Patient № 66 (Stroke) arrives at: 42.334
# Patient № 66 started treatment at 42.334; queue time was 0.000
# Patient № 67 (Stroke) arrives at: 42.765
# Patient № 67 started treatment at 42.765; queue time was 0.000
# Patient № 68 (Stroke) arrives at: 43.893
# Patient № 68 started treatment at 44.194; queue time was 0.300
# Patient № 69 (Neuro) arrives at: 44.314
# Patient № 69 started treatment at 44.977; queue time was 0.663
# Patient № 70 (Stroke) arrives at: 45.807
# Patient № 70 started treatment at 45.807; queue time was 0.000
# Patient № 71 (Neuro) arrives at: 47.310
# Patient № 71 started treatment at 47.310; queue time was 0.000
# Patient № 72 (Stroke) arrives at: 47.435
# Patient № 72 started treatment at 47.435; queue time was 0.000
# Patient № 73 (Neuro) arrives at: 47.559
# Patient № 73 started treatment at 47.559; queue time was 0.000
# Patient № 74 (Stroke) arrives at: 48.788
# Patient № 74 started treatment at 48.788; queue time was 0.000
# Patient № 75 (Stroke) arrives at: 49.067
# Patient № 75 started treatment at 49.067; queue time was 0.000
# Patient № 76 (Neuro) arrives at: 49.664
# Patient № 76 started treatment at 49.664; queue time was 0.000
# Patient № 77 (Stroke) arrives at: 51.496
# Patient № 77 started treatment at 51.496; queue time was 0.000
# Patient № 78 (Stroke) arrives at: 52.102
# Patient № 78 started treatment at 52.102; queue time was 0.000
# Patient № 79 (Stroke) arrives at: 52.128
# Patient № 79 started treatment at 52.128; queue time was 0.000
# Patient № 80 (TIA) arrives at: 52.204
# Patient № 80 started treatment at 52.204; queue time was 0.000
# Patient № 81 (Stroke) arrives at: 53.897
# Patient № 81 started treatment at 53.897; queue time was 0.000
# Patient № 82 (Neuro) arrives at: 54.381
# Patient № 82 started treatment at 54.381; queue time was 0.000
# Patient № 83 (Neuro) arrives at: 56.544
# Patient № 83 started treatment at 56.544; queue time was 0.000
# Patient № 84 (TIA) arrives at: 56.998
# Patient № 84 started treatment at 56.998; queue time was 0.000
# Patient № 85 (Stroke) arrives at: 57.065
# Patient № 85 started treatment at 57.065; queue time was 0.000
# Patient № 86 (Stroke) arrives at: 57.689
# Patient № 86 started treatment at 57.689; queue time was 0.000
# Patient № 87 (Neuro) arrives at: 60.823
# Patient № 87 started treatment at 60.823; queue time was 0.000
# Patient № 88 (Neuro) arrives at: 61.198
# Patient № 88 started treatment at 61.198; queue time was 0.000
# Patient № 89 (Stroke) arrives at: 61.478
# Patient № 89 started treatment at 61.478; queue time was 0.000
# Patient № 90 (Stroke) arrives at: 61.779
# Patient № 90 started treatment at 61.779; queue time was 0.000
# Patient № 91 (TIA) arrives at: 62.953
# Patient № 91 started treatment at 62.953; queue time was 0.000
# Patient № 92 (Neuro) arrives at: 63.132
# Patient № 92 started treatment at 63.132; queue time was 0.000
# Patient № 93 (Stroke) arrives at: 65.091
# Patient № 93 started treatment at 65.091; queue time was 0.000
# Patient № 94 (Stroke) arrives at: 65.625
# Patient № 94 started treatment at 65.625; queue time was 0.000
# Patient № 95 (Neuro) arrives at: 66.267
# Patient № 95 started treatment at 66.267; queue time was 0.000
# Patient № 96 (Neuro) arrives at: 66.736
# Patient № 96 started treatment at 66.736; queue time was 0.000
# Patient № 97 (Stroke) arrives at: 66.956
# Patient № 97 started treatment at 67.397; queue time was 0.441
# Patient № 98 (Neuro) arrives at: 68.997
# Patient № 98 started treatment at 68.997; queue time was 0.000
# Patient № 99 (Stroke) arrives at: 69.872
# Patient № 99 started treatment at 69.872; queue time was 0.000
# Patient № 100 (Stroke) arrives at: 72.370
# Patient № 100 started treatment at 72.370; queue time was 0.000
# Patient № 101 (Stroke) arrives at: 73.685
# Patient № 101 started treatment at 73.685; queue time was 0.000
# Patient № 102 (Stroke) arrives at: 74.412
# Patient № 102 started treatment at 74.412; queue time was 0.000
# Patient № 103 (Stroke) arrives at: 76.330
# Patient № 103 started treatment at 76.330; queue time was 0.000
# Patient № 104 (Stroke) arrives at: 77.570
# Patient № 104 started treatment at 77.570; queue time was 0.000
# Patient № 105 (Neuro) arrives at: 77.624
# Patient № 105 started treatment at 77.624; queue time was 0.000
# Patient № 106 (Stroke) arrives at: 77.995
# Patient № 106 started treatment at 77.995; queue time was 0.000
# Patient № 107 (Stroke) arrives at: 78.236
# Patient № 107 started treatment at 78.236; queue time was 0.000
# Patient № 108 (Stroke) arrives at: 79.511
# Patient № 108 started treatment at 79.511; queue time was 0.000
# Patient № 109 (Stroke) arrives at: 80.021
# Patient № 109 started treatment at 80.021; queue time was 0.000
# Patient № 110 (TIA) arrives at: 80.633
# Patient № 110 started treatment at 80.633; queue time was 0.000
# Patient № 111 (Stroke) arrives at: 81.902
# Patient № 111 started treatment at 81.902; queue time was 0.000
# Patient № 112 (Stroke) arrives at: 82.304
# Patient № 112 started treatment at 82.304; queue time was 0.000
# Patient № 113 (Stroke) arrives at: 83.700
# Patient № 113 started treatment at 83.700; queue time was 0.000
# Patient № 114 (Stroke) arrives at: 84.174
# Patient № 114 started treatment at 84.174; queue time was 0.000
# Patient № 115 (Neuro) arrives at: 85.023
# Patient № 115 started treatment at 85.023; queue time was 0.000
# Patient № 116 (Stroke) arrives at: 85.130
# Patient № 116 started treatment at 85.130; queue time was 0.000
# Patient № 117 (Stroke) arrives at: 86.538
# Patient № 117 started treatment at 86.538; queue time was 0.000
# Patient № 118 (Stroke) arrives at: 86.831
# Patient № 118 started treatment at 86.831; queue time was 0.000
# Patient № 119 (Stroke) arrives at: 89.143
# Patient № 119 started treatment at 89.143; queue time was 0.000
# Patient № 120 (Stroke) arrives at: 90.138
# Patient № 120 started treatment at 90.138; queue time was 0.000
# Patient № 121 (Stroke) arrives at: 90.700
# Patient № 121 started treatment at 90.700; queue time was 0.000
# Patient № 122 (Neuro) arrives at: 91.324
# Patient № 122 started treatment at 91.324; queue time was 0.000
# Patient № 123 (Neuro) arrives at: 91.370
# Patient № 123 started treatment at 91.778; queue time was 0.408
# Patient № 124 (Stroke) arrives at: 93.346
# Patient № 124 started treatment at 93.346; queue time was 0.000
# Patient № 125 (Stroke) arrives at: 93.963
# Patient № 125 started treatment at 93.963; queue time was 0.000
# Patient № 126 (Stroke) arrives at: 95.403
# Patient № 126 started treatment at 95.403; queue time was 0.000
# Patient № 127 (Stroke) arrives at: 96.847
# Patient № 127 started treatment at 96.847; queue time was 0.000
# Patient № 128 (Stroke) arrives at: 99.630
# Patient № 128 started treatment at 99.630; queue time was 0.000
# Patient № 129 (Stroke) arrives at: 99.781
# Patient № 129 started treatment at 99.781; queue time was 0.000
# Patient № 130 (TIA) arrives at: 100.752
# Patient № 130 started treatment at 100.752; queue time was 0.000
# Patient № 131 (TIA) arrives at: 103.969
# Patient № 131 started treatment at 103.969; queue time was 0.000
# Patient № 132 (Stroke) arrives at: 104.235
# Patient № 132 started treatment at 104.235; queue time was 0.000
# Patient № 133 (Neuro) arrives at: 107.174
# Patient № 133 started treatment at 107.174; queue time was 0.000
# Patient № 134 (Stroke) arrives at: 107.619
# Patient № 134 started treatment at 107.619; queue time was 0.000
# Patient № 135 (Stroke) arrives at: 107.999
# Patient № 135 started treatment at 107.999; queue time was 0.000
# Patient № 136 (Stroke) arrives at: 110.000
# Patient № 136 started treatment at 110.000; queue time was 0.000
# Patient № 137 (Stroke) arrives at: 110.008
# Patient № 137 started treatment at 110.008; queue time was 0.000
# Patient № 138 (Stroke) arrives at: 110.576
# Patient № 138 started treatment at 110.576; queue time was 0.000
# Patient № 139 (Neuro) arrives at: 110.642
# Patient № 139 started treatment at 110.642; queue time was 0.000
# Patient № 140 (Stroke) arrives at: 111.017
# Patient № 140 started treatment at 111.017; queue time was 0.000
# Patient № 141 (Stroke) arrives at: 111.515
# Patient № 141 started treatment at 111.594; queue time was 0.078
# Patient № 142 (Stroke) arrives at: 111.647
# Patient № 143 (Neuro) arrives at: 111.839
# Patient № 142 started treatment at 112.343; queue time was 0.697
# Patient № 143 started treatment at 113.279; queue time was 1.441
# Patient № 144 (Neuro) arrives at: 113.403
# Patient № 144 started treatment at 113.471; queue time was 0.068
# Patient № 145 (Stroke) arrives at: 116.371
# Patient № 145 started treatment at 116.371; queue time was 0.000
# Patient № 146 (Stroke) arrives at: 116.912
# Patient № 146 started treatment at 116.912; queue time was 0.000
# Patient № 147 (TIA) arrives at: 117.257
# Patient № 147 started treatment at 117.257; queue time was 0.000
# Patient № 148 (Stroke) arrives at: 118.554
# Patient № 148 started treatment at 118.554; queue time was 0.000
# Patient № 149 (Stroke) arrives at: 119.824
# Patient № 149 started treatment at 119.824; queue time was 0.000
# Patient № 150 (Neuro) arrives at: 120.284
# Patient № 150 started treatment at 120.284; queue time was 0.000
# Patient № 151 (Neuro) arrives at: 120.786
# Patient № 151 started treatment at 120.786; queue time was 0.000
# Patient № 152 (Neuro) arrives at: 121.596
# Patient № 152 started treatment at 121.596; queue time was 0.000
# Patient № 153 (Stroke) arrives at: 123.261
# Patient № 153 started treatment at 123.261; queue time was 0.000
# Patient № 154 (Stroke) arrives at: 123.557
# Patient № 154 started treatment at 123.557; queue time was 0.000
# Patient № 155 (Stroke) arrives at: 123.675
# Patient № 155 started treatment at 123.675; queue time was 0.000
# Patient № 156 (Stroke) arrives at: 125.237
# Patient № 156 started treatment at 125.237; queue time was 0.000
# Patient № 157 (TIA) arrives at: 125.527
# Patient № 158 (Neuro) arrives at: 125.612
# Patient № 157 started treatment at 125.719; queue time was 0.192
# Patient № 158 started treatment at 125.795; queue time was 0.183
# Patient № 159 (Neuro) arrives at: 125.982
# Patient № 159 started treatment at 126.325; queue time was 0.343
# Patient № 160 (Neuro) arrives at: 127.944
# Patient № 160 started treatment at 127.944; queue time was 0.000
# Patient № 161 (Stroke) arrives at: 129.151
# Patient № 161 started treatment at 129.151; queue time was 0.000
# Patient № 162 (Stroke) arrives at: 129.154
# Patient № 162 started treatment at 129.154; queue time was 0.000
# Patient № 163 (Stroke) arrives at: 129.364
# Patient № 163 started treatment at 129.364; queue time was 0.000
# Patient № 164 (Neuro) arrives at: 131.234
# Patient № 164 started treatment at 131.234; queue time was 0.000
# Patient № 165 (Stroke) arrives at: 131.775
# Patient № 165 started treatment at 131.775; queue time was 0.000
# Patient № 166 (Stroke) arrives at: 132.195
# Patient № 166 started treatment at 132.195; queue time was 0.000
# Patient № 167 (Stroke) arrives at: 133.577
# Patient № 167 started treatment at 133.577; queue time was 0.000
# Patient № 168 (Stroke) arrives at: 133.745
# Patient № 168 started treatment at 133.745; queue time was 0.000
# Patient № 169 (Stroke) arrives at: 133.835
# Patient № 169 started treatment at 133.835; queue time was 0.000
# Patient № 170 (Stroke) arrives at: 134.666
# Patient № 170 started treatment at 134.666; queue time was 0.000
# Patient № 171 (Stroke) arrives at: 135.302
# Patient № 171 started treatment at 135.302; queue time was 0.000
# Patient № 172 (TIA) arrives at: 135.325
# Patient № 173 (Stroke) arrives at: 135.461
# Patient № 172 started treatment at 135.928; queue time was 0.603
# Patient № 173 started treatment at 136.340; queue time was 0.878
# Patient № 174 (Neuro) arrives at: 137.159
# Patient № 174 started treatment at 137.159; queue time was 0.000
# Patient № 175 (Stroke) arrives at: 140.273
# Patient № 175 started treatment at 140.273; queue time was 0.000
# Patient № 176 (Neuro) arrives at: 140.646
# Patient № 176 started treatment at 140.646; queue time was 0.000
# Patient № 177 (Neuro) arrives at: 142.140
# Patient № 177 started treatment at 142.140; queue time was 0.000
# Patient № 178 (Neuro) arrives at: 143.591
# Patient № 178 started treatment at 143.591; queue time was 0.000
# Patient № 179 (Neuro) arrives at: 145.391
# Patient № 179 started treatment at 145.391; queue time was 0.000
# Patient № 180 (Stroke) arrives at: 145.793
# Patient № 180 started treatment at 145.793; queue time was 0.000
# Patient № 181 (TIA) arrives at: 148.307
# Patient № 181 started treatment at 148.307; queue time was 0.000
# Patient № 182 (Neuro) arrives at: 149.031
# Patient № 182 started treatment at 149.031; queue time was 0.000
# Patient № 183 (Neuro) arrives at: 150.962
# Patient № 183 started treatment at 150.962; queue time was 0.000
# Patient № 184 (Stroke) arrives at: 151.903
# Patient № 184 started treatment at 151.903; queue time was 0.000
# Patient № 185 (Stroke) arrives at: 153.111
# Patient № 185 started treatment at 153.111; queue time was 0.000
# Patient № 186 (Stroke) arrives at: 153.529
# Patient № 186 started treatment at 153.529; queue time was 0.000
# Patient № 187 (Stroke) arrives at: 153.897
# Patient № 187 started treatment at 153.897; queue time was 0.000
# Patient № 188 (TIA) arrives at: 153.956
# Patient № 188 started treatment at 153.956; queue time was 0.000
# Patient № 189 (Neuro) arrives at: 154.421
# Patient № 189 started treatment at 154.421; queue time was 0.000
# Patient № 190 (Stroke) arrives at: 156.296
# Patient № 190 started treatment at 156.296; queue time was 0.000
# Patient № 191 (Stroke) arrives at: 156.620
# Patient № 191 started treatment at 156.620; queue time was 0.000
# Patient № 192 (Stroke) arrives at: 156.826
# Patient № 192 started treatment at 156.826; queue time was 0.000
# Patient № 193 (Neuro) arrives at: 158.093
# Patient № 193 started treatment at 158.093; queue time was 0.000
# Patient № 194 (TIA) arrives at: 161.377
# Patient № 194 started treatment at 161.377; queue time was 0.000
# Patient № 195 (Stroke) arrives at: 161.639
# Patient № 195 started treatment at 161.639; queue time was 0.000
# Patient № 196 (Neuro) arrives at: 161.714
# Patient № 196 started treatment at 161.714; queue time was 0.000
# Patient № 197 (Neuro) arrives at: 163.130
# Patient № 197 started treatment at 163.130; queue time was 0.000
# Patient № 198 (Stroke) arrives at: 164.431
# Patient № 198 started treatment at 164.431; queue time was 0.000
# Patient № 199 (Stroke) arrives at: 164.550
# Patient № 199 started treatment at 164.550; queue time was 0.000
# Patient № 200 (Stroke) arrives at: 164.565
# Patient № 200 started treatment at 164.565; queue time was 0.000
# Patient № 201 (Stroke) arrives at: 165.835
# Patient № 201 started treatment at 165.835; queue time was 0.000
# Patient № 202 (Stroke) arrives at: 166.720
# Patient № 202 started treatment at 166.720; queue time was 0.000
# Patient № 203 (Stroke) arrives at: 167.711
# Patient № 203 started treatment at 167.711; queue time was 0.000
# Patient № 204 (Stroke) arrives at: 169.997
# Patient № 204 started treatment at 169.997; queue time was 0.000
# Patient № 205 (Stroke) arrives at: 170.498
# Patient № 205 started treatment at 170.498; queue time was 0.000
# Patient № 206 (TIA) arrives at: 171.234
# Patient № 206 started treatment at 171.234; queue time was 0.000
# Patient № 207 (Stroke) arrives at: 172.270
# Patient № 207 started treatment at 172.270; queue time was 0.000
# Patient № 208 (Stroke) arrives at: 172.273
# Patient № 208 started treatment at 172.273; queue time was 0.000
# Patient № 209 (Neuro) arrives at: 172.484
# Patient № 209 started treatment at 172.484; queue time was 0.000
# Patient № 210 (Stroke) arrives at: 172.597
# Patient № 210 started treatment at 172.732; queue time was 0.135
# Patient № 211 (Stroke) arrives at: 173.091
# Patient № 211 started treatment at 173.091; queue time was 0.000
# Patient № 212 (Stroke) arrives at: 174.490
# Patient № 212 started treatment at 174.490; queue time was 0.000
# Patient № 213 (Neuro) arrives at: 175.014
# Patient № 213 started treatment at 175.014; queue time was 0.000
# Patient № 214 (Stroke) arrives at: 175.236
# Patient № 214 started treatment at 175.236; queue time was 0.000
# Patient № 215 (Stroke) arrives at: 175.474
# Patient № 215 started treatment at 175.474; queue time was 0.000
# Patient № 216 (Stroke) arrives at: 175.618
# Patient № 216 started treatment at 175.687; queue time was 0.069
# Patient № 217 (Stroke) arrives at: 175.690
# Patient № 217 started treatment at 175.989; queue time was 0.300
# Patient № 218 (Neuro) arrives at: 177.760
# Patient № 218 started treatment at 177.760; queue time was 0.000
# Patient № 219 (Neuro) arrives at: 178.836
# Patient № 219 started treatment at 178.898; queue time was 0.062
# Patient № 220 (Neuro) arrives at: 179.795
# Patient № 220 started treatment at 179.795; queue time was 0.000
# Patient № 221 (Stroke) arrives at: 179.999
# Patient № 221 started treatment at 179.999; queue time was 0.000
# Patient № 222 (Stroke) arrives at: 180.048
# Patient № 222 started treatment at 180.455; queue time was 0.407
# Patient № 223 (Stroke) arrives at: 182.011
# Patient № 223 started treatment at 182.011; queue time was 0.000
# Patient № 224 (Neuro) arrives at: 182.172
# Patient № 224 started treatment at 182.172; queue time was 0.000
# Patient № 225 (Stroke) arrives at: 183.530
# Patient № 225 started treatment at 183.530; queue time was 0.000
# Patient № 226 (Neuro) arrives at: 183.733
# Patient № 227 (Neuro) arrives at: 184.160
# Patient № 228 (Neuro) arrives at: 184.638
# Patient № 226 started treatment at 184.860; queue time was 1.128
# Patient № 227 started treatment at 185.177; queue time was 1.017
# Patient № 229 (TIA) arrives at: 185.289
# Patient № 228 started treatment at 185.521; queue time was 0.883
# Patient № 229 started treatment at 185.687; queue time was 0.399
# Patient № 230 (TIA) arrives at: 187.504
# Patient № 230 started treatment at 187.504; queue time was 0.000
# Patient № 231 (TIA) arrives at: 188.039
# Patient № 231 started treatment at 188.039; queue time was 0.000
# Patient № 232 (Stroke) arrives at: 188.236
# Patient № 232 started treatment at 188.236; queue time was 0.000
# Patient № 233 (Neuro) arrives at: 188.675
# Patient № 233 started treatment at 188.675; queue time was 0.000
# Patient № 234 (Stroke) arrives at: 188.853
# Patient № 235 (Stroke) arrives at: 189.024
# Patient № 236 (Stroke) arrives at: 189.442
# Patient № 234 started treatment at 189.669; queue time was 0.815
# Patient № 237 (Stroke) arrives at: 190.164
# Patient № 235 started treatment at 190.178; queue time was 1.154
# Patient № 238 (Stroke) arrives at: 191.629
# Patient № 239 (Neuro) arrives at: 191.771
# Patient № 236 started treatment at 191.786; queue time was 2.344
# Patient № 240 (TIA) arrives at: 191.845
# Patient № 241 (Stroke) arrives at: 191.927
# Patient № 237 started treatment at 192.097; queue time was 1.933
# Patient № 238 started treatment at 192.430; queue time was 0.800
# Patient № 239 started treatment at 193.026; queue time was 1.255
# Patient № 240 started treatment at 193.508; queue time was 1.663
# Patient № 241 started treatment at 193.879; queue time was 1.952
# Patient № 242 (Stroke) arrives at: 193.974
# Patient № 242 started treatment at 193.992; queue time was 0.018
# Patient № 243 (Stroke) arrives at: 194.189
# Patient № 243 started treatment at 194.429; queue time was 0.241
# Patient № 244 (Neuro) arrives at: 195.411
# Patient № 244 started treatment at 195.411; queue time was 0.000
# Patient № 245 (Stroke) arrives at: 195.479
# Patient № 245 started treatment at 196.041; queue time was 0.562
# Patient № 246 (Stroke) arrives at: 196.377
# Patient № 246 started treatment at 196.377; queue time was 0.000
# Patient № 247 (Neuro) arrives at: 197.057
# Patient № 247 started treatment at 197.057; queue time was 0.000
# Patient № 248 (Neuro) arrives at: 198.109
# Patient № 248 started treatment at 198.109; queue time was 0.000
# Patient № 249 (Neuro) arrives at: 199.068
# Patient № 249 started treatment at 199.068; queue time was 0.000
# Patient № 250 (Stroke) arrives at: 199.877
# Patient № 250 started treatment at 199.877; queue time was 0.000
# Patient № 251 (Neuro) arrives at: 201.357
# Patient № 251 started treatment at 201.357; queue time was 0.000
# Patient № 252 (Stroke) arrives at: 201.597
# Patient № 252 started treatment at 201.597; queue time was 0.000
# Patient № 253 (Neuro) arrives at: 201.915
# Patient № 253 started treatment at 201.915; queue time was 0.000
# Patient № 254 (Stroke) arrives at: 202.741
# Patient № 254 started treatment at 202.741; queue time was 0.000
# Patient № 255 (Stroke) arrives at: 202.836
# Patient № 255 started treatment at 202.836; queue time was 0.000
# Patient № 256 (Stroke) arrives at: 203.709
# Patient № 256 started treatment at 203.709; queue time was 0.000
# Patient № 257 (Stroke) arrives at: 204.509
# Patient № 257 started treatment at 204.509; queue time was 0.000
# Patient № 258 (Neuro) arrives at: 204.741
# Patient № 258 started treatment at 204.741; queue time was 0.000
# Patient № 259 (Stroke) arrives at: 205.191
# Patient № 259 started treatment at 205.630; queue time was 0.439
# Patient № 260 (Stroke) arrives at: 207.268
# Patient № 260 started treatment at 207.268; queue time was 0.000
# Patient № 261 (Stroke) arrives at: 208.162
# Patient № 261 started treatment at 208.162; queue time was 0.000
# Patient № 262 (Stroke) arrives at: 209.019
# Patient № 262 started treatment at 209.019; queue time was 0.000
# Patient № 263 (Stroke) arrives at: 209.164
# Patient № 263 started treatment at 209.164; queue time was 0.000
# Patient № 264 (Neuro) arrives at: 210.431
# Patient № 264 started treatment at 210.431; queue time was 0.000
# Patient № 265 (Stroke) arrives at: 210.639
# Patient № 265 started treatment at 210.639; queue time was 0.000
# Patient № 266 (Stroke) arrives at: 210.647
# Patient № 266 started treatment at 210.647; queue time was 0.000
# Patient № 267 (Stroke) arrives at: 210.748
# Patient № 267 started treatment at 210.786; queue time was 0.038
# Patient № 268 (Stroke) arrives at: 210.988
# Patient № 268 started treatment at 211.348; queue time was 0.360
# Patient № 269 (Stroke) arrives at: 211.466
# Patient № 269 started treatment at 211.466; queue time was 0.000
# Patient № 270 (Stroke) arrives at: 211.871
# Patient № 270 started treatment at 211.871; queue time was 0.000
# Patient № 271 (TIA) arrives at: 212.223
# Patient № 271 started treatment at 212.223; queue time was 0.000
# Patient № 272 (Neuro) arrives at: 218.091
# Patient № 272 started treatment at 218.091; queue time was 0.000
# Patient № 273 (Stroke) arrives at: 218.462
# Patient № 273 started treatment at 218.462; queue time was 0.000
# Patient № 274 (Neuro) arrives at: 218.730
# Patient № 274 started treatment at 218.730; queue time was 0.000
# Patient № 275 (Stroke) arrives at: 221.172
# Patient № 275 started treatment at 221.172; queue time was 0.000
# Patient № 276 (Neuro) arrives at: 221.182
# Patient № 276 started treatment at 221.182; queue time was 0.000
# Patient № 277 (Stroke) arrives at: 222.309
# Patient № 277 started treatment at 222.309; queue time was 0.000
# Patient № 278 (Stroke) arrives at: 222.946
# Patient № 278 started treatment at 222.946; queue time was 0.000
# Patient № 279 (Stroke) arrives at: 223.596
# Patient № 279 started treatment at 223.596; queue time was 0.000
# Patient № 280 (Stroke) arrives at: 224.124
# Patient № 280 started treatment at 224.124; queue time was 0.000
# Patient № 281 (Stroke) arrives at: 224.336
# Patient № 281 started treatment at 224.336; queue time was 0.000
# Patient № 282 (Neuro) arrives at: 224.945
# Patient № 282 started treatment at 224.945; queue time was 0.000
# Patient № 283 (Stroke) arrives at: 225.183
# Patient № 283 started treatment at 225.183; queue time was 0.000
# Patient № 284 (Stroke) arrives at: 225.428
# Patient № 284 started treatment at 225.428; queue time was 0.000
# Patient № 285 (Stroke) arrives at: 227.842
# Patient № 285 started treatment at 227.842; queue time was 0.000
# Patient № 286 (Stroke) arrives at: 228.099
# Patient № 286 started treatment at 228.099; queue time was 0.000
# Patient № 287 (Stroke) arrives at: 228.259
# Patient № 287 started treatment at 228.259; queue time was 0.000
# Patient № 288 (TIA) arrives at: 228.391
# Patient № 288 started treatment at 228.391; queue time was 0.000
# Patient № 289 (TIA) arrives at: 228.805
# Patient № 289 started treatment at 228.805; queue time was 0.000
# Patient № 290 (Neuro) arrives at: 229.324
# Patient № 290 started treatment at 229.324; queue time was 0.000
# Patient № 291 (Neuro) arrives at: 229.442
# Patient № 291 started treatment at 229.442; queue time was 0.000
# Patient № 292 (Stroke) arrives at: 229.788
# Patient № 293 (TIA) arrives at: 230.352
# Patient № 292 started treatment at 230.635; queue time was 0.847
# Patient № 293 started treatment at 230.750; queue time was 0.398
# Patient № 294 (Neuro) arrives at: 231.621
# Patient № 294 started treatment at 231.621; queue time was 0.000
# Patient № 295 (Neuro) arrives at: 231.662
# Patient № 295 started treatment at 231.924; queue time was 0.262
# Patient № 296 (Stroke) arrives at: 232.633
# Patient № 296 started treatment at 232.633; queue time was 0.000
# Patient № 297 (Neuro) arrives at: 232.841
# Patient № 297 started treatment at 232.841; queue time was 0.000
# Patient № 298 (Stroke) arrives at: 232.862
# Patient № 298 started treatment at 232.862; queue time was 0.000
# Patient № 299 (TIA) arrives at: 233.302
# Patient № 299 started treatment at 233.302; queue time was 0.000
# Patient № 300 (TIA) arrives at: 233.695
# Patient № 300 started treatment at 234.157; queue time was 0.463
# Patient № 301 (Stroke) arrives at: 234.301
# Patient № 302 (Stroke) arrives at: 234.465
# Patient № 301 started treatment at 234.665; queue time was 0.364
# Patient № 302 started treatment at 234.756; queue time was 0.291
# Patient № 303 (Stroke) arrives at: 235.170
# Patient № 303 started treatment at 235.170; queue time was 0.000
# Patient № 304 (Stroke) arrives at: 236.697
# Patient № 304 started treatment at 236.697; queue time was 0.000
# Patient № 305 (Stroke) arrives at: 236.858
# Patient № 305 started treatment at 236.858; queue time was 0.000
# Patient № 306 (Stroke) arrives at: 238.354
# Patient № 306 started treatment at 238.354; queue time was 0.000
# Patient № 307 (Stroke) arrives at: 239.554
# Patient № 307 started treatment at 239.554; queue time was 0.000
# Patient № 308 (Stroke) arrives at: 239.893
# Patient № 308 started treatment at 239.893; queue time was 0.000
# Patient № 309 (Stroke) arrives at: 242.110
# Patient № 309 started treatment at 242.110; queue time was 0.000
# Patient № 310 (Stroke) arrives at: 242.991
# Patient № 310 started treatment at 242.991; queue time was 0.000
# Patient № 311 (Stroke) arrives at: 243.220
# Patient № 311 started treatment at 243.220; queue time was 0.000
# Patient № 312 (Neuro) arrives at: 243.761
# Patient № 312 started treatment at 243.761; queue time was 0.000
# Patient № 313 (Neuro) arrives at: 245.098
# Patient № 313 started treatment at 245.098; queue time was 0.000
# Patient № 314 (Neuro) arrives at: 246.382
# Patient № 314 started treatment at 246.382; queue time was 0.000
# Patient № 315 (Stroke) arrives at: 246.634
# Patient № 315 started treatment at 246.634; queue time was 0.000
# Patient № 316 (Stroke) arrives at: 246.958
# Patient № 316 started treatment at 246.958; queue time was 0.000
# Patient № 317 (Stroke) arrives at: 248.207
# Patient № 317 started treatment at 248.207; queue time was 0.000
# Patient № 318 (Stroke) arrives at: 249.265
# Patient № 318 started treatment at 249.265; queue time was 0.000
# Patient № 319 (Stroke) arrives at: 250.189
# Patient № 319 started treatment at 250.189; queue time was 0.000
# Patient № 320 (Stroke) arrives at: 250.777
# Patient № 320 started treatment at 250.777; queue time was 0.000
# Patient № 321 (Stroke) arrives at: 250.780
# Patient № 321 started treatment at 250.780; queue time was 0.000
# Patient № 322 (Stroke) arrives at: 251.261
# Patient № 322 started treatment at 251.261; queue time was 0.000
# Patient № 323 (Stroke) arrives at: 251.343
# Patient № 324 (Stroke) arrives at: 251.878
# Patient № 325 (Stroke) arrives at: 252.230
# Patient № 323 started treatment at 252.655; queue time was 1.312
# Patient № 326 (Stroke) arrives at: 252.827
# Patient № 327 (Stroke) arrives at: 254.468
# Patient № 324 started treatment at 254.978; queue time was 3.100
# Patient № 325 started treatment at 256.260; queue time was 4.030
# Patient № 326 started treatment at 256.546; queue time was 3.719
# Patient № 327 started treatment at 257.217; queue time was 2.749
# Patient № 328 (TIA) arrives at: 257.392
# Patient № 328 started treatment at 258.668; queue time was 1.276
# Patient № 329 (Stroke) arrives at: 259.096
# Patient № 329 started treatment at 259.096; queue time was 0.000
# Patient № 330 (TIA) arrives at: 259.119
# Patient № 330 started treatment at 260.158; queue time was 1.039
# Patient № 331 (TIA) arrives at: 260.516
# Patient № 332 (Neuro) arrives at: 260.623
# Patient № 331 started treatment at 260.666; queue time was 0.149
# Patient № 333 (Stroke) arrives at: 260.678
# Patient № 334 (Stroke) arrives at: 260.757
# Patient № 332 started treatment at 261.169; queue time was 0.546
# Patient № 335 (Stroke) arrives at: 261.399
# Patient № 336 (Stroke) arrives at: 261.560
# Patient № 333 started treatment at 261.651; queue time was 0.974
# Patient № 334 started treatment at 262.309; queue time was 1.552
# Patient № 335 started treatment at 262.442; queue time was 1.043
# Patient № 336 started treatment at 262.462; queue time was 0.903
# Patient № 337 (TIA) arrives at: 263.721
# Patient № 337 started treatment at 263.721; queue time was 0.000
# Patient № 338 (Stroke) arrives at: 264.185
# Patient № 338 started treatment at 264.185; queue time was 0.000
# Patient № 339 (Stroke) arrives at: 266.674
# Patient № 339 started treatment at 266.674; queue time was 0.000
# Patient № 340 (Neuro) arrives at: 267.045
# Patient № 340 started treatment at 267.045; queue time was 0.000
# Patient № 341 (Neuro) arrives at: 267.377
# Patient № 341 started treatment at 267.377; queue time was 0.000
# Patient № 342 (Neuro) arrives at: 268.020
# Patient № 342 started treatment at 268.020; queue time was 0.000
# Patient № 343 (Stroke) arrives at: 269.165
# Patient № 343 started treatment at 269.165; queue time was 0.000
# Patient № 344 (Neuro) arrives at: 270.226
# Patient № 344 started treatment at 270.226; queue time was 0.000
# Patient № 345 (Stroke) arrives at: 270.378
# Patient № 345 started treatment at 270.378; queue time was 0.000
# Patient № 346 (Neuro) arrives at: 271.668
# Patient № 346 started treatment at 271.668; queue time was 0.000
# Patient № 347 (Stroke) arrives at: 273.637
# Patient № 347 started treatment at 273.637; queue time was 0.000
# Patient № 348 (Neuro) arrives at: 274.581
# Patient № 348 started treatment at 274.581; queue time was 0.000
# Patient № 349 (Neuro) arrives at: 274.601
# Patient № 349 started treatment at 274.601; queue time was 0.000
# Patient № 350 (Stroke) arrives at: 275.735
# Patient № 350 started treatment at 275.735; queue time was 0.000
# Patient № 351 (Stroke) arrives at: 276.030
# Patient № 351 started treatment at 276.030; queue time was 0.000
# Patient № 352 (TIA) arrives at: 276.184
# Patient № 352 started treatment at 276.184; queue time was 0.000
# Patient № 353 (Stroke) arrives at: 276.623
# Patient № 353 started treatment at 276.623; queue time was 0.000
# Patient № 354 (Stroke) arrives at: 276.905
# Patient № 354 started treatment at 276.905; queue time was 0.000
# Patient № 355 (Stroke) arrives at: 277.519
# Patient № 355 started treatment at 277.519; queue time was 0.000
# Patient № 356 (Stroke) arrives at: 278.124
# Patient № 356 started treatment at 278.124; queue time was 0.000
# Patient № 357 (Stroke) arrives at: 278.652
# Patient № 357 started treatment at 278.652; queue time was 0.000
# Patient № 358 (Neuro) arrives at: 278.937
# Patient № 358 started treatment at 278.967; queue time was 0.030
# Patient № 359 (Stroke) arrives at: 279.579
# Patient № 359 started treatment at 279.579; queue time was 0.000
# Patient № 360 (Stroke) arrives at: 279.984
# Patient № 360 started treatment at 279.984; queue time was 0.000
# Patient № 361 (Stroke) arrives at: 280.598
# Patient № 361 started treatment at 280.882; queue time was 0.284
# Patient № 362 (Stroke) arrives at: 281.803
# Patient № 362 started treatment at 281.803; queue time was 0.000
# Patient № 363 (Neuro) arrives at: 282.086
# Patient № 363 started treatment at 282.086; queue time was 0.000
# Patient № 364 (Neuro) arrives at: 282.637
# Patient № 364 started treatment at 282.637; queue time was 0.000
# Patient № 365 (Neuro) arrives at: 283.166
# Patient № 365 started treatment at 283.742; queue time was 0.576
# Patient № 366 (Neuro) arrives at: 284.506
# Patient № 366 started treatment at 284.506; queue time was 0.000
# Patient № 367 (Neuro) arrives at: 284.563
# Patient № 367 started treatment at 284.563; queue time was 0.000
# Patient № 368 (Stroke) arrives at: 284.970
# Patient № 368 started treatment at 284.970; queue time was 0.000
# Patient № 369 (Stroke) arrives at: 285.465
# Patient № 369 started treatment at 285.465; queue time was 0.000
# Patient № 370 (Stroke) arrives at: 285.669
# Patient № 370 started treatment at 285.669; queue time was 0.000
# Patient № 371 (Neuro) arrives at: 285.844
# Patient № 371 started treatment at 285.844; queue time was 0.000
# Patient № 372 (Stroke) arrives at: 286.202
# Patient № 372 started treatment at 286.202; queue time was 0.000
# Patient № 373 (Stroke) arrives at: 287.240
# Patient № 373 started treatment at 287.240; queue time was 0.000
# Patient № 374 (Stroke) arrives at: 288.966
# Patient № 374 started treatment at 288.966; queue time was 0.000
# Patient № 375 (Stroke) arrives at: 289.548
# Patient № 375 started treatment at 289.548; queue time was 0.000
# Patient № 376 (Stroke) arrives at: 289.850
# Patient № 376 started treatment at 289.850; queue time was 0.000
# Patient № 377 (Stroke) arrives at: 289.860
# Patient № 377 started treatment at 289.860; queue time was 0.000
# Patient № 378 (Neuro) arrives at: 290.657
# Patient № 378 started treatment at 290.657; queue time was 0.000
# Patient № 379 (Stroke) arrives at: 291.294
# Patient № 379 started treatment at 291.294; queue time was 0.000
# Patient № 380 (Stroke) arrives at: 291.549
# Patient № 380 started treatment at 291.549; queue time was 0.000
# Patient № 381 (Stroke) arrives at: 292.849
# Patient № 381 started treatment at 292.849; queue time was 0.000
# Patient № 382 (Stroke) arrives at: 293.030
# Patient № 382 started treatment at 293.030; queue time was 0.000
# Patient № 383 (Stroke) arrives at: 293.036
# Patient № 383 started treatment at 293.036; queue time was 0.000
# Patient № 384 (TIA) arrives at: 294.736
# Patient № 384 started treatment at 294.736; queue time was 0.000
# Patient № 385 (Stroke) arrives at: 295.070
# Patient № 385 started treatment at 295.070; queue time was 0.000
# Patient № 386 (Neuro) arrives at: 295.880
# Patient № 386 started treatment at 295.880; queue time was 0.000
# Patient № 387 (Stroke) arrives at: 296.915
# Patient № 387 started treatment at 296.915; queue time was 0.000
# Patient № 388 (Neuro) arrives at: 297.969
# Patient № 388 started treatment at 297.969; queue time was 0.000
# Patient № 389 (Neuro) arrives at: 298.261
# Patient № 389 started treatment at 298.261; queue time was 0.000
# Patient № 390 (TIA) arrives at: 299.061
# Patient № 390 started treatment at 299.061; queue time was 0.000
# Patient № 391 (Stroke) arrives at: 300.102
# Patient № 391 started treatment at 300.102; queue time was 0.000
# Patient № 392 (Stroke) arrives at: 300.531
# Patient № 392 started treatment at 300.531; queue time was 0.000
# Patient № 393 (Stroke) arrives at: 302.680
# Patient № 393 started treatment at 302.680; queue time was 0.000
# Patient № 394 (Neuro) arrives at: 302.975
# Patient № 394 started treatment at 302.975; queue time was 0.000
# Patient № 395 (Stroke) arrives at: 303.178
# Patient № 396 (Stroke) arrives at: 303.435
# Patient № 395 started treatment at 304.284; queue time was 1.105
# Patient № 396 started treatment at 304.566; queue time was 1.130
# Patient № 397 (Stroke) arrives at: 305.631
# Patient № 397 started treatment at 305.631; queue time was 0.000
# Patient № 398 (Stroke) arrives at: 306.413
# Patient № 399 (TIA) arrives at: 307.282
# Patient № 398 started treatment at 307.465; queue time was 1.051
# Patient № 400 (Stroke) arrives at: 307.755
# Patient № 399 started treatment at 307.854; queue time was 0.572
# Patient № 401 (Neuro) arrives at: 308.010
# Patient № 400 started treatment at 308.084; queue time was 0.328
# Patient № 401 started treatment at 308.098; queue time was 0.087
# Patient № 402 (TIA) arrives at: 308.575
# Patient № 402 started treatment at 308.575; queue time was 0.000
# Patient № 403 (Neuro) arrives at: 308.746
# Patient № 404 (Stroke) arrives at: 308.856
# Patient № 403 started treatment at 309.106; queue time was 0.360
# Patient № 404 started treatment at 309.239; queue time was 0.383
# Patient № 405 (Stroke) arrives at: 309.478
# Patient № 405 started treatment at 309.706; queue time was 0.228
# Patient № 406 (TIA) arrives at: 311.550
# Patient № 406 started treatment at 311.550; queue time was 0.000
# Patient № 407 (Stroke) arrives at: 311.666
# Patient № 407 started treatment at 311.666; queue time was 0.000
# Patient № 408 (Stroke) arrives at: 312.398
# Patient № 408 started treatment at 312.398; queue time was 0.000
# Patient № 409 (Stroke) arrives at: 312.760
# Patient № 409 started treatment at 312.760; queue time was 0.000
# Patient № 410 (Stroke) arrives at: 313.197
# Patient № 410 started treatment at 313.197; queue time was 0.000
# Patient № 411 (TIA) arrives at: 314.544
# Patient № 411 started treatment at 314.544; queue time was 0.000
# Patient № 412 (Neuro) arrives at: 316.548
# Patient № 412 started treatment at 316.548; queue time was 0.000
# Patient № 413 (Stroke) arrives at: 319.275
# Patient № 413 started treatment at 319.275; queue time was 0.000
# Patient № 414 (Stroke) arrives at: 320.409
# Patient № 414 started treatment at 320.409; queue time was 0.000
# Patient № 415 (Stroke) arrives at: 321.325
# Patient № 415 started treatment at 321.325; queue time was 0.000
# Patient № 416 (TIA) arrives at: 321.443
# Patient № 416 started treatment at 321.443; queue time was 0.000
# Patient № 417 (Stroke) arrives at: 321.608
# Patient № 417 started treatment at 321.608; queue time was 0.000
# Patient № 418 (Stroke) arrives at: 323.318
# Patient № 418 started treatment at 323.318; queue time was 0.000
# Patient № 419 (Stroke) arrives at: 323.470
# Patient № 419 started treatment at 323.470; queue time was 0.000
# Patient № 420 (Stroke) arrives at: 323.569
# Patient № 420 started treatment at 323.569; queue time was 0.000
# Patient № 421 (Stroke) arrives at: 323.779
# Patient № 421 started treatment at 323.779; queue time was 0.000
# Patient № 422 (Stroke) arrives at: 323.805
# Patient № 422 started treatment at 323.805; queue time was 0.000
# Patient № 423 (Stroke) arrives at: 323.952
# Patient № 424 (Stroke) arrives at: 323.985
# Patient № 425 (Neuro) arrives at: 324.919
# Patient № 426 (Stroke) arrives at: 325.117
# Patient № 423 started treatment at 325.211; queue time was 1.259
# Patient № 427 (Stroke) arrives at: 325.250
# Patient № 428 (Neuro) arrives at: 325.280
# Patient № 429 (Stroke) arrives at: 326.029
# Patient № 430 (Stroke) arrives at: 326.747
# Patient № 424 started treatment at 327.158; queue time was 3.173
# Patient № 425 started treatment at 327.588; queue time was 2.669
# Patient № 426 started treatment at 327.591; queue time was 2.474
# Patient № 431 (Stroke) arrives at: 327.968
# Patient № 432 (Stroke) arrives at: 328.172
# Patient № 433 (Stroke) arrives at: 328.316
# Patient № 434 (Stroke) arrives at: 328.753
# Patient № 427 started treatment at 328.987; queue time was 3.737
# Patient № 428 started treatment at 328.996; queue time was 3.717
# Patient № 435 (Neuro) arrives at: 329.214
# Patient № 436 (Stroke) arrives at: 329.326
# Patient № 437 (Stroke) arrives at: 329.598
# Patient № 438 (Stroke) arrives at: 329.884
# Patient № 429 started treatment at 330.580; queue time was 4.552
# Patient № 439 (Stroke) arrives at: 332.875
# Patient № 440 (TIA) arrives at: 332.905
# Patient № 430 started treatment at 333.424; queue time was 6.677
# Patient № 431 started treatment at 333.965; queue time was 5.997
# Patient № 432 started treatment at 335.310; queue time was 7.138
# Patient № 441 (Stroke) arrives at: 335.515
# Patient № 433 started treatment at 336.655; queue time was 8.338
# Patient № 442 (Neuro) arrives at: 336.676
# Patient № 443 (Neuro) arrives at: 336.701
# Patient № 434 started treatment at 337.225; queue time was 8.472
# Patient № 435 started treatment at 337.250; queue time was 8.036
# Patient № 436 started treatment at 337.374; queue time was 8.048
# Patient № 437 started treatment at 337.985; queue time was 8.387
# Patient № 444 (Stroke) arrives at: 338.118
# Patient № 445 (Stroke) arrives at: 338.552
# Patient № 446 (Stroke) arrives at: 338.705
# Patient № 447 (Neuro) arrives at: 339.944
# Patient № 438 started treatment at 339.955; queue time was 10.072
# Patient № 439 started treatment at 340.912; queue time was 8.037
# Patient № 448 (Stroke) arrives at: 341.737
# Patient № 440 started treatment at 341.958; queue time was 9.053
# Patient № 441 started treatment at 342.576; queue time was 7.061
# Patient № 449 (Stroke) arrives at: 342.732
# Patient № 450 (Neuro) arrives at: 343.627
# Patient № 442 started treatment at 343.730; queue time was 7.054
# Patient № 451 (Stroke) arrives at: 343.879
# Patient № 452 (Stroke) arrives at: 344.125
# Patient № 443 started treatment at 344.174; queue time was 7.473
# Patient № 444 started treatment at 344.177; queue time was 6.059
# Patient № 445 started treatment at 344.749; queue time was 6.196
# Patient № 453 (Neuro) arrives at: 344.752
# Patient № 454 (Stroke) arrives at: 345.119
# Patient № 455 (Neuro) arrives at: 345.428
# Patient № 456 (Stroke) arrives at: 345.456
# Patient № 446 started treatment at 345.660; queue time was 6.955
# Patient № 457 (Stroke) arrives at: 346.141
# Patient № 447 started treatment at 346.226; queue time was 6.282
# Patient № 448 started treatment at 346.923; queue time was 5.185
# Patient № 458 (Stroke) arrives at: 347.469
# Patient № 459 (Stroke) arrives at: 347.838
# Patient № 449 started treatment at 348.565; queue time was 5.833
# Patient № 460 (Stroke) arrives at: 348.701
# Patient № 461 (Stroke) arrives at: 348.841
# Patient № 462 (Stroke) arrives at: 349.441
# Patient № 450 started treatment at 349.851; queue time was 6.223
# Patient № 463 (Stroke) arrives at: 350.126
# Patient № 451 started treatment at 350.401; queue time was 6.522
# Patient № 452 started treatment at 351.252; queue time was 7.128
# Patient № 464 (TIA) arrives at: 351.561
# Patient № 465 (Neuro) arrives at: 352.017
# Patient № 466 (Stroke) arrives at: 352.266
# Patient № 453 started treatment at 352.364; queue time was 7.613
# Patient № 454 started treatment at 352.567; queue time was 7.447
# Patient № 467 (Stroke) arrives at: 352.940
# Patient № 455 started treatment at 353.322; queue time was 7.894
# Patient № 468 (Stroke) arrives at: 353.778
# Patient № 469 (Stroke) arrives at: 354.261
# Patient № 456 started treatment at 355.102; queue time was 9.647
# Patient № 470 (Stroke) arrives at: 355.385
# Patient № 471 (Stroke) arrives at: 356.232
# Patient № 457 started treatment at 356.672; queue time was 10.531
# Patient № 472 (Stroke) arrives at: 356.999
# Patient № 473 (Stroke) arrives at: 357.283
# Patient № 458 started treatment at 357.293; queue time was 9.824
# Patient № 459 started treatment at 357.818; queue time was 9.980
# Patient № 474 (Stroke) arrives at: 358.825
# Patient № 460 started treatment at 358.848; queue time was 10.147
# Patient № 461 started treatment at 358.855; queue time was 10.015
# Patient № 475 (Neuro) arrives at: 359.491
# Patient № 462 started treatment at 360.084; queue time was 10.643
# Patient № 463 started treatment at 360.729; queue time was 10.603
# Patient № 476 (Neuro) arrives at: 360.736
# Patient № 464 started treatment at 360.788; queue time was 9.227
# Patient № 477 (Neuro) arrives at: 361.267
# Patient № 478 (TIA) arrives at: 361.304
# Patient № 465 started treatment at 361.540; queue time was 9.523
# Patient № 466 started treatment at 361.886; queue time was 9.620
# Patient № 479 (Neuro) arrives at: 362.531
# Patient № 467 started treatment at 363.125; queue time was 10.185
# Patient № 468 started treatment at 363.176; queue time was 9.398
# Patient № 480 (Neuro) arrives at: 363.292
# Patient № 469 started treatment at 363.349; queue time was 9.088
# Patient № 470 started treatment at 363.583; queue time was 8.198
# Patient № 481 (Stroke) arrives at: 364.608
# Patient № 482 (Stroke) arrives at: 364.674
# Patient № 483 (Stroke) arrives at: 364.735
# Patient № 484 (Neuro) arrives at: 364.738
# end of run. simulation clock time = 365
#
# Single run results
# ------------------
# Mean Queue Time of Bottom 90% of the Patients: 3.40 hours!
# Bed utilisation: 76.59 %!
