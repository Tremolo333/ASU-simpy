# %% [markdown]
# # Imports
#
# Please use the provided `hds_stoch` environment for this work.

# %%
import simpy
simpy.__version__
# Out:
# '4.0.1'

# %%
import numpy as np
import pandas as pd
import itertools
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Distribution classes
#
# To help you build your model, the notebook includes some pre-written distribution classes that you may wish to use to setup sampling.  You are free to use these, but you can choose not too if you have an approach you prefer.

# %%
class Exponential:
    '''
    Convenience class for the exponential distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, mean, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        mean: float
            The mean of the exponential distribution
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.mean = mean
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.exponential(self.mean, size=size)

class Lognormal:
    """
    Encapsulates a lognormal distirbution
    """
    def __init__(self, mean, stdev, random_seed=None):
        """
        Params:
        -------
        mean = mean of the lognormal distribution
        stdev = standard dev of the lognormal distribution
        """
        self.rand = np.random.default_rng(seed=random_seed)
        mu, sigma = self.normal_moments_from_lognormal(mean, stdev**2)
        self.mu = mu
        self.sigma = sigma
        
    def normal_moments_from_lognormal(self, m, v):
        '''
        Returns mu and sigma of normal distribution
        underlying a lognormal with mean m and variance v
        source: https://blogs.sas.com/content/iml/2014/06/04/simulate-lognormal
        -data-with-specified-mean-and-variance.html

        Params:
        -------
        m = mean of lognormal distribution
        v = variance of lognormal distribution
                
        Returns:
        -------
        (float, float)
        '''
        phi = math.sqrt(v + m**2)
        mu = math.log(m**2/phi)
        sigma = math.sqrt(math.log(phi**2/m**2))
        return mu, sigma
        
    def sample(self):
        """
        Sample from the normal distribution
        """
        return self.rand.lognormal(self.mu, self.sigma)

# %% [markdown]
# # Utility functions

# %%
def trace(msg):
    '''
    Utility function for printing simulation
    set the TRACE constant to FALSE to 
    turn tracing off.
    
    Params:
    -------
    msg: str
        string to print to screen.
    '''
    if TRACE:
        print(msg)

# %% [markdown]
# # Model parameters
#
# The constants below provides hard coded data representing the base case or 'as-is' state of the minor injury unit.

# %%
# These are the parameters for a base case model run.
# Note if you change these parameters then your model will run a new 'scenario' 

# resource counts
N_BEDS = 6

# time between arrivals in minutes (exponential)
# for acute stroke, TIA and neuro respectively
MEAN_IATS = [1.2, 9.5, 3.5]

# treatment (lognormal)
TREAT_MEAN = 3.7
TREAT_STD = 4.4

# SEEDS to reproduce results of a single run
REPRODUCIBLE_RUN = True
    
if REPRODUCIBLE_RUN:
    SEEDS = [42, 101, 1066, 1966, 2013, 999, 1444, 2016]
else:
    SEEDS = [None, None, None, None, None, None, None, None]

# %% [markdown]
# # Scenario class
# In the cell below the parameters you will find a `Scenario` class.  This makes use of the default parameters to set up the base case scenario.  Remember that its good practice to pass all of your parameters to your simulation model in a **container**.  A class is a flexible way to achieve this aim.

# %%
class Scenario:
    '''
    Parameter container class for minor injury unit model.
    '''
    def __init__(self, name=None):
        '''
        The init method sets up our defaults. 
        
        Params:
        -------
        
        name - str or None
            optional name for scenario
        '''
        # optional name
        self.name = name
        
        # number of beds
        self.beds = N_BEDS
        
        # inter-arrival distributions
        self.arrival_dists = [Exponential((1.0/mean_iat), random_seed=seed) for mean_iat, seed in zip(MEAN_IATS, SEEDS[:3])]
        
        
        # treatment distribution
        self.treatment_dist = Lognormal(TREAT_MEAN, TREAT_STD, 
                                         random_seed=SEEDS[3])

# %% [markdown]
# # Model building

# %%
class Patient:
    '''
    Patient in the minor ED process
    '''
    def __init__(self, identifier, env, args):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env

        # treatment parameters
        self.beds = args.beds
        self.treatment_dist = args.treatment_dist
                
        # individual patient metrics
        self.queue_time = 0.0
        
    
    def treatment(self):
        '''
        simulates the process for minor emergencies
        
        1. request and wait for triage
        2. request and wait for a minor cubicle
        3. minor assessment
        4. exit system.
        
        '''
        # record the time that patient entered the system
        arrival_time = self.env.now
        
            
        
        # get bed
        with self.beds.request() as req:
            yield req
            
            # record time to first being seen by a doctor
            self.queue_time = self.env.now - arrival_time
            
            
            trace(f'Patient № {self.identifier} started treatment at {self.env.now:.3f};'
                      + f' queue time was {self.queue_time:.3f}')
            
            
            # sample for patient pathway
            treat_time = self.sample_all()
            
            activity_duration = treat_time
          
            # treatment delay
            yield self.env.timeout(activity_duration)
            
                        
    def sample_all(self):
        '''
        Sample assessment time, if the patient requires diagnostics,
        if the diags are done in parallel to assessment and 
        '''

        # sample assessment time
        treat_time = self.treatment_dist.sample()

        return (treat_time)

# %%
class ASU:  
    '''
    Model of an ASU
    '''
    def __init__(self, env, args):
        '''
        Contructor
        
        Params:
        -------
        env: simpy.Environment
        
        args: Scenario
            container class for simulation model inputs.
        '''
        self.env = env
        self.args = args 
        self.init_model_resources(args)
        self.patients = []
        self.patient_count = 0
        
        
    def init_model_resources(self, args):
        '''
        Setup the simpy resource objects
        
        Params:
        ------
        args - Scenario
            Simulation Parameter Container
        '''

        args.beds = simpy.Resource(self.env, 
                                   capacity=args.beds)
        
            
                
    def arrivals_generator(self):
        while True:
            for i, arrival_dist in enumerate(self.args.arrival_dists):
                inter_arrival_time = arrival_dist.sample()
                self.patient_count += 1
                yield self.env.timeout(inter_arrival_time)
                trace(f'Patient № {self.patient_count} (Type {i+1}) arrives at: {self.env.now:.3f}')
                new_patient = Patient(self.patient_count, self.env, self.args)
                self.patients.append(new_patient)
                self.env.process(new_patient.treatment())

# %% [markdown]
# # Script to run the model

# %%
# run length in days
RUN_LENGTH = 365

# Turn off tracing
TRACE = True #False 

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()

# create the model
model = ASU(env, default_args)

# setup the process
env.process(model.arrivals_generator())

env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')




# Calculate and printout Performance metrics


# mean time to treatment
mean_queue = np.array([patient.queue_time 
                               for patient in model.patients]).mean()


print('\nSingle run results\n------------------')
print(f'Mean Queue Time: {mean_queue:.2f}')


###################################################################
# Out:
# Patient № 1 (Type 1) arrives at: 2.004
# Patient № 1 started treatment at 2.004; queue time was 0.000
# Patient № 2 (Type 2) arrives at: 2.434
# Patient № 2 started treatment at 2.434; queue time was 0.000
# Patient № 3 (Type 3) arrives at: 3.050
# Patient № 3 started treatment at 3.050; queue time was 0.000
# Patient № 4 (Type 1) arrives at: 4.996
# Patient № 4 started treatment at 4.996; queue time was 0.000
# Patient № 5 (Type 2) arrives at: 5.057
# Patient № 5 started treatment at 5.057; queue time was 0.000
# Patient № 6 (Type 3) arrives at: 5.391
# Patient № 6 started treatment at 5.391; queue time was 0.000
# Patient № 7 (Type 1) arrives at: 7.378
# Patient № 7 started treatment at 7.378; queue time was 0.000
# Patient № 8 (Type 2) arrives at: 7.479
# Patient № 8 started treatment at 7.479; queue time was 0.000
# Patient № 9 (Type 3) arrives at: 7.505
# Patient № 9 started treatment at 7.505; queue time was 0.000
# Patient № 10 (Type 1) arrives at: 7.738
# Patient № 10 started treatment at 7.738; queue time was 0.000
# Patient № 11 (Type 2) arrives at: 7.847
# Patient № 12 (Type 3) arrives at: 8.038
# Patient № 13 (Type 1) arrives at: 8.110
# Patient № 14 (Type 2) arrives at: 8.177
# Patient № 15 (Type 3) arrives at: 8.254
# Patient № 11 started treatment at 8.835; queue time was 0.988
# Patient № 16 (Type 1) arrives at: 9.465
# Patient № 17 (Type 2) arrives at: 9.505
# Patient № 12 started treatment at 9.716; queue time was 1.679
# Patient № 13 started treatment at 9.791; queue time was 1.682
# Patient № 18 (Type 3) arrives at: 9.840
# Patient № 14 started treatment at 9.922; queue time was 1.745
# Patient № 15 started treatment at 10.755; queue time was 2.501
# Patient № 19 (Type 1) arrives at: 11.015
# Patient № 20 (Type 2) arrives at: 11.302
# Patient № 21 (Type 3) arrives at: 11.394
# Patient № 16 started treatment at 12.029; queue time was 2.565
# Patient № 17 started treatment at 12.061; queue time was 2.556
# Patient № 18 started treatment at 12.127; queue time was 2.287
# Patient № 19 started treatment at 13.224; queue time was 2.209
# Patient № 22 (Type 1) arrives at: 13.997
# Patient № 23 (Type 2) arrives at: 14.063
# Patient № 24 (Type 3) arrives at: 14.381
# Patient № 20 started treatment at 14.417; queue time was 3.115
# Patient № 25 (Type 1) arrives at: 14.447
# Patient № 21 started treatment at 14.530; queue time was 3.137
# Patient № 26 (Type 2) arrives at: 14.876
# Patient № 27 (Type 3) arrives at: 14.930
# Patient № 22 started treatment at 15.408; queue time was 1.411
# Patient № 23 started treatment at 15.613; queue time was 1.550
# Patient № 28 (Type 1) arrives at: 15.802
# Patient № 29 (Type 2) arrives at: 15.889
# Patient № 30 (Type 3) arrives at: 16.104
# Patient № 31 (Type 1) arrives at: 16.163
# Patient № 32 (Type 2) arrives at: 16.206
# Patient № 24 started treatment at 16.651; queue time was 2.270
# Patient № 33 (Type 3) arrives at: 16.860
# Patient № 25 started treatment at 17.700; queue time was 3.253
# Patient № 34 (Type 1) arrives at: 17.768
# Patient № 35 (Type 2) arrives at: 17.772
# Patient № 26 started treatment at 17.860; queue time was 2.984
# Patient № 36 (Type 3) arrives at: 18.106
# Patient № 27 started treatment at 18.217; queue time was 3.288
# Patient № 28 started treatment at 18.407; queue time was 2.606
# Patient № 29 started treatment at 18.746; queue time was 2.857
# Patient № 30 started treatment at 18.947; queue time was 2.843
# Patient № 31 started treatment at 19.304; queue time was 3.142
# Patient № 37 (Type 1) arrives at: 19.549
# Patient № 32 started treatment at 19.889; queue time was 3.683
# Patient № 38 (Type 2) arrives at: 20.203
# Patient № 39 (Type 3) arrives at: 20.293
# Patient № 33 started treatment at 20.405; queue time was 3.545
# Patient № 40 (Type 1) arrives at: 20.615
# Patient № 34 started treatment at 20.646; queue time was 2.879
# Patient № 41 (Type 2) arrives at: 21.034
# Patient № 35 started treatment at 21.184; queue time was 3.412
# Patient № 42 (Type 3) arrives at: 21.297
# Patient № 43 (Type 1) arrives at: 22.323
# Patient № 44 (Type 2) arrives at: 22.350
# Patient № 45 (Type 3) arrives at: 22.534
# Patient № 36 started treatment at 22.563; queue time was 4.457
# Patient № 46 (Type 1) arrives at: 22.662
# Patient № 47 (Type 2) arrives at: 22.785
# Patient № 37 started treatment at 23.181; queue time was 3.632
# Patient № 48 (Type 3) arrives at: 23.417
# Patient № 38 started treatment at 23.432; queue time was 3.229
# Patient № 49 (Type 1) arrives at: 23.494
# Patient № 50 (Type 2) arrives at: 23.657
# Patient № 39 started treatment at 24.852; queue time was 4.559
# Patient № 51 (Type 3) arrives at: 24.914
# Patient № 52 (Type 1) arrives at: 25.177
# Patient № 53 (Type 2) arrives at: 25.341
# Patient № 54 (Type 3) arrives at: 25.504
# Patient № 55 (Type 1) arrives at: 26.255
# Patient № 56 (Type 2) arrives at: 26.381
# Patient № 57 (Type 3) arrives at: 27.148
# Patient № 58 (Type 1) arrives at: 27.492
# Patient № 40 started treatment at 27.504; queue time was 6.888
# Patient № 59 (Type 2) arrives at: 27.559
# Patient № 60 (Type 3) arrives at: 28.126
# Patient № 41 started treatment at 28.682; queue time was 7.647
# Patient № 61 (Type 1) arrives at: 29.165
# Patient № 62 (Type 2) arrives at: 29.171
# Patient № 63 (Type 3) arrives at: 29.207
# Patient № 64 (Type 1) arrives at: 29.393
# Patient № 65 (Type 2) arrives at: 29.428
# Patient № 66 (Type 3) arrives at: 30.008
# Patient № 42 started treatment at 30.369; queue time was 9.072
# Patient № 43 started treatment at 30.856; queue time was 8.533
# Patient № 44 started treatment at 30.964; queue time was 8.614
# Patient № 67 (Type 1) arrives at: 31.540
# Patient № 68 (Type 2) arrives at: 31.987
# Patient № 69 (Type 3) arrives at: 32.058
# Patient № 45 started treatment at 32.432; queue time was 9.898
# Patient № 46 started treatment at 32.663; queue time was 10.001
# Patient № 47 started treatment at 32.723; queue time was 9.938
# Patient № 70 (Type 1) arrives at: 33.080
# Patient № 71 (Type 2) arrives at: 33.167
# Patient № 48 started treatment at 33.260; queue time was 9.842
# Patient № 49 started treatment at 33.282; queue time was 9.789
# Patient № 72 (Type 3) arrives at: 33.289
# Patient № 50 started treatment at 33.570; queue time was 9.913
# Patient № 73 (Type 1) arrives at: 33.835
# Patient № 74 (Type 2) arrives at: 33.965
# Patient № 75 (Type 3) arrives at: 34.150
# Patient № 51 started treatment at 34.469; queue time was 9.554
# Patient № 76 (Type 1) arrives at: 34.497
# Patient № 77 (Type 2) arrives at: 34.654
# Patient № 52 started treatment at 34.788; queue time was 9.611
# Patient № 78 (Type 3) arrives at: 34.844
# Patient № 53 started treatment at 34.893; queue time was 9.552
# Patient № 54 started treatment at 35.123; queue time was 9.619
# Patient № 79 (Type 1) arrives at: 35.221
# Patient № 55 started treatment at 35.241; queue time was 8.985
# Patient № 80 (Type 2) arrives at: 35.423
# Patient № 81 (Type 3) arrives at: 35.505
# Patient № 82 (Type 1) arrives at: 35.569
# Patient № 83 (Type 2) arrives at: 35.658
# Patient № 84 (Type 3) arrives at: 36.022
# Patient № 85 (Type 1) arrives at: 36.172
# Patient № 86 (Type 2) arrives at: 36.193
# Patient № 87 (Type 3) arrives at: 36.261
# Patient № 88 (Type 1) arrives at: 36.832
# Patient № 89 (Type 2) arrives at: 36.989
# Patient № 90 (Type 3) arrives at: 37.189
# Patient № 56 started treatment at 37.247; queue time was 10.865
# Patient № 91 (Type 1) arrives at: 37.513
# Patient № 92 (Type 2) arrives at: 37.594
# Patient № 57 started treatment at 37.793; queue time was 10.645
# Patient № 93 (Type 3) arrives at: 37.886
# Patient № 58 started treatment at 38.092; queue time was 10.600
# Patient № 94 (Type 1) arrives at: 38.940
# Patient № 59 started treatment at 39.090; queue time was 11.531
# Patient № 95 (Type 2) arrives at: 39.175
# Patient № 96 (Type 3) arrives at: 39.432
# Patient № 97 (Type 1) arrives at: 40.023
# Patient № 98 (Type 2) arrives at: 40.048
# Patient № 99 (Type 3) arrives at: 40.475
# Patient № 100 (Type 1) arrives at: 40.674
# Patient № 101 (Type 2) arrives at: 40.769
# Patient № 102 (Type 3) arrives at: 41.123
# Patient № 60 started treatment at 41.437; queue time was 13.311
# Patient № 103 (Type 1) arrives at: 41.507
# Patient № 104 (Type 2) arrives at: 41.612
# Patient № 105 (Type 3) arrives at: 41.695
# Patient № 106 (Type 1) arrives at: 42.229
# Patient № 61 started treatment at 42.291; queue time was 13.126
# Patient № 107 (Type 2) arrives at: 42.410
# Patient № 62 started treatment at 42.447; queue time was 13.276
# Patient № 108 (Type 3) arrives at: 42.680
# Patient № 109 (Type 1) arrives at: 42.967
# Patient № 110 (Type 2) arrives at: 43.044
# Patient № 63 started treatment at 43.058; queue time was 13.851
# Patient № 111 (Type 3) arrives at: 43.110
# Patient № 112 (Type 1) arrives at: 43.378
# Patient № 113 (Type 2) arrives at: 43.427
# Patient № 114 (Type 3) arrives at: 43.469
# Patient № 64 started treatment at 43.951; queue time was 14.558
# Patient № 65 started treatment at 44.154; queue time was 14.726
# Patient № 115 (Type 1) arrives at: 44.201
# Patient № 116 (Type 2) arrives at: 44.243
# Patient № 117 (Type 3) arrives at: 44.246
# Patient № 118 (Type 1) arrives at: 44.493
# Patient № 119 (Type 2) arrives at: 44.528
# Patient № 66 started treatment at 44.644; queue time was 14.636
# Patient № 67 started treatment at 44.886; queue time was 13.347
# Patient № 68 started treatment at 45.127; queue time was 13.139
# Patient № 120 (Type 3) arrives at: 45.178
# Patient № 69 started treatment at 46.000; queue time was 13.942
# Patient № 121 (Type 1) arrives at: 46.290
# Patient № 122 (Type 2) arrives at: 46.310
# Patient № 70 started treatment at 46.550; queue time was 13.469
# Patient № 123 (Type 3) arrives at: 46.651
# Patient № 71 started treatment at 46.661; queue time was 13.494
# Patient № 72 started treatment at 46.728; queue time was 13.439
# Patient № 73 started treatment at 47.034; queue time was 13.199
# Patient № 74 started treatment at 47.059; queue time was 13.094
# Patient № 124 (Type 1) arrives at: 47.810
# Patient № 125 (Type 2) arrives at: 47.888
# Patient № 126 (Type 3) arrives at: 47.972
# Patient № 75 started treatment at 48.718; queue time was 14.568
# Patient № 127 (Type 1) arrives at: 48.875
# Patient № 128 (Type 2) arrives at: 48.913
# Patient № 129 (Type 3) arrives at: 49.013
# Patient № 130 (Type 1) arrives at: 49.074
# Patient № 131 (Type 2) arrives at: 49.090
# Patient № 132 (Type 3) arrives at: 49.331
# Patient № 76 started treatment at 49.611; queue time was 15.114
# Patient № 77 started treatment at 49.987; queue time was 15.333
# Patient № 133 (Type 1) arrives at: 50.276
# Patient № 134 (Type 2) arrives at: 50.312
# Patient № 135 (Type 3) arrives at: 50.484
# Patient № 78 started treatment at 51.188; queue time was 16.344
# Patient № 79 started treatment at 51.235; queue time was 16.014
# Patient № 80 started treatment at 51.246; queue time was 15.823
# Patient № 136 (Type 1) arrives at: 51.613
# Patient № 81 started treatment at 51.646; queue time was 16.141
# Patient № 137 (Type 2) arrives at: 51.673
# Patient № 138 (Type 3) arrives at: 52.659
# Patient № 82 started treatment at 53.158; queue time was 17.589
# Patient № 139 (Type 1) arrives at: 53.594
# Patient № 140 (Type 2) arrives at: 53.604
# Patient № 141 (Type 3) arrives at: 53.716
# Patient № 142 (Type 1) arrives at: 53.949
# Patient № 143 (Type 2) arrives at: 54.137
# Patient № 144 (Type 3) arrives at: 54.141
# Patient № 83 started treatment at 54.207; queue time was 18.549
# Patient № 145 (Type 1) arrives at: 54.409
# Patient № 146 (Type 2) arrives at: 54.611
# Patient № 147 (Type 3) arrives at: 54.612
# Patient № 148 (Type 1) arrives at: 54.750
# Patient № 149 (Type 2) arrives at: 54.808
# Patient № 150 (Type 3) arrives at: 54.897
# Patient № 151 (Type 1) arrives at: 55.192
# Patient № 152 (Type 2) arrives at: 55.325
# Patient № 153 (Type 3) arrives at: 56.282
# Patient № 154 (Type 1) arrives at: 56.300
# Patient № 84 started treatment at 56.539; queue time was 20.517
# Patient № 155 (Type 2) arrives at: 56.560
# Patient № 85 started treatment at 56.936; queue time was 20.765
# Patient № 86 started treatment at 56.955; queue time was 20.762
# Patient № 156 (Type 3) arrives at: 57.128
# Patient № 157 (Type 1) arrives at: 57.267
# Patient № 158 (Type 2) arrives at: 57.276
# Patient № 159 (Type 3) arrives at: 57.346
# Patient № 87 started treatment at 57.998; queue time was 21.737
# Patient № 88 started treatment at 58.027; queue time was 21.195
# Patient № 160 (Type 1) arrives at: 58.442
# Patient № 161 (Type 2) arrives at: 58.501
# Patient № 162 (Type 3) arrives at: 58.674
# Patient № 89 started treatment at 59.041; queue time was 22.052
# Patient № 90 started treatment at 60.317; queue time was 23.128
# Patient № 91 started treatment at 61.614; queue time was 24.101
# Patient № 92 started treatment at 61.638; queue time was 24.044
# Patient № 163 (Type 1) arrives at: 62.003
# Patient № 164 (Type 2) arrives at: 62.152
# Patient № 93 started treatment at 62.196; queue time was 24.309
# Patient № 165 (Type 3) arrives at: 62.372
# Patient № 166 (Type 1) arrives at: 62.842
# Patient № 167 (Type 2) arrives at: 62.857
# Patient № 94 started treatment at 62.937; queue time was 23.998
# Patient № 168 (Type 3) arrives at: 63.023
# Patient № 169 (Type 1) arrives at: 63.260
# Patient № 170 (Type 2) arrives at: 63.432
# Patient № 171 (Type 3) arrives at: 63.451
# Patient № 95 started treatment at 63.603; queue time was 24.427
# Patient № 172 (Type 1) arrives at: 63.783
# Patient № 173 (Type 2) arrives at: 63.796
# Patient № 96 started treatment at 63.850; queue time was 24.418
# Patient № 97 started treatment at 63.992; queue time was 23.969
# Patient № 174 (Type 3) arrives at: 64.202
# Patient № 175 (Type 1) arrives at: 64.503
# Patient № 176 (Type 2) arrives at: 64.681
# Patient № 177 (Type 3) arrives at: 65.241
# Patient № 178 (Type 1) arrives at: 65.349
# Patient № 179 (Type 2) arrives at: 65.358
# Patient № 98 started treatment at 65.417; queue time was 25.369
# Patient № 180 (Type 3) arrives at: 65.679
# Patient № 99 started treatment at 66.083; queue time was 25.608
# Patient № 181 (Type 1) arrives at: 66.581
# Patient № 182 (Type 2) arrives at: 66.585
# Patient № 183 (Type 3) arrives at: 66.599
# Patient № 100 started treatment at 67.612; queue time was 26.938
# Patient № 184 (Type 1) arrives at: 67.746
# Patient № 185 (Type 2) arrives at: 67.760
# Patient № 101 started treatment at 67.800; queue time was 27.031
# Patient № 186 (Type 3) arrives at: 67.862
# Patient № 102 started treatment at 67.864; queue time was 26.741
# Patient № 103 started treatment at 68.333; queue time was 26.826
# Patient № 104 started treatment at 68.905; queue time was 27.293
# Patient № 187 (Type 1) arrives at: 69.118
# Patient № 188 (Type 2) arrives at: 69.221
# Patient № 189 (Type 3) arrives at: 69.398
# Patient № 105 started treatment at 70.003; queue time was 28.308
# Patient № 106 started treatment at 70.995; queue time was 28.766
# Patient № 107 started treatment at 72.438; queue time was 30.028
# Patient № 108 started treatment at 72.543; queue time was 29.863
# Patient № 109 started treatment at 72.836; queue time was 29.870
# Patient № 110 started treatment at 73.134; queue time was 30.090
# Patient № 111 started treatment at 73.584; queue time was 30.474
# Patient № 190 (Type 1) arrives at: 73.823
# Patient № 191 (Type 2) arrives at: 74.031
# Patient № 192 (Type 3) arrives at: 74.692
# Patient № 112 started treatment at 75.649; queue time was 32.271
# Patient № 193 (Type 1) arrives at: 76.448
# Patient № 194 (Type 2) arrives at: 76.711
# Patient № 195 (Type 3) arrives at: 76.755
# Patient № 196 (Type 1) arrives at: 78.125
# Patient № 197 (Type 2) arrives at: 78.437
# Patient № 198 (Type 3) arrives at: 78.483
# Patient № 113 started treatment at 78.499; queue time was 35.072
# Patient № 114 started treatment at 78.901; queue time was 35.432
# Patient № 199 (Type 1) arrives at: 79.353
# Patient № 200 (Type 2) arrives at: 79.394
# Patient № 201 (Type 3) arrives at: 79.780
# Patient № 115 started treatment at 79.866; queue time was 35.664
# Patient № 202 (Type 1) arrives at: 80.274
# Patient № 116 started treatment at 80.359; queue time was 36.116
# Patient № 203 (Type 2) arrives at: 80.365
# Patient № 204 (Type 3) arrives at: 80.645
# Patient № 205 (Type 1) arrives at: 80.682
# Patient № 206 (Type 2) arrives at: 80.730
# Patient № 207 (Type 3) arrives at: 80.963
# Patient № 208 (Type 1) arrives at: 81.760
# Patient № 117 started treatment at 82.051; queue time was 37.805
# Patient № 209 (Type 2) arrives at: 82.096
# Patient № 210 (Type 3) arrives at: 82.447
# Patient № 118 started treatment at 82.625; queue time was 38.132
# Patient № 211 (Type 1) arrives at: 82.965
# Patient № 119 started treatment at 83.049; queue time was 38.521
# Patient № 212 (Type 2) arrives at: 83.176
# Patient № 213 (Type 3) arrives at: 83.228
# Patient № 214 (Type 1) arrives at: 84.485
# Patient № 120 started treatment at 84.495; queue time was 39.317
# Patient № 215 (Type 2) arrives at: 84.513
# Patient № 216 (Type 3) arrives at: 84.684
# Patient № 121 started treatment at 86.031; queue time was 39.741
# Patient № 217 (Type 1) arrives at: 86.374
# Patient № 122 started treatment at 86.452; queue time was 40.143
# Patient № 218 (Type 2) arrives at: 86.510
# Patient № 219 (Type 3) arrives at: 86.635
# Patient № 220 (Type 1) arrives at: 86.912
# Patient № 221 (Type 2) arrives at: 86.975
# Patient № 222 (Type 3) arrives at: 87.107
# Patient № 223 (Type 1) arrives at: 87.148
# Patient № 224 (Type 2) arrives at: 87.295
# Patient № 123 started treatment at 87.463; queue time was 40.812
# Patient № 225 (Type 3) arrives at: 87.563
# Patient № 226 (Type 1) arrives at: 88.334
# Patient № 227 (Type 2) arrives at: 88.698
# Patient № 228 (Type 3) arrives at: 88.717
# Patient № 124 started treatment at 89.860; queue time was 42.050
# Patient № 125 started treatment at 90.024; queue time was 42.137
# Patient № 229 (Type 1) arrives at: 90.844
# Patient № 230 (Type 2) arrives at: 90.986
# Patient № 231 (Type 3) arrives at: 91.163
# Patient № 232 (Type 1) arrives at: 91.847
# Patient № 233 (Type 2) arrives at: 91.938
# Patient № 234 (Type 3) arrives at: 91.944
# Patient № 126 started treatment at 92.307; queue time was 44.335
# Patient № 127 started treatment at 92.357; queue time was 43.482
# Patient № 128 started treatment at 92.599; queue time was 43.686
# Patient № 129 started treatment at 92.909; queue time was 43.896
# Patient № 130 started treatment at 93.364; queue time was 44.290
# Patient № 235 (Type 1) arrives at: 93.719
# Patient № 236 (Type 2) arrives at: 93.775
# Patient № 237 (Type 3) arrives at: 93.778
# Patient № 131 started treatment at 93.916; queue time was 44.827
# Patient № 238 (Type 1) arrives at: 94.406
# Patient № 239 (Type 2) arrives at: 94.437
# Patient № 132 started treatment at 94.678; queue time was 45.348
# Patient № 240 (Type 3) arrives at: 94.721
# Patient № 133 started treatment at 95.126; queue time was 44.850
# Patient № 241 (Type 1) arrives at: 95.816
# Patient № 134 started treatment at 95.951; queue time was 45.639
# Patient № 242 (Type 2) arrives at: 95.952
# Patient № 243 (Type 3) arrives at: 96.012
# Patient № 244 (Type 1) arrives at: 96.253
# Patient № 245 (Type 2) arrives at: 96.291
# Patient № 135 started treatment at 96.531; queue time was 46.047
# Patient № 136 started treatment at 96.832; queue time was 45.219
# Patient № 246 (Type 3) arrives at: 96.936
# Patient № 247 (Type 1) arrives at: 97.048
# Patient № 248 (Type 2) arrives at: 97.057
# Patient № 249 (Type 3) arrives at: 98.071
# Patient № 250 (Type 1) arrives at: 98.190
# Patient № 251 (Type 2) arrives at: 98.411
# Patient № 252 (Type 3) arrives at: 98.424
# Patient № 253 (Type 1) arrives at: 98.522
# Patient № 254 (Type 2) arrives at: 98.529
# Patient № 137 started treatment at 98.769; queue time was 47.096
# Patient № 255 (Type 3) arrives at: 99.048
# Patient № 256 (Type 1) arrives at: 99.093
# Patient № 257 (Type 2) arrives at: 99.193
# Patient № 138 started treatment at 99.194; queue time was 46.535
# Patient № 258 (Type 3) arrives at: 99.240
# Patient № 139 started treatment at 99.678; queue time was 46.084
# Patient № 140 started treatment at 100.255; queue time was 46.651
# Patient № 259 (Type 1) arrives at: 100.671
# Patient № 141 started treatment at 100.677; queue time was 46.961
# Patient № 142 started treatment at 100.730; queue time was 46.781
# Patient № 260 (Type 2) arrives at: 100.847
# Patient № 261 (Type 3) arrives at: 100.979
# Patient № 143 started treatment at 101.080; queue time was 46.943
# Patient № 144 started treatment at 101.149; queue time was 47.008
# Patient № 262 (Type 1) arrives at: 101.353
# Patient № 263 (Type 2) arrives at: 101.600
# Patient № 145 started treatment at 101.760; queue time was 47.351
# Patient № 264 (Type 3) arrives at: 102.010
# Patient № 146 started treatment at 102.097; queue time was 47.486
# Patient № 147 started treatment at 102.215; queue time was 47.603
# Patient № 265 (Type 1) arrives at: 102.332
# Patient № 266 (Type 2) arrives at: 102.339
# Patient № 148 started treatment at 102.581; queue time was 47.831
# Patient № 149 started treatment at 103.093; queue time was 48.285
# Patient № 150 started treatment at 103.637; queue time was 48.740
# Patient № 151 started treatment at 103.719; queue time was 48.527
# Patient № 267 (Type 3) arrives at: 103.757
# Patient № 152 started treatment at 104.363; queue time was 49.038
# Patient № 268 (Type 1) arrives at: 104.537
# Patient № 153 started treatment at 104.541; queue time was 48.259
# Patient № 154 started treatment at 104.558; queue time was 48.258
# Patient № 269 (Type 2) arrives at: 104.860
# Patient № 270 (Type 3) arrives at: 104.994
# Patient № 155 started treatment at 105.039; queue time was 48.479
# Patient № 156 started treatment at 105.062; queue time was 47.934
# Patient № 271 (Type 1) arrives at: 105.150
# Patient № 272 (Type 2) arrives at: 105.313
# Patient № 157 started treatment at 105.726; queue time was 48.459
# Patient № 273 (Type 3) arrives at: 105.858
# Patient № 158 started treatment at 106.772; queue time was 49.496
# Patient № 159 started treatment at 107.346; queue time was 50.000
# Patient № 160 started treatment at 107.359; queue time was 48.918
# Patient № 161 started treatment at 107.427; queue time was 48.926
# Patient № 274 (Type 1) arrives at: 107.456
# Patient № 275 (Type 2) arrives at: 107.596
# Patient № 276 (Type 3) arrives at: 107.813
# Patient № 162 started treatment at 108.091; queue time was 49.417
# Patient № 277 (Type 1) arrives at: 108.890
# Patient № 278 (Type 2) arrives at: 108.918
# Patient № 163 started treatment at 109.043; queue time was 47.040
# Patient № 279 (Type 3) arrives at: 109.277
# Patient № 280 (Type 1) arrives at: 109.551
# Patient № 281 (Type 2) arrives at: 109.577
# Patient № 164 started treatment at 109.696; queue time was 47.544
# Patient № 282 (Type 3) arrives at: 109.772
# Patient № 283 (Type 1) arrives at: 109.939
# Patient № 165 started treatment at 110.006; queue time was 47.634
# Patient № 284 (Type 2) arrives at: 110.090
# Patient № 166 started treatment at 110.548; queue time was 47.706
# Patient № 167 started treatment at 110.660; queue time was 47.803
# Patient № 285 (Type 3) arrives at: 110.989
# Patient № 168 started treatment at 111.137; queue time was 48.114
# Patient № 286 (Type 1) arrives at: 111.431
# Patient № 287 (Type 2) arrives at: 111.554
# Patient № 288 (Type 3) arrives at: 111.646
# Patient № 289 (Type 1) arrives at: 111.900
# Patient № 290 (Type 2) arrives at: 111.970
# Patient № 169 started treatment at 112.535; queue time was 49.275
# Patient № 170 started treatment at 112.749; queue time was 49.317
# Patient № 291 (Type 3) arrives at: 112.824
# Patient № 292 (Type 1) arrives at: 112.887
# Patient № 293 (Type 2) arrives at: 112.925
# Patient № 294 (Type 3) arrives at: 113.182
# Patient № 171 started treatment at 113.220; queue time was 49.769
# Patient № 295 (Type 1) arrives at: 113.602
# Patient № 296 (Type 2) arrives at: 113.636
# Patient № 297 (Type 3) arrives at: 114.141
# Patient № 172 started treatment at 115.095; queue time was 51.312
# Patient № 173 started treatment at 115.875; queue time was 52.079
# Patient № 298 (Type 1) arrives at: 116.018
# Patient № 299 (Type 2) arrives at: 116.087
# Patient № 300 (Type 3) arrives at: 116.347
# Patient № 174 started treatment at 116.551; queue time was 52.349
# Patient № 175 started treatment at 116.998; queue time was 52.495
# Patient № 301 (Type 1) arrives at: 117.188
# Patient № 302 (Type 2) arrives at: 117.276
# Patient № 303 (Type 3) arrives at: 117.626
# Patient № 176 started treatment at 118.079; queue time was 53.397
# Patient № 177 started treatment at 118.127; queue time was 52.886
# Patient № 178 started treatment at 118.181; queue time was 52.832
# Patient № 179 started treatment at 119.215; queue time was 53.857
# Patient № 180 started treatment at 119.537; queue time was 53.858
# Patient № 181 started treatment at 119.863; queue time was 53.282
# Patient № 304 (Type 1) arrives at: 120.195
# Patient № 305 (Type 2) arrives at: 120.207
# Patient № 306 (Type 3) arrives at: 120.297
# Patient № 182 started treatment at 121.520; queue time was 54.935
# Patient № 183 started treatment at 121.946; queue time was 55.347
# Patient № 184 started treatment at 122.002; queue time was 54.256
# Patient № 307 (Type 1) arrives at: 122.002
# Patient № 308 (Type 2) arrives at: 122.046
# Patient № 309 (Type 3) arrives at: 122.248
# Patient № 185 started treatment at 122.399; queue time was 54.638
# Patient № 186 started treatment at 122.717; queue time was 54.855
# Patient № 310 (Type 1) arrives at: 123.179
# Patient № 311 (Type 2) arrives at: 123.201
# Patient № 187 started treatment at 123.337; queue time was 54.218
# Patient № 312 (Type 3) arrives at: 123.354
# Patient № 188 started treatment at 124.606; queue time was 55.385
# Patient № 313 (Type 1) arrives at: 124.896
# Patient № 314 (Type 2) arrives at: 125.130
# Patient № 315 (Type 3) arrives at: 125.247
# Patient № 189 started treatment at 125.777; queue time was 56.379
# Patient № 316 (Type 1) arrives at: 125.853
# Patient № 317 (Type 2) arrives at: 125.878
# Patient № 190 started treatment at 126.203; queue time was 52.380
# Patient № 318 (Type 3) arrives at: 126.216
# Patient № 319 (Type 1) arrives at: 127.106
# Patient № 320 (Type 2) arrives at: 127.225
# Patient № 321 (Type 3) arrives at: 127.313
# Patient № 191 started treatment at 127.551; queue time was 53.520
# Patient № 192 started treatment at 127.610; queue time was 52.917
# Patient № 322 (Type 1) arrives at: 127.630
# Patient № 323 (Type 2) arrives at: 127.707
# Patient № 324 (Type 3) arrives at: 127.891
# Patient № 325 (Type 1) arrives at: 128.073
# Patient № 326 (Type 2) arrives at: 128.244
# Patient № 327 (Type 3) arrives at: 128.480
# Patient № 193 started treatment at 129.811; queue time was 53.363
# Patient № 194 started treatment at 129.880; queue time was 53.168
# Patient № 328 (Type 1) arrives at: 130.268
# Patient № 329 (Type 2) arrives at: 130.287
# Patient № 330 (Type 3) arrives at: 130.345
# Patient № 331 (Type 1) arrives at: 130.462
# Patient № 332 (Type 2) arrives at: 130.471
# Patient № 333 (Type 3) arrives at: 130.605
# Patient № 334 (Type 1) arrives at: 130.762
# Patient № 335 (Type 2) arrives at: 131.119
# Patient № 195 started treatment at 131.247; queue time was 54.492
# Patient № 336 (Type 3) arrives at: 131.570
# Patient № 337 (Type 1) arrives at: 131.828
# Patient № 338 (Type 2) arrives at: 131.847
# Patient № 339 (Type 3) arrives at: 131.912
# Patient № 340 (Type 1) arrives at: 132.718
# Patient № 341 (Type 2) arrives at: 132.741
# Patient № 342 (Type 3) arrives at: 133.085
# Patient № 343 (Type 1) arrives at: 133.430
# Patient № 196 started treatment at 133.430; queue time was 55.305
# Patient № 344 (Type 2) arrives at: 134.050
# Patient № 345 (Type 3) arrives at: 134.104
# Patient № 197 started treatment at 134.406; queue time was 55.968
# Patient № 346 (Type 1) arrives at: 134.675
# Patient № 347 (Type 2) arrives at: 134.778
# Patient № 348 (Type 3) arrives at: 134.788
# Patient № 198 started treatment at 135.726; queue time was 57.243
# Patient № 199 started treatment at 135.907; queue time was 56.555
# Patient № 349 (Type 1) arrives at: 136.588
# Patient № 350 (Type 2) arrives at: 136.663
# Patient № 351 (Type 3) arrives at: 137.009
# Patient № 200 started treatment at 137.510; queue time was 58.117
# Patient № 201 started treatment at 137.631; queue time was 57.851
# Patient № 352 (Type 1) arrives at: 138.294
# Patient № 353 (Type 2) arrives at: 138.339
# Patient № 202 started treatment at 138.678; queue time was 58.404
# Patient № 354 (Type 3) arrives at: 138.990
# Patient № 203 started treatment at 139.035; queue time was 58.670
# Patient № 204 started treatment at 139.329; queue time was 58.684
# Patient № 205 started treatment at 139.619; queue time was 58.937
# Patient № 355 (Type 1) arrives at: 139.966
# Patient № 356 (Type 2) arrives at: 140.057
# Patient № 206 started treatment at 140.072; queue time was 59.342
# Patient № 357 (Type 3) arrives at: 140.179
# Patient № 358 (Type 1) arrives at: 140.321
# Patient № 359 (Type 2) arrives at: 140.359
# Patient № 360 (Type 3) arrives at: 140.559
# Patient № 207 started treatment at 140.893; queue time was 59.930
# Patient № 361 (Type 1) arrives at: 141.550
# Patient № 362 (Type 2) arrives at: 141.675
# Patient № 363 (Type 3) arrives at: 142.489
# Patient № 364 (Type 1) arrives at: 142.868
# Patient № 365 (Type 2) arrives at: 142.888
# Patient № 208 started treatment at 142.962; queue time was 61.202
# Patient № 209 started treatment at 143.025; queue time was 60.929
# Patient № 210 started treatment at 143.235; queue time was 60.788
# Patient № 366 (Type 3) arrives at: 143.323
# Patient № 367 (Type 1) arrives at: 143.426
# Patient № 368 (Type 2) arrives at: 143.473
# Patient № 211 started treatment at 143.547; queue time was 60.582
# Patient № 369 (Type 3) arrives at: 143.698
# Patient № 212 started treatment at 143.843; queue time was 60.667
# Patient № 370 (Type 1) arrives at: 144.031
# Patient № 371 (Type 2) arrives at: 144.252
# Patient № 372 (Type 3) arrives at: 144.421
# Patient № 373 (Type 1) arrives at: 144.479
# Patient № 374 (Type 2) arrives at: 144.550
# Patient № 375 (Type 3) arrives at: 144.739
# Patient № 213 started treatment at 144.891; queue time was 61.662
# Patient № 376 (Type 1) arrives at: 145.502
# Patient № 377 (Type 2) arrives at: 145.504
# Patient № 378 (Type 3) arrives at: 146.639
# Patient № 379 (Type 1) arrives at: 147.449
# Patient № 214 started treatment at 147.478; queue time was 62.993
# Patient № 380 (Type 2) arrives at: 147.728
# Patient № 381 (Type 3) arrives at: 147.840
# Patient № 215 started treatment at 148.019; queue time was 63.506
# Patient № 216 started treatment at 148.041; queue time was 63.357
# Patient № 382 (Type 1) arrives at: 148.085
# Patient № 383 (Type 2) arrives at: 148.284
# Patient № 384 (Type 3) arrives at: 148.707
# Patient № 385 (Type 1) arrives at: 148.745
# Patient № 217 started treatment at 148.919; queue time was 62.545
# Patient № 386 (Type 2) arrives at: 148.976
# Patient № 387 (Type 3) arrives at: 148.979
# Patient № 218 started treatment at 149.164; queue time was 62.654
# Patient № 219 started treatment at 149.660; queue time was 63.025
# Patient № 220 started treatment at 150.325; queue time was 63.413
# Patient № 388 (Type 1) arrives at: 151.254
# Patient № 389 (Type 2) arrives at: 151.321
# Patient № 390 (Type 3) arrives at: 151.561
# Patient № 221 started treatment at 152.217; queue time was 65.242
# Patient № 391 (Type 1) arrives at: 152.234
# Patient № 392 (Type 2) arrives at: 152.302
# Patient № 222 started treatment at 152.304; queue time was 65.197
# Patient № 393 (Type 3) arrives at: 152.377
# Patient № 223 started treatment at 153.079; queue time was 65.931
# Patient № 394 (Type 1) arrives at: 153.617
# Patient № 224 started treatment at 153.699; queue time was 66.405
# Patient № 225 started treatment at 153.704; queue time was 66.141
# Patient № 395 (Type 2) arrives at: 153.722
# Patient № 396 (Type 3) arrives at: 155.077
# Patient № 397 (Type 1) arrives at: 155.371
# Patient № 398 (Type 2) arrives at: 155.478
# Patient № 399 (Type 3) arrives at: 156.093
# Patient № 226 started treatment at 156.105; queue time was 67.772
# Patient № 227 started treatment at 156.824; queue time was 68.126
# Patient № 228 started treatment at 157.360; queue time was 68.644
# Patient № 400 (Type 1) arrives at: 157.490
# Patient № 401 (Type 2) arrives at: 157.588
# Patient № 229 started treatment at 157.784; queue time was 66.939
# Patient № 402 (Type 3) arrives at: 157.935
# Patient № 230 started treatment at 158.147; queue time was 67.161
# Patient № 231 started treatment at 158.977; queue time was 67.815
# Patient № 403 (Type 1) arrives at: 159.303
# Patient № 404 (Type 2) arrives at: 159.354
# Patient № 405 (Type 3) arrives at: 159.373
# Patient № 406 (Type 1) arrives at: 159.450
# Patient № 407 (Type 2) arrives at: 159.560
# Patient № 408 (Type 3) arrives at: 159.793
# Patient № 232 started treatment at 160.377; queue time was 68.531
# Patient № 233 started treatment at 160.727; queue time was 68.789
# Patient № 234 started treatment at 161.542; queue time was 69.598
# Patient № 235 started treatment at 162.208; queue time was 68.488
# Patient № 409 (Type 1) arrives at: 164.319
# Patient № 410 (Type 2) arrives at: 164.468
# Patient № 236 started treatment at 165.170; queue time was 71.394
# Patient № 411 (Type 3) arrives at: 165.241
# Patient № 237 started treatment at 165.336; queue time was 71.558
# Patient № 412 (Type 1) arrives at: 165.802
# Patient № 238 started treatment at 165.816; queue time was 71.410
# Patient № 413 (Type 2) arrives at: 165.872
# Patient № 239 started treatment at 166.190; queue time was 71.753
# Patient № 414 (Type 3) arrives at: 166.314
# Patient № 415 (Type 1) arrives at: 167.479
# Patient № 416 (Type 2) arrives at: 167.584
# Patient № 417 (Type 3) arrives at: 167.839
# Patient № 240 started treatment at 168.024; queue time was 73.302
# Patient № 418 (Type 1) arrives at: 168.042
# Patient № 419 (Type 2) arrives at: 168.084
# Patient № 420 (Type 3) arrives at: 168.470
# Patient № 421 (Type 1) arrives at: 169.290
# Patient № 422 (Type 2) arrives at: 169.495
# Patient № 423 (Type 3) arrives at: 170.032
# Patient № 241 started treatment at 170.091; queue time was 74.275
# Patient № 424 (Type 1) arrives at: 170.271
# Patient № 425 (Type 2) arrives at: 170.376
# Patient № 426 (Type 3) arrives at: 170.461
# Patient № 242 started treatment at 170.625; queue time was 74.672
# Patient № 243 started treatment at 171.270; queue time was 75.258
# Patient № 427 (Type 1) arrives at: 171.806
# Patient № 244 started treatment at 171.962; queue time was 75.709
# Patient № 428 (Type 2) arrives at: 171.997
# Patient № 429 (Type 3) arrives at: 172.090
# Patient № 245 started treatment at 172.392; queue time was 76.102
# Patient № 430 (Type 1) arrives at: 172.476
# Patient № 431 (Type 2) arrives at: 172.503
# Patient № 246 started treatment at 173.019; queue time was 76.084
# Patient № 247 started treatment at 173.080; queue time was 76.032
# Patient № 432 (Type 3) arrives at: 173.612
# Patient № 248 started treatment at 173.719; queue time was 76.661
# Patient № 249 started treatment at 173.946; queue time was 75.875
# Patient № 433 (Type 1) arrives at: 174.261
# Patient № 434 (Type 2) arrives at: 174.308
# Patient № 250 started treatment at 174.400; queue time was 76.210
# Patient № 435 (Type 3) arrives at: 174.472
# Patient № 251 started treatment at 174.480; queue time was 76.069
# Patient № 436 (Type 1) arrives at: 174.912
# Patient № 437 (Type 2) arrives at: 175.031
# Patient № 438 (Type 3) arrives at: 175.035
# Patient № 439 (Type 1) arrives at: 175.663
# Patient № 440 (Type 2) arrives at: 175.812
# Patient № 252 started treatment at 175.822; queue time was 77.398
# Patient № 441 (Type 3) arrives at: 175.852
# Patient № 253 started treatment at 176.055; queue time was 77.533
# Patient № 254 started treatment at 176.125; queue time was 77.596
# Patient № 442 (Type 1) arrives at: 176.245
# Patient № 443 (Type 2) arrives at: 176.333
# Patient № 255 started treatment at 176.417; queue time was 77.370
# Patient № 444 (Type 3) arrives at: 176.663
# Patient № 256 started treatment at 176.945; queue time was 77.852
# Patient № 257 started treatment at 176.982; queue time was 77.789
# Patient № 445 (Type 1) arrives at: 177.174
# Patient № 446 (Type 2) arrives at: 177.191
# Patient № 447 (Type 3) arrives at: 177.418
# Patient № 448 (Type 1) arrives at: 177.442
# Patient № 449 (Type 2) arrives at: 177.507
# Patient № 450 (Type 3) arrives at: 178.219
# Patient № 451 (Type 1) arrives at: 179.542
# Patient № 452 (Type 2) arrives at: 179.835
# Patient № 453 (Type 3) arrives at: 179.870
# Patient № 258 started treatment at 180.120; queue time was 80.880
# Patient № 259 started treatment at 180.783; queue time was 80.112
# Patient № 454 (Type 1) arrives at: 181.962
# Patient № 260 started treatment at 181.997; queue time was 81.149
# Patient № 455 (Type 2) arrives at: 182.134
# Patient № 456 (Type 3) arrives at: 182.165
# Patient № 457 (Type 1) arrives at: 182.649
# Patient № 458 (Type 2) arrives at: 182.688
# Patient № 459 (Type 3) arrives at: 182.721
# Patient № 261 started treatment at 183.633; queue time was 82.654
# Patient № 262 started treatment at 184.628; queue time was 83.276
# Patient № 263 started treatment at 184.937; queue time was 83.337
# Patient № 264 started treatment at 185.393; queue time was 83.383
# Patient № 460 (Type 1) arrives at: 185.558
# Patient № 461 (Type 2) arrives at: 185.564
# Patient № 265 started treatment at 185.712; queue time was 83.381
# Patient № 462 (Type 3) arrives at: 186.633
# Patient № 266 started treatment at 186.744; queue time was 84.405
# Patient № 463 (Type 1) arrives at: 186.773
# Patient № 267 started treatment at 186.853; queue time was 83.096
# Patient № 464 (Type 2) arrives at: 186.916
# Patient № 465 (Type 3) arrives at: 187.015
# Patient № 268 started treatment at 187.172; queue time was 82.635
# Patient № 269 started treatment at 187.408; queue time was 82.548
# Patient № 270 started treatment at 188.145; queue time was 83.151
# Patient № 271 started treatment at 188.196; queue time was 83.045
# Patient № 272 started treatment at 188.704; queue time was 83.391
# Patient № 466 (Type 1) arrives at: 189.336
# Patient № 273 started treatment at 189.459; queue time was 83.602
# Patient № 467 (Type 2) arrives at: 189.468
# Patient № 468 (Type 3) arrives at: 189.555
# Patient № 469 (Type 1) arrives at: 189.859
# Patient № 274 started treatment at 189.891; queue time was 82.434
# Patient № 470 (Type 2) arrives at: 190.015
# Patient № 471 (Type 3) arrives at: 190.088
# Patient № 472 (Type 1) arrives at: 190.646
# Patient № 473 (Type 2) arrives at: 190.865
# Patient № 275 started treatment at 191.185; queue time was 83.589
# Patient № 474 (Type 3) arrives at: 191.307
# Patient № 276 started treatment at 191.385; queue time was 83.572
# Patient № 277 started treatment at 191.509; queue time was 82.619
# Patient № 278 started treatment at 192.600; queue time was 83.682
# Patient № 475 (Type 1) arrives at: 193.338
# Patient № 476 (Type 2) arrives at: 193.393
# Patient № 477 (Type 3) arrives at: 193.644
# Patient № 478 (Type 1) arrives at: 193.750
# Patient № 279 started treatment at 193.754; queue time was 84.477
# Patient № 280 started treatment at 193.777; queue time was 84.225
# Patient № 479 (Type 2) arrives at: 193.820
# Patient № 480 (Type 3) arrives at: 194.162
# Patient № 481 (Type 1) arrives at: 194.321
# Patient № 482 (Type 2) arrives at: 194.336
# Patient № 281 started treatment at 194.378; queue time was 84.801
# Patient № 483 (Type 3) arrives at: 194.728
# Patient № 282 started treatment at 195.066; queue time was 85.294
# Patient № 283 started treatment at 195.188; queue time was 85.249
# Patient № 284 started treatment at 195.703; queue time was 85.613
# Patient № 484 (Type 1) arrives at: 195.846
# Patient № 485 (Type 2) arrives at: 196.184
# Patient № 486 (Type 3) arrives at: 196.217
# Patient № 285 started treatment at 196.477; queue time was 85.489
# Patient № 487 (Type 1) arrives at: 197.036
# Patient № 488 (Type 2) arrives at: 197.089
# Patient № 286 started treatment at 197.910; queue time was 86.479
# Patient № 489 (Type 3) arrives at: 198.067
# Patient № 287 started treatment at 198.155; queue time was 86.600
# Patient № 288 started treatment at 198.302; queue time was 86.656
# Patient № 490 (Type 1) arrives at: 198.307
# Patient № 491 (Type 2) arrives at: 198.662
# Patient № 492 (Type 3) arrives at: 199.118
# Patient № 289 started treatment at 199.408; queue time was 87.508
# Patient № 493 (Type 1) arrives at: 199.487
# Patient № 494 (Type 2) arrives at: 199.535
# Patient № 495 (Type 3) arrives at: 199.659
# Patient № 496 (Type 1) arrives at: 200.284
# Patient № 497 (Type 2) arrives at: 200.305
# Patient № 498 (Type 3) arrives at: 200.366
# Patient № 290 started treatment at 200.741; queue time was 88.770
# Patient № 499 (Type 1) arrives at: 201.949
# Patient № 500 (Type 2) arrives at: 201.981
# Patient № 501 (Type 3) arrives at: 202.215
# Patient № 502 (Type 1) arrives at: 202.513
# Patient № 503 (Type 2) arrives at: 202.640
# Patient № 504 (Type 3) arrives at: 202.704
# Patient № 505 (Type 1) arrives at: 203.341
# Patient № 291 started treatment at 203.385; queue time was 90.561
# Patient № 506 (Type 2) arrives at: 203.766
# Patient № 507 (Type 3) arrives at: 203.957
# Patient № 508 (Type 1) arrives at: 204.253
# Patient № 509 (Type 2) arrives at: 204.346
# Patient № 510 (Type 3) arrives at: 204.880
# Patient № 292 started treatment at 204.975; queue time was 92.088
# Patient № 511 (Type 1) arrives at: 205.134
# Patient № 512 (Type 2) arrives at: 205.322
# Patient № 293 started treatment at 205.458; queue time was 92.533
# Patient № 294 started treatment at 205.479; queue time was 92.297
# Patient № 513 (Type 3) arrives at: 205.639
# Patient № 295 started treatment at 206.199; queue time was 92.597
# Patient № 296 started treatment at 206.612; queue time was 92.976
# Patient № 514 (Type 1) arrives at: 207.417
# Patient № 515 (Type 2) arrives at: 207.425
# Patient № 516 (Type 3) arrives at: 207.489
# Patient № 297 started treatment at 207.500; queue time was 93.359
# Patient № 517 (Type 1) arrives at: 207.952
# Patient № 518 (Type 2) arrives at: 208.054
# Patient № 519 (Type 3) arrives at: 208.162
# Patient № 298 started treatment at 208.652; queue time was 92.635
# Patient № 299 started treatment at 208.940; queue time was 92.852
# Patient № 520 (Type 1) arrives at: 209.278
# Patient № 521 (Type 2) arrives at: 209.556
# Patient № 522 (Type 3) arrives at: 209.693
# Patient № 523 (Type 1) arrives at: 209.945
# Patient № 524 (Type 2) arrives at: 209.948
# Patient № 525 (Type 3) arrives at: 210.293
# Patient № 526 (Type 1) arrives at: 210.448
# Patient № 527 (Type 2) arrives at: 210.450
# Patient № 300 started treatment at 210.983; queue time was 94.636
# Patient № 528 (Type 3) arrives at: 211.140
# Patient № 301 started treatment at 211.275; queue time was 94.088
# Patient № 302 started treatment at 211.308; queue time was 94.032
# Patient № 303 started treatment at 211.686; queue time was 94.060
# Patient № 529 (Type 1) arrives at: 212.092
# Patient № 530 (Type 2) arrives at: 212.122
# Patient № 531 (Type 3) arrives at: 212.257
# Patient № 304 started treatment at 212.289; queue time was 92.095
# Patient № 305 started treatment at 212.695; queue time was 92.489
# Patient № 306 started treatment at 213.034; queue time was 92.737
# Patient № 532 (Type 1) arrives at: 213.438
# Patient № 533 (Type 2) arrives at: 213.448
# Patient № 534 (Type 3) arrives at: 213.690
# Patient № 307 started treatment at 214.036; queue time was 92.033
# Patient № 308 started treatment at 214.227; queue time was 92.180
# Patient № 535 (Type 1) arrives at: 214.482
# Patient № 536 (Type 2) arrives at: 214.585
# Patient № 309 started treatment at 214.724; queue time was 92.476
# Patient № 537 (Type 3) arrives at: 214.873
# Patient № 310 started treatment at 214.885; queue time was 91.706
# Patient № 311 started treatment at 215.083; queue time was 91.882
# Patient № 538 (Type 1) arrives at: 215.862
# Patient № 312 started treatment at 215.912; queue time was 92.558
# Patient № 539 (Type 2) arrives at: 216.011
# Patient № 313 started treatment at 216.140; queue time was 91.244
# Patient № 540 (Type 3) arrives at: 216.339
# Patient № 314 started treatment at 216.511; queue time was 91.380
# Patient № 541 (Type 1) arrives at: 217.188
# Patient № 542 (Type 2) arrives at: 217.285
# Patient № 315 started treatment at 217.309; queue time was 92.062
# Patient № 543 (Type 3) arrives at: 217.413
# Patient № 316 started treatment at 218.020; queue time was 92.166
# Patient № 544 (Type 1) arrives at: 218.323
# Patient № 317 started treatment at 218.341; queue time was 92.463
# Patient № 545 (Type 2) arrives at: 218.372
# Patient № 546 (Type 3) arrives at: 218.531
# Patient № 318 started treatment at 218.838; queue time was 92.622
# Patient № 319 started treatment at 219.943; queue time was 92.837
# Patient № 320 started treatment at 220.332; queue time was 93.106
# Patient № 547 (Type 1) arrives at: 220.410
# Patient № 548 (Type 2) arrives at: 220.523
# Patient № 549 (Type 3) arrives at: 220.811
# Patient № 321 started treatment at 221.085; queue time was 93.771
# Patient № 322 started treatment at 221.538; queue time was 93.908
# Patient № 323 started treatment at 221.833; queue time was 94.126
# Patient № 324 started treatment at 221.903; queue time was 94.012
# Patient № 325 started treatment at 222.363; queue time was 94.290
# Patient № 326 started treatment at 222.760; queue time was 94.516
# Patient № 550 (Type 1) arrives at: 223.164
# Patient № 551 (Type 2) arrives at: 223.182
# Patient № 327 started treatment at 223.462; queue time was 94.982
# Patient № 328 started treatment at 223.965; queue time was 93.697
# Patient № 552 (Type 3) arrives at: 224.064
# Patient № 329 started treatment at 224.569; queue time was 94.282
# Patient № 553 (Type 1) arrives at: 224.616
# Patient № 330 started treatment at 224.645; queue time was 94.300
# Patient № 554 (Type 2) arrives at: 224.831
# Patient № 555 (Type 3) arrives at: 224.952
# Patient № 331 started treatment at 224.991; queue time was 94.529
# Patient № 556 (Type 1) arrives at: 225.028
# Patient № 557 (Type 2) arrives at: 225.288
# Patient № 558 (Type 3) arrives at: 225.381
# Patient № 559 (Type 1) arrives at: 226.550
# Patient № 560 (Type 2) arrives at: 226.607
# Patient № 561 (Type 3) arrives at: 226.664
# Patient № 332 started treatment at 226.823; queue time was 96.352
# Patient № 333 started treatment at 226.896; queue time was 96.291
# Patient № 562 (Type 1) arrives at: 227.369
# Patient № 563 (Type 2) arrives at: 227.492
# Patient № 564 (Type 3) arrives at: 228.297
# Patient № 334 started treatment at 228.750; queue time was 97.988
# Patient № 335 started treatment at 229.226; queue time was 98.107
# Patient № 336 started treatment at 229.252; queue time was 97.682
# Patient № 337 started treatment at 229.297; queue time was 97.469
# Patient № 338 started treatment at 229.885; queue time was 98.038
# Patient № 339 started treatment at 230.058; queue time was 98.146
# Patient № 565 (Type 1) arrives at: 230.331
# Patient № 566 (Type 2) arrives at: 230.369
# Patient № 567 (Type 3) arrives at: 230.444
# Patient № 568 (Type 1) arrives at: 231.314
# Patient № 340 started treatment at 231.339; queue time was 98.621
# Patient № 569 (Type 2) arrives at: 231.347
# Patient № 570 (Type 3) arrives at: 231.484
# Patient № 341 started treatment at 231.504; queue time was 98.762
# Patient № 571 (Type 1) arrives at: 231.601
# Patient № 572 (Type 2) arrives at: 231.698
# Patient № 573 (Type 3) arrives at: 232.436
# Patient № 342 started treatment at 232.960; queue time was 99.875
# Patient № 574 (Type 1) arrives at: 233.311
# Patient № 575 (Type 2) arrives at: 233.515
# Patient № 576 (Type 3) arrives at: 233.603
# Patient № 577 (Type 1) arrives at: 234.080
# Patient № 578 (Type 2) arrives at: 234.220
# Patient № 343 started treatment at 234.233; queue time was 100.803
# Patient № 579 (Type 3) arrives at: 234.380
# Patient № 580 (Type 1) arrives at: 234.476
# Patient № 581 (Type 2) arrives at: 234.622
# Patient № 582 (Type 3) arrives at: 234.713
# Patient № 583 (Type 1) arrives at: 234.941
# Patient № 584 (Type 2) arrives at: 234.961
# Patient № 585 (Type 3) arrives at: 235.168
# Patient № 344 started treatment at 236.806; queue time was 102.756
# Patient № 345 started treatment at 237.009; queue time was 102.905
# Patient № 346 started treatment at 237.785; queue time was 103.111
# Patient № 586 (Type 1) arrives at: 238.065
# Patient № 587 (Type 2) arrives at: 238.099
# Patient № 347 started treatment at 238.152; queue time was 103.375
# Patient № 588 (Type 3) arrives at: 238.372
# Patient № 589 (Type 1) arrives at: 238.707
# Patient № 590 (Type 2) arrives at: 238.939
# Patient № 591 (Type 3) arrives at: 239.052
# Patient № 348 started treatment at 239.098; queue time was 104.310
# Patient № 592 (Type 1) arrives at: 239.267
# Patient № 593 (Type 2) arrives at: 239.335
# Patient № 594 (Type 3) arrives at: 239.374
# Patient № 349 started treatment at 239.490; queue time was 102.902
# Patient № 595 (Type 1) arrives at: 239.744
# Patient № 596 (Type 2) arrives at: 239.891
# ...
# Patient № 724 (Type 1) arrives at: 292.476
# Patient № 725 (Type 2) arrives at: 292.571
# Patient № 726 (Type 3) arrives at: 292.582
# Patient № 424 started treatment at 293.079; queue time was 122.808
# Patient № 425 started treatment at 293.161; queue time was 122.785
# Patient № 426 started treatment at 294.306; queue time was 123.845
# Patient № 427 started treatment at 294.533; queue time was 122.727
# Patient № 727 (Type 1) arrives at: 294.644
# Patient № 728 (Type 2) arrives at: 294.723
# Patient № 729 (Type 3) arrives at: 294.725
# Patient № 428 started treatment at 295.114; queue time was 123.117
# Patient № 730 (Type 1) arrives at: 295.412
# Patient № 731 (Type 2) arrives at: 295.528
# Patient № 732 (Type 3) arrives at: 295.561
# Patient № 429 started treatment at 295.708; queue time was 123.618
# Patient № 430 started treatment at 295.841; queue time was 123.365
# Patient № 733 (Type 1) arrives at: 297.316
# Patient № 734 (Type 2) arrives at: 297.886
# Patient № 735 (Type 3) arrives at: 297.974
# Patient № 431 started treatment at 298.115; queue time was 125.612
# Patient № 432 started treatment at 298.265; queue time was 124.653
# Patient № 736 (Type 1) arrives at: 298.816
# Patient № 737 (Type 2) arrives at: 298.834
# Patient № 433 started treatment at 299.667; queue time was 125.406
# Patient № 434 started treatment at 300.179; queue time was 125.870
# Patient № 738 (Type 3) arrives at: 300.192
# Patient № 739 (Type 1) arrives at: 300.610
# Patient № 740 (Type 2) arrives at: 300.636
# Patient № 741 (Type 3) arrives at: 300.901
# Patient № 435 started treatment at 301.061; queue time was 126.589
# Patient № 742 (Type 1) arrives at: 301.104
# Patient № 743 (Type 2) arrives at: 301.121
# Patient № 744 (Type 3) arrives at: 301.386
# Patient № 436 started treatment at 302.413; queue time was 127.500
# Patient № 745 (Type 1) arrives at: 302.534
# Patient № 746 (Type 2) arrives at: 302.557
# Patient № 437 started treatment at 302.737; queue time was 127.705
# Patient № 747 (Type 3) arrives at: 302.755
# Patient № 438 started treatment at 302.871; queue time was 127.836
# Patient № 748 (Type 1) arrives at: 304.539
# Patient № 749 (Type 2) arrives at: 304.545
# Patient № 750 (Type 3) arrives at: 304.579
# Patient № 439 started treatment at 304.860; queue time was 129.197
# Patient № 440 started treatment at 306.521; queue time was 130.709
# Patient № 751 (Type 1) arrives at: 306.804
# Patient № 441 started treatment at 306.817; queue time was 130.965
# Patient № 752 (Type 2) arrives at: 307.247
# Patient № 753 (Type 3) arrives at: 307.344
# Patient № 442 started treatment at 307.458; queue time was 131.213
# Patient № 443 started treatment at 307.563; queue time was 131.230
# Patient № 754 (Type 1) arrives at: 307.596
# Patient № 755 (Type 2) arrives at: 307.672
# Patient № 444 started treatment at 307.724; queue time was 131.061
# Patient № 756 (Type 3) arrives at: 307.780
# Patient № 757 (Type 1) arrives at: 308.635
# Patient № 758 (Type 2) arrives at: 308.780
# Patient № 759 (Type 3) arrives at: 308.926
# Patient № 760 (Type 1) arrives at: 309.354
# Patient № 761 (Type 2) arrives at: 309.454
# Patient № 762 (Type 3) arrives at: 309.514
# Patient № 445 started treatment at 309.702; queue time was 132.528
# Patient № 446 started treatment at 309.765; queue time was 132.574
# Patient № 447 started treatment at 310.174; queue time was 132.756
# Patient № 763 (Type 1) arrives at: 310.941
# Patient № 448 started treatment at 310.943; queue time was 133.501
# Patient № 764 (Type 2) arrives at: 310.946
# Patient № 449 started treatment at 311.202; queue time was 133.695
# Patient № 450 started treatment at 311.261; queue time was 133.042
# Patient № 765 (Type 3) arrives at: 311.440
# Patient № 766 (Type 1) arrives at: 311.624
# Patient № 767 (Type 2) arrives at: 311.658
# Patient № 768 (Type 3) arrives at: 311.661
# Patient № 451 started treatment at 311.663; queue time was 132.121
# Patient № 452 started treatment at 311.700; queue time was 131.865
# Patient № 769 (Type 1) arrives at: 311.710
# Patient № 770 (Type 2) arrives at: 311.713
# Patient № 453 started treatment at 311.747; queue time was 131.877
# Patient № 771 (Type 3) arrives at: 311.863
# Patient № 772 (Type 1) arrives at: 312.164
# Patient № 773 (Type 2) arrives at: 312.166
# Patient № 774 (Type 3) arrives at: 312.316
# Patient № 775 (Type 1) arrives at: 312.375
# Patient № 776 (Type 2) arrives at: 312.375
# Patient № 777 (Type 3) arrives at: 312.614
# Patient № 778 (Type 1) arrives at: 313.007
# Patient № 779 (Type 2) arrives at: 313.348
# Patient № 780 (Type 3) arrives at: 313.356
# Patient № 781 (Type 1) arrives at: 313.762
# Patient № 454 started treatment at 313.867; queue time was 131.905
# Patient № 782 (Type 2) arrives at: 313.939
# Patient № 455 started treatment at 314.047; queue time was 131.913
# Patient № 783 (Type 3) arrives at: 314.484
# Patient № 784 (Type 1) arrives at: 314.578
# Patient № 785 (Type 2) arrives at: 314.696
# Patient № 786 (Type 3) arrives at: 314.700
# Patient № 456 started treatment at 315.348; queue time was 133.184
# Patient № 457 started treatment at 315.804; queue time was 133.155
# Patient № 458 started treatment at 316.482; queue time was 133.794
# Patient № 787 (Type 1) arrives at: 317.272
# Patient № 788 (Type 2) arrives at: 317.376
# Patient № 459 started treatment at 317.399; queue time was 134.678
# Patient № 789 (Type 3) arrives at: 317.899
# Patient № 790 (Type 1) arrives at: 318.151
# Patient № 791 (Type 2) arrives at: 318.408
# Patient № 792 (Type 3) arrives at: 318.451
# Patient № 460 started treatment at 318.920; queue time was 133.362
# Patient № 461 started treatment at 319.378; queue time was 133.814
# Patient № 793 (Type 1) arrives at: 319.448
# Patient № 794 (Type 2) arrives at: 319.557
# Patient № 795 (Type 3) arrives at: 319.702
# Patient № 796 (Type 1) arrives at: 319.869
# Patient № 797 (Type 2) arrives at: 320.199
# Patient № 462 started treatment at 320.309; queue time was 133.676
# Patient № 463 started treatment at 320.491; queue time was 133.718
# Patient № 798 (Type 3) arrives at: 320.517
# Patient № 464 started treatment at 320.781; queue time was 133.865
# Patient № 799 (Type 1) arrives at: 320.941
# Patient № 800 (Type 2) arrives at: 321.020
# Patient № 465 started treatment at 321.126; queue time was 134.111
# Patient № 801 (Type 3) arrives at: 321.338
# Patient № 466 started treatment at 321.389; queue time was 132.053
# Patient № 467 started treatment at 321.394; queue time was 131.926
# Patient № 802 (Type 1) arrives at: 321.413
# Patient № 803 (Type 2) arrives at: 321.421
# Patient № 804 (Type 3) arrives at: 321.545
# Patient № 805 (Type 1) arrives at: 321.643
# Patient № 806 (Type 2) arrives at: 321.705
# Patient № 468 started treatment at 321.893; queue time was 132.338
# Patient № 807 (Type 3) arrives at: 322.539
# Patient № 808 (Type 1) arrives at: 322.549
# Patient № 809 (Type 2) arrives at: 322.613
# Patient № 810 (Type 3) arrives at: 322.682
# Patient № 469 started treatment at 322.997; queue time was 133.138
# Patient № 470 started treatment at 323.538; queue time was 133.522
# Patient № 471 started treatment at 323.842; queue time was 133.754
# Patient № 472 started treatment at 323.852; queue time was 133.207
# Patient № 811 (Type 1) arrives at: 324.028
# Patient № 812 (Type 2) arrives at: 324.051
# Patient № 813 (Type 3) arrives at: 324.211
# Patient № 814 (Type 1) arrives at: 324.507
# Patient № 815 (Type 2) arrives at: 324.654
# Patient № 816 (Type 3) arrives at: 324.712
# Patient № 473 started treatment at 325.200; queue time was 134.335
# Patient № 474 started treatment at 325.260; queue time was 133.953
# Patient № 817 (Type 1) arrives at: 325.289
# Patient № 818 (Type 2) arrives at: 325.305
# Patient № 819 (Type 3) arrives at: 325.479
# Patient № 820 (Type 1) arrives at: 326.203
# Patient № 821 (Type 2) arrives at: 326.291
# Patient № 822 (Type 3) arrives at: 326.479
# Patient № 823 (Type 1) arrives at: 326.629
# Patient № 475 started treatment at 326.705; queue time was 133.367
# Patient № 824 (Type 2) arrives at: 326.729
# Patient № 825 (Type 3) arrives at: 326.973
# Patient № 476 started treatment at 327.405; queue time was 134.012
# Patient № 477 started treatment at 327.957; queue time was 134.313
# Patient № 478 started treatment at 328.088; queue time was 134.338
# Patient № 479 started treatment at 328.405; queue time was 134.585
# Patient № 826 (Type 1) arrives at: 329.417
# Patient № 827 (Type 2) arrives at: 329.438
# Patient № 828 (Type 3) arrives at: 329.937
# Patient № 480 started treatment at 330.222; queue time was 136.060
# Patient № 829 (Type 1) arrives at: 330.393
# Patient № 830 (Type 2) arrives at: 330.423
# Patient № 831 (Type 3) arrives at: 330.791
# Patient № 832 (Type 1) arrives at: 330.854
# Patient № 481 started treatment at 331.000; queue time was 136.679
# Patient № 833 (Type 2) arrives at: 331.077
# Patient № 834 (Type 3) arrives at: 331.080
# Patient № 835 (Type 1) arrives at: 331.170
# Patient № 482 started treatment at 331.262; queue time was 136.925
# Patient № 483 started treatment at 331.350; queue time was 136.622
# Patient № 836 (Type 2) arrives at: 331.691
# Patient № 837 (Type 3) arrives at: 331.738
# Patient № 838 (Type 1) arrives at: 332.152
# Patient № 839 (Type 2) arrives at: 332.202
# Patient № 840 (Type 3) arrives at: 332.981
# Patient № 841 (Type 1) arrives at: 333.087
# Patient № 842 (Type 2) arrives at: 333.136
# Patient № 843 (Type 3) arrives at: 333.166
# Patient № 844 (Type 1) arrives at: 333.438
# Patient № 845 (Type 2) arrives at: 333.509
# Patient № 484 started treatment at 333.558; queue time was 137.712
# Patient № 485 started treatment at 333.817; queue time was 137.633
# Patient № 846 (Type 3) arrives at: 334.170
# Patient № 486 started treatment at 334.572; queue time was 138.355
# Patient № 847 (Type 1) arrives at: 334.789
# Patient № 848 (Type 2) arrives at: 334.801
# Patient № 849 (Type 3) arrives at: 334.823
# Patient № 850 (Type 1) arrives at: 334.858
# Patient № 851 (Type 2) arrives at: 334.970
# Patient № 852 (Type 3) arrives at: 334.987
# Patient № 487 started treatment at 335.065; queue time was 138.030
# Patient № 488 started treatment at 335.144; queue time was 138.055
# Patient № 853 (Type 1) arrives at: 335.286
# Patient № 854 (Type 2) arrives at: 335.337
# Patient № 855 (Type 3) arrives at: 335.344
# Patient № 489 started treatment at 335.610; queue time was 137.542
# Patient № 490 started treatment at 336.624; queue time was 138.317
# Patient № 856 (Type 1) arrives at: 336.652
# Patient № 857 (Type 2) arrives at: 336.685
# Patient № 858 (Type 3) arrives at: 337.796
# Patient № 859 (Type 1) arrives at: 337.858
# Patient № 860 (Type 2) arrives at: 338.074
# Patient № 861 (Type 3) arrives at: 338.404
# Patient № 862 (Type 1) arrives at: 339.213
# Patient № 863 (Type 2) arrives at: 339.287
# Patient № 864 (Type 3) arrives at: 339.360
# Patient № 865 (Type 1) arrives at: 339.402
# Patient № 866 (Type 2) arrives at: 339.443
# Patient № 867 (Type 3) arrives at: 339.486
# Patient № 491 started treatment at 339.714; queue time was 141.053
# Patient № 492 started treatment at 339.859; queue time was 140.741
# Patient № 493 started treatment at 340.148; queue time was 140.661
# Patient № 494 started treatment at 341.389; queue time was 141.853
# Patient № 495 started treatment at 341.614; queue time was 141.955
# Patient № 868 (Type 1) arrives at: 341.718
# Patient № 869 (Type 2) arrives at: 341.803
# Patient № 496 started treatment at 342.277; queue time was 141.994
# Patient № 870 (Type 3) arrives at: 342.292
# Patient № 871 (Type 1) arrives at: 342.504
# Patient № 872 (Type 2) arrives at: 342.566
# Patient № 873 (Type 3) arrives at: 342.737
# Patient № 874 (Type 1) arrives at: 342.941
# Patient № 875 (Type 2) arrives at: 343.167
# Patient № 876 (Type 3) arrives at: 343.517
# Patient № 497 started treatment at 344.062; queue time was 143.757
# Patient № 877 (Type 1) arrives at: 344.426
# Patient № 498 started treatment at 344.499; queue time was 144.133
# Patient № 878 (Type 2) arrives at: 344.692
# Patient № 879 (Type 3) arrives at: 344.848
# Patient № 499 started treatment at 345.176; queue time was 143.227
# Patient № 500 started treatment at 345.338; queue time was 143.356
# Patient № 501 started treatment at 346.445; queue time was 144.230
# Patient № 880 (Type 1) arrives at: 346.731
# Patient № 881 (Type 2) arrives at: 346.759
# Patient № 882 (Type 3) arrives at: 346.859
# Patient № 502 started treatment at 347.043; queue time was 144.530
# Patient № 503 started treatment at 347.831; queue time was 145.191
# Patient № 504 started treatment at 348.602; queue time was 145.899
# Patient № 505 started treatment at 348.711; queue time was 145.370
# Patient № 883 (Type 1) arrives at: 349.516
# Patient № 884 (Type 2) arrives at: 349.537
# Patient № 885 (Type 3) arrives at: 349.636
# Patient № 506 started treatment at 349.681; queue time was 145.914
# Patient № 507 started treatment at 349.739; queue time was 145.782
# Patient № 508 started treatment at 350.314; queue time was 146.062
# Patient № 886 (Type 1) arrives at: 350.788
# Patient № 887 (Type 2) arrives at: 351.072
# Patient № 888 (Type 3) arrives at: 351.077
# Patient № 509 started treatment at 352.242; queue time was 147.896
# Patient № 510 started treatment at 352.284; queue time was 147.404
# Patient № 511 started treatment at 352.332; queue time was 147.198
# Patient № 889 (Type 1) arrives at: 352.517
# Patient № 890 (Type 2) arrives at: 352.769
# Patient № 512 started treatment at 352.780; queue time was 147.458
# Patient № 891 (Type 3) arrives at: 352.960
# Patient № 513 started treatment at 353.419; queue time was 147.780
# Patient № 892 (Type 1) arrives at: 353.874
# Patient № 893 (Type 2) arrives at: 353.927
# Patient № 514 started treatment at 354.074; queue time was 146.656
# Patient № 894 (Type 3) arrives at: 354.326
# Patient № 895 (Type 1) arrives at: 354.486
# Patient № 896 (Type 2) arrives at: 354.489
# Patient № 897 (Type 3) arrives at: 354.910
# Patient № 898 (Type 1) arrives at: 355.881
# Patient № 899 (Type 2) arrives at: 355.896
# Patient № 515 started treatment at 356.062; queue time was 148.637
# Patient № 900 (Type 3) arrives at: 356.167
# Patient № 901 (Type 1) arrives at: 356.306
# Patient № 902 (Type 2) arrives at: 356.384
# Patient № 903 (Type 3) arrives at: 356.417
# Patient № 904 (Type 1) arrives at: 357.241
# Patient № 905 (Type 2) arrives at: 357.280
# Patient № 906 (Type 3) arrives at: 357.516
# Patient № 516 started treatment at 357.660; queue time was 150.171
# Patient № 907 (Type 1) arrives at: 358.155
# Patient № 908 (Type 2) arrives at: 358.248
# Patient № 517 started treatment at 358.713; queue time was 150.761
# Patient № 909 (Type 3) arrives at: 359.109
# Patient № 910 (Type 1) arrives at: 359.407
# Patient № 911 (Type 2) arrives at: 359.554
# Patient № 912 (Type 3) arrives at: 359.578
# Patient № 518 started treatment at 359.624; queue time was 151.570
# Patient № 519 started treatment at 359.792; queue time was 151.629
# Patient № 913 (Type 1) arrives at: 360.170
# Patient № 914 (Type 2) arrives at: 360.387
# Patient № 520 started treatment at 360.639; queue time was 151.360
# Patient № 915 (Type 3) arrives at: 360.679
# Patient № 521 started treatment at 361.425; queue time was 151.868
# Patient № 916 (Type 1) arrives at: 361.430
# Patient № 917 (Type 2) arrives at: 361.433
# Patient № 918 (Type 3) arrives at: 362.256
# Patient № 522 started treatment at 362.404; queue time was 152.711
# Patient № 919 (Type 1) arrives at: 362.449
# Patient № 920 (Type 2) arrives at: 362.619
# Patient № 921 (Type 3) arrives at: 362.648
# Patient № 523 started treatment at 362.879; queue time was 152.935
# Patient № 922 (Type 1) arrives at: 362.996
# Patient № 923 (Type 2) arrives at: 363.112
# Patient № 924 (Type 3) arrives at: 363.120
# Patient № 925 (Type 1) arrives at: 363.472
# Patient № 926 (Type 2) arrives at: 363.583
# Patient № 524 started treatment at 363.737; queue time was 153.789
# Patient № 927 (Type 3) arrives at: 363.789
# Patient № 928 (Type 1) arrives at: 363.882
# Patient № 929 (Type 2) arrives at: 364.043
# Patient № 525 started treatment at 364.430; queue time was 154.137
# Patient № 930 (Type 3) arrives at: 364.476
# Patient № 931 (Type 1) arrives at: 364.717
# Patient № 932 (Type 2) arrives at: 364.738
# Patient № 933 (Type 3) arrives at: 364.845
# end of run. simulation clock time = 365
#
# Single run results
# ------------------
# Mean Queue Time: 43.30
