# %% [markdown]
# # Imports
#
# Please use the provided `hds_stoch` environment for this work.

# %%
import simpy
simpy.__version__
# Out:
# '4.0.1'

# %%
import numpy as np
import pandas as pd
import itertools
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Distribution classes
#
# To help you build your model, the notebook includes some pre-written distribution classes that you may wish to use to setup sampling.  You are free to use these, but you can choose not too if you have an approach you prefer.

# %%
class Exponential:
    '''
    Convenience class for the exponential distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, mean, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        mean: float
            The mean of the exponential distribution
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.mean = mean
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.exponential(self.mean, size=size)

class Lognormal:
    """
    Encapsulates a lognormal distirbution
    """
    def __init__(self, mean, stdev, random_seed=None):
        """
        Params:
        -------
        mean = mean of the lognormal distribution
        stdev = standard dev of the lognormal distribution
        """
        self.rand = np.random.default_rng(seed=random_seed)
        mu, sigma = self.normal_moments_from_lognormal(mean, stdev**2)
        self.mu = mu
        self.sigma = sigma
        
    def normal_moments_from_lognormal(self, m, v):
        '''
        Returns mu and sigma of normal distribution
        underlying a lognormal with mean m and variance v
        source: https://blogs.sas.com/content/iml/2014/06/04/simulate-lognormal
        -data-with-specified-mean-and-variance.html

        Params:
        -------
        m = mean of lognormal distribution
        v = variance of lognormal distribution
                
        Returns:
        -------
        (float, float)
        '''
        phi = math.sqrt(v + m**2)
        mu = math.log(m**2/phi)
        sigma = math.sqrt(math.log(phi**2/m**2))
        return mu, sigma
        
    def sample(self):
        """
        Sample from the normal distribution
        """
        return self.rand.lognormal(self.mu, self.sigma)

# %% [markdown]
# # Utility functions

# %%
def trace(msg):
    '''
    Utility function for printing simulation
    set the TRACE constant to FALSE to 
    turn tracing off.
    
    Params:
    -------
    msg: str
        string to print to screen.
    '''
    if TRACE:
        print(msg)

# %% [markdown]
# # Model parameters
#
# The constants below provides hard coded data representing the base case or 'as-is' state of the minor injury unit.

# %%
# These are the parameters for a base case model run.
# Note if you change these parameters then your model will run a new 'scenario' 

# resource counts
N_BEDS = 6

# time between arrivals in minutes (exponential)
# for acute stroke, TIA and neuro respectively
MEAN_IATs = [1.2, 9.5, 3.5]

# treatment (lognormal)
TREAT_MEAN = 3.7
TREAT_STD = 4.4

# SEEDS to reproduce results of a single run
REPRODUCIBLE_RUN = True
    
if REPRODUCIBLE_RUN:
    SEEDS = [42, 101, 1066, 1966, 2013, 999, 1444, 2016]
else:
    SEEDS = [None, None, None, None, None, None, None, None]

# %% [markdown]
# # Scenario class
# In the cell below the parameters you will find a `Scenario` class.  This makes use of the default parameters to set up the base case scenario.  Remember that its good practice to pass all of your parameters to your simulation model in a **container**.  A class is a flexible way to achieve this aim.

# %%
class Scenario:
    '''
    Parameter container class for minor injury unit model.
    '''
    def __init__(self, name=None):
        '''
        The init method sets up our defaults. 
        
        Params:
        -------
        
        name - str or None
            optional name for scenario
        '''
        # optional name
        self.name = name
        
        # number of beds
        self.beds = N_BEDS
        
        # inter-arrival distributions
        self.arrival_dist_type1 = Exponential(MEAN_IATs[0], random_seed=SEEDS[0]) 
        self.arrival_dist_type2 = Exponential(MEAN_IATs[1], random_seed=SEEDS[1])
        self.arrival_dist_type3 = Exponential(MEAN_IATs[2], random_seed=SEEDS[2])
        
        
        # treatment distribution
        self.treatment_dist = Lognormal(TREAT_MEAN, TREAT_STD, 
                                         random_seed=SEEDS[3])

# %% [markdown]
# # Model building

# %%
class Patient:
    '''
    Patient in the minor ED process
    '''
    def __init__(self, identifier, env, args):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env

        # treatment parameters
        self.beds = args.beds
        self.treatment_dist = args.treatment_dist
                
        # individual patient metrics
        self.queue_time = 0.0
        
    
    def treatment(self):
        '''
        simulates the process for minor emergencies
        
        1. request and wait for triage
        2. request and wait for a minor cubicle
        3. minor assessment
        4. exit system.
        
        '''
        # record the time that patient entered the system
        arrival_time = self.env.now
        
            
        
        # get bed
        with self.beds.request() as req:
            yield req
            
            # record time to first being seen by a doctor
            self.queue_time = self.env.now - arrival_time
            
            
            trace(f'Patient № {self.identifier} started treatment at {self.env.now:.3f};'
                      + f' queue time was {self.queue_time:.3f}')
            
            
            # sample for patient pathway
            treat_time = self.sample_all()
            
            activity_duration = treat_time
          
            # treatment delay
            yield self.env.timeout(activity_duration)
            
                        
    def sample_all(self):
        '''
        Sample assessment time, if the patient requires diagnostics,
        if the diags are done in parallel to assessment and 
        '''

        # sample assessment time
        treat_time = self.treatment_dist.sample()

        return (treat_time)

# %%
class ASU:  
    '''
    Model of an ASU
    '''
    def __init__(self, env, args):
        '''
        Contructor
        
        Params:
        -------
        env: simpy.Environment
        
        args: Scenario
            container class for simulation model inputs.
        '''
        self.env = env
        self.args = args 
        self.init_model_resources(args)
        self.patients = []
        self.patient_count = 0
        
        
    def init_model_resources(self, args):
        '''
        Setup the simpy resource objects
        
        Params:
        ------
        args - Scenario
            Simulation Parameter Container
        '''

        args.beds = simpy.Resource(self.env, 
                                   capacity=args.beds)
        
            
    def arrivals_generator_type1(self):
            
        while True:
            
            
                # PATIENT WITH ACUTE STROKE ARRIVES (TYPE 1)
                inter_arrival_time = self.args.arrival_dist_type1.sample()
                
                self.patient_count += 1
            
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)                

                # init the minor injury process for this patient
                self.env.process(new_patient.treatment())                
            
                trace(f'Patient № {self.patient_count} (Stroke) arrives at: {self.env.now:.3f}')
            
                
                yield self.env.timeout(inter_arrival_time)
                
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)                
                
                
    def arrivals_generator_type2(self):
            
        while True:
            
                            
                # PATIENT WITH TRANSITORY ISCHEMIC ATTACK ARRIVES (TYPE 2)
                inter_arrival_time = self.args.arrival_dist_type2.sample()
                
                self.patient_count += 1
            
                
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)
            
                # init the minor injury process for this patient
                self.env.process(new_patient.treatment())

                
                trace(f'Patient № {self.patient_count} (TIA) arrives at: {self.env.now:.3f}')
                
                
                yield self.env.timeout(inter_arrival_time)
                
                
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)                
                
    def arrivals_generator_type3(self):
            
        while True:
            
                
                # PATIENT WITH COMPLEX NEUROLOGICAL DIAGNOSIS ARRIVES (TYPE 3)
                inter_arrival_time = self.args.arrival_dist_type3.sample()
                
                self.patient_count += 1
            
            
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)
            
                # init the minor injury process for this patient
                self.env.process(new_patient.treatment())
            
                trace(f'Patient № {self.patient_count} (Neuro) arrives at: {self.env.now:.3f}')
                
                yield self.env.timeout(inter_arrival_time)
                
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)

# %% [markdown]
# # Script to run the model

# %%
# run length in days
RUN_LENGTH = 365

# Turn off tracing
TRACE = True #False 

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()

# create the model
model = ASU(env, default_args)

# setup the processes
env.process(model.arrivals_generator_type1())
env.process(model.arrivals_generator_type2())
env.process(model.arrivals_generator_type3())



env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')






# Calculate and printout Performance metrics


# mean time to treatment
mean_queue = np.array([patient.queue_time 
                               for patient in model.patients]).mean()


print('\nSingle run results\n------------------')
print(f'Mean Queue Time: {mean_queue:.2f} days!')


###################################################################
# Out:
# Patient № 1 (Stroke) arrives at: 0.000
# Patient № 2 (TIA) arrives at: 0.000
# Patient № 3 (Neuro) arrives at: 0.000
# Patient № 1 started treatment at 0.000; queue time was 0.000
# Patient № 2 started treatment at 0.000; queue time was 0.000
# Patient № 3 started treatment at 0.000; queue time was 0.000
# Patient № 4 (Stroke) arrives at: 2.885
# Patient № 4 started treatment at 2.885; queue time was 0.000
# Patient № 5 (Stroke) arrives at: 5.688
# Patient № 5 started treatment at 5.688; queue time was 0.000
# Patient № 6 (Neuro) arrives at: 7.542
# Patient № 6 started treatment at 7.542; queue time was 0.000
# Patient № 7 (Stroke) arrives at: 8.550
# Patient № 7 started treatment at 8.550; queue time was 0.000
# Patient № 8 (Stroke) arrives at: 8.886
# Patient № 8 started treatment at 8.886; queue time was 0.000
# Patient № 9 (Stroke) arrives at: 8.990
# Patient № 9 started treatment at 8.990; queue time was 0.000
# Patient № 10 (Stroke) arrives at: 10.733
# Patient № 10 started treatment at 10.733; queue time was 0.000
# Patient № 11 (Neuro) arrives at: 11.624
# Patient № 11 started treatment at 11.624; queue time was 0.000
# Patient № 12 (Neuro) arrives at: 11.946
# Patient № 12 started treatment at 11.946; queue time was 0.000
# Patient № 13 (Stroke) arrives at: 12.425
# Patient № 13 started treatment at 12.425; queue time was 0.000
# Patient № 14 (Neuro) arrives at: 14.284
# Patient № 14 started treatment at 14.284; queue time was 0.000
# Patient № 15 (Neuro) arrives at: 15.230
# Patient № 15 started treatment at 15.230; queue time was 0.000
# Patient № 16 (Stroke) arrives at: 16.174
# Patient № 16 started treatment at 16.174; queue time was 0.000
# Patient № 17 (Stroke) arrives at: 16.269
# Patient № 17 started treatment at 16.269; queue time was 0.000
# Patient № 18 (Stroke) arrives at: 17.525
# Patient № 18 started treatment at 17.525; queue time was 0.000
# Patient № 19 (Stroke) arrives at: 17.610
# Patient № 19 started treatment at 17.610; queue time was 0.000
# Patient № 20 (Stroke) arrives at: 18.916
# Patient № 20 started treatment at 18.916; queue time was 0.000
# Patient № 21 (Neuro) arrives at: 19.337
# Patient № 21 started treatment at 19.337; queue time was 0.000
# Patient № 22 (Neuro) arrives at: 20.461
# Patient № 22 started treatment at 20.461; queue time was 0.000
# Patient № 23 (Stroke) arrives at: 20.994
# Patient № 23 started treatment at 20.994; queue time was 0.000
# Patient № 24 (Stroke) arrives at: 21.458
# Patient № 24 started treatment at 21.458; queue time was 0.000
# Patient № 25 (Stroke) arrives at: 22.936
# Patient № 25 started treatment at 22.936; queue time was 0.000
# Patient № 26 (Stroke) arrives at: 23.121
# Patient № 26 started treatment at 23.121; queue time was 0.000
# Patient № 27 (Stroke) arrives at: 23.231
# Patient № 27 started treatment at 23.231; queue time was 0.000
# Patient № 28 (Stroke) arrives at: 23.609
# Patient № 28 started treatment at 23.609; queue time was 0.000
# Patient № 29 (Neuro) arrives at: 24.356
# Patient № 29 started treatment at 24.356; queue time was 0.000
# Patient № 30 (Stroke) arrives at: 24.690
# Patient № 30 started treatment at 24.690; queue time was 0.000
# Patient № 31 (Neuro) arrives at: 25.018
# Patient № 31 started treatment at 25.018; queue time was 0.000
# Patient № 32 (Stroke) arrives at: 25.186
# Patient № 32 started treatment at 25.186; queue time was 0.000
# Patient № 33 (Stroke) arrives at: 26.683
# Patient № 33 started treatment at 26.683; queue time was 0.000
# Patient № 34 (Stroke) arrives at: 26.951
# Patient № 34 started treatment at 26.951; queue time was 0.000
# Patient № 35 (Neuro) arrives at: 27.653
# Patient № 35 started treatment at 27.653; queue time was 0.000
# Patient № 36 (Stroke) arrives at: 29.156
# Patient № 36 started treatment at 29.156; queue time was 0.000
# Patient № 37 (Stroke) arrives at: 30.629
# Patient № 37 started treatment at 30.629; queue time was 0.000
# Patient № 38 (Stroke) arrives at: 31.416
# Patient № 38 started treatment at 31.416; queue time was 0.000
# Patient № 39 (Stroke) arrives at: 31.916
# Patient № 39 started treatment at 32.300; queue time was 0.384
# Patient № 40 (Stroke) arrives at: 32.460
# Patient № 41 (Stroke) arrives at: 32.553
# Patient № 42 (Stroke) arrives at: 32.768
# Patient № 43 (Stroke) arrives at: 33.591
# Patient № 40 started treatment at 33.972; queue time was 1.512
# Patient № 44 (Stroke) arrives at: 34.057
# Patient № 41 started treatment at 35.151; queue time was 2.598
# Patient № 45 (Stroke) arrives at: 35.574
# Patient № 46 (Neuro) arrives at: 35.665
# Patient № 42 started treatment at 35.665; queue time was 2.897
# Patient № 47 (Stroke) arrives at: 36.425
# Patient № 48 (Stroke) arrives at: 36.710
# Patient № 43 started treatment at 37.134; queue time was 3.543
# Patient № 49 (Stroke) arrives at: 37.263
# Patient № 44 started treatment at 37.729; queue time was 3.672
# Patient № 50 (Stroke) arrives at: 38.033
# Patient № 51 (Stroke) arrives at: 38.446
# Patient № 52 (Stroke) arrives at: 38.832
# Patient № 53 (TIA) arrives at: 38.852
# Patient № 45 started treatment at 38.941; queue time was 3.366
# Patient № 46 started treatment at 38.949; queue time was 3.284
# Patient № 54 (Neuro) arrives at: 39.755
# Patient № 47 started treatment at 39.768; queue time was 3.344
# Patient № 48 started treatment at 39.855; queue time was 3.145
# Patient № 55 (Stroke) arrives at: 39.887
# Patient № 49 started treatment at 40.047; queue time was 2.784
# Patient № 50 started treatment at 40.171; queue time was 2.137
# Patient № 56 (Stroke) arrives at: 40.243
# Patient № 57 (Neuro) arrives at: 40.859
# Patient № 51 started treatment at 41.065; queue time was 2.619
# Patient № 52 started treatment at 41.493; queue time was 2.661
# Patient № 53 started treatment at 41.553; queue time was 2.701
# Patient № 58 (Stroke) arrives at: 41.844
# Patient № 54 started treatment at 41.946; queue time was 2.191
# Patient № 55 started treatment at 42.169; queue time was 2.282
# Patient № 59 (Stroke) arrives at: 43.513
# Patient № 56 started treatment at 43.907; queue time was 3.664
# Patient № 60 (Neuro) arrives at: 44.073
# Patient № 57 started treatment at 44.262; queue time was 3.403
# Patient № 61 (TIA) arrives at: 44.344
# Patient № 58 started treatment at 44.685; queue time was 2.842
# Patient № 62 (Stroke) arrives at: 44.814
# Patient № 63 (Stroke) arrives at: 44.901
# Patient № 59 started treatment at 45.559; queue time was 2.046
# Patient № 64 (Stroke) arrives at: 46.262
# Patient № 65 (Neuro) arrives at: 46.324
# Patient № 66 (Stroke) arrives at: 47.887
# Patient № 60 started treatment at 48.259; queue time was 4.186
# Patient № 61 started treatment at 48.887; queue time was 4.543
# Patient № 67 (Stroke) arrives at: 49.234
# Patient № 62 started treatment at 49.375; queue time was 4.561
# Patient № 68 (Stroke) arrives at: 49.570
# Patient № 63 started treatment at 49.651; queue time was 4.750
# Patient № 69 (Stroke) arrives at: 49.955
# Patient № 70 (Stroke) arrives at: 50.154
# Patient № 71 (Stroke) arrives at: 50.579
# Patient № 72 (Stroke) arrives at: 50.604
# Patient № 64 started treatment at 50.611; queue time was 4.349
# Patient № 65 started treatment at 50.749; queue time was 4.425
# Patient № 73 (Stroke) arrives at: 50.805
# Patient № 66 started treatment at 51.113; queue time was 3.226
# Patient № 67 started treatment at 51.482; queue time was 2.248
# Patient № 68 started treatment at 51.720; queue time was 2.151
# Patient № 74 (Stroke) arrives at: 52.383
# Patient № 69 started treatment at 52.594; queue time was 2.639
# Patient № 70 started treatment at 53.018; queue time was 2.865
# Patient № 71 started treatment at 53.388; queue time was 2.809
# Patient № 75 (TIA) arrives at: 53.430
# Patient № 72 started treatment at 53.589; queue time was 2.984
# Patient № 73 started treatment at 53.629; queue time was 2.824
# Patient № 74 started treatment at 53.653; queue time was 1.269
# Patient № 76 (Neuro) arrives at: 54.077
# Patient № 75 started treatment at 55.313; queue time was 1.884
# Patient № 76 started treatment at 56.434; queue time was 2.357
# Patient № 77 (Stroke) arrives at: 57.178
# Patient № 77 started treatment at 57.178; queue time was 0.000
# Patient № 78 (Stroke) arrives at: 57.854
# Patient № 78 started treatment at 57.854; queue time was 0.000
# Patient № 79 (Stroke) arrives at: 58.195
# Patient № 79 started treatment at 58.195; queue time was 0.000
# Patient № 80 (Stroke) arrives at: 58.673
# Patient № 80 started treatment at 58.673; queue time was 0.000
# Patient № 81 (Stroke) arrives at: 59.106
# Patient № 81 started treatment at 59.106; queue time was 0.000
# Patient № 82 (Stroke) arrives at: 59.262
# Patient № 83 (Stroke) arrives at: 60.562
# Patient № 82 started treatment at 60.618; queue time was 1.356
# Patient № 83 started treatment at 60.873; queue time was 0.312
# Patient № 84 (Stroke) arrives at: 62.213
# Patient № 85 (TIA) arrives at: 63.241
# Patient № 84 started treatment at 63.622; queue time was 1.409
# Patient № 85 started treatment at 63.731; queue time was 0.490
# Patient № 86 (Stroke) arrives at: 64.022
# Patient № 86 started treatment at 64.022; queue time was 0.000
# Patient № 87 (TIA) arrives at: 69.321
# Patient № 87 started treatment at 69.321; queue time was 0.000
# Patient № 88 (Neuro) arrives at: 69.482
# Patient № 88 started treatment at 69.482; queue time was 0.000
# Patient № 89 (Stroke) arrives at: 70.394
# Patient № 89 started treatment at 70.394; queue time was 0.000
# Patient № 90 (Neuro) arrives at: 71.487
# Patient № 90 started treatment at 71.487; queue time was 0.000
# Patient № 91 (Stroke) arrives at: 72.922
# Patient № 91 started treatment at 72.922; queue time was 0.000
# Patient № 92 (TIA) arrives at: 72.939
# Patient № 92 started treatment at 72.939; queue time was 0.000
# Patient № 93 (Stroke) arrives at: 74.896
# Patient № 93 started treatment at 74.896; queue time was 0.000
# Patient № 94 (Stroke) arrives at: 76.148
# Patient № 94 started treatment at 76.148; queue time was 0.000
# Patient № 95 (Stroke) arrives at: 76.859
# Patient № 95 started treatment at 76.859; queue time was 0.000
# Patient № 96 (Stroke) arrives at: 76.912
# Patient № 96 started treatment at 76.912; queue time was 0.000
# Patient № 97 (Stroke) arrives at: 78.060
# Patient № 97 started treatment at 78.060; queue time was 0.000
# Patient № 98 (Stroke) arrives at: 78.806
# Patient № 98 started treatment at 78.806; queue time was 0.000
# Patient № 99 (Stroke) arrives at: 80.616
# Patient № 99 started treatment at 80.616; queue time was 0.000
# Patient № 100 (Neuro) arrives at: 80.871
# Patient № 100 started treatment at 80.871; queue time was 0.000
# Patient № 101 (Stroke) arrives at: 83.049
# Patient № 101 started treatment at 83.049; queue time was 0.000
# Patient № 102 (Stroke) arrives at: 83.448
# Patient № 102 started treatment at 83.448; queue time was 0.000
# Patient № 103 (Stroke) arrives at: 83.507
# Patient № 103 started treatment at 83.507; queue time was 0.000
# Patient № 104 (Stroke) arrives at: 84.617
# Patient № 104 started treatment at 84.617; queue time was 0.000
# Patient № 105 (Stroke) arrives at: 87.681
# Patient № 105 started treatment at 87.681; queue time was 0.000
# Patient № 106 (Neuro) arrives at: 87.816
# Patient № 106 started treatment at 87.816; queue time was 0.000
# Patient № 107 (Neuro) arrives at: 88.254
# Patient № 107 started treatment at 88.254; queue time was 0.000
# Patient № 108 (Stroke) arrives at: 88.666
# Patient № 108 started treatment at 88.666; queue time was 0.000
# Patient № 109 (Stroke) arrives at: 91.224
# Patient № 109 started treatment at 91.224; queue time was 0.000
# Patient № 110 (Stroke) arrives at: 92.127
# Patient № 110 started treatment at 92.127; queue time was 0.000
# Patient № 111 (Stroke) arrives at: 93.704
# Patient № 111 started treatment at 93.704; queue time was 0.000
# Patient № 112 (Stroke) arrives at: 94.051
# Patient № 112 started treatment at 94.051; queue time was 0.000
# Patient № 113 (Stroke) arrives at: 94.212
# Patient № 114 (Stroke) arrives at: 94.383
# Patient № 115 (Stroke) arrives at: 94.524
# Patient № 116 (Stroke) arrives at: 94.590
# Patient № 113 started treatment at 94.622; queue time was 0.411
# Patient № 117 (Neuro) arrives at: 95.362
# Patient № 114 started treatment at 95.682; queue time was 1.299
# Patient № 118 (Neuro) arrives at: 96.228
# Patient № 115 started treatment at 96.482; queue time was 1.958
# Patient № 119 (Stroke) arrives at: 96.650
# Patient № 120 (Stroke) arrives at: 97.188
# Patient № 116 started treatment at 97.303; queue time was 2.713
# Patient № 121 (Stroke) arrives at: 97.651
# Patient № 122 (Neuro) arrives at: 97.718
# Patient № 123 (Stroke) arrives at: 98.773
# Patient № 124 (TIA) arrives at: 98.830
# Patient № 117 started treatment at 98.831; queue time was 3.469
# Patient № 125 (Stroke) arrives at: 98.998
# Patient № 126 (Neuro) arrives at: 99.981
# Patient № 127 (Stroke) arrives at: 101.300
# Patient № 118 started treatment at 101.436; queue time was 5.209
# Patient № 119 started treatment at 101.618; queue time was 4.969
# Patient № 128 (Neuro) arrives at: 102.301
# Patient № 129 (Stroke) arrives at: 102.850
# Patient № 120 started treatment at 103.069; queue time was 5.881
# Patient № 130 (Stroke) arrives at: 103.245
# Patient № 131 (Neuro) arrives at: 103.299
# Patient № 121 started treatment at 103.306; queue time was 5.655
# Patient № 132 (Stroke) arrives at: 103.486
# Patient № 133 (Stroke) arrives at: 104.123
# Patient № 134 (Stroke) arrives at: 104.489
# Patient № 135 (Stroke) arrives at: 104.580
# Patient № 122 started treatment at 104.600; queue time was 6.882
# Patient № 136 (TIA) arrives at: 104.754
# Patient № 137 (Stroke) arrives at: 105.184
# Patient № 123 started treatment at 105.611; queue time was 6.837
# Patient № 138 (Neuro) arrives at: 107.763
# Patient № 139 (Stroke) arrives at: 107.886
# Patient № 124 started treatment at 108.008; queue time was 9.178
# Patient № 140 (Neuro) arrives at: 108.598
# Patient № 141 (Stroke) arrives at: 109.097
# Patient № 125 started treatment at 109.138; queue time was 10.140
# Patient № 126 started treatment at 109.582; queue time was 9.602
# Patient № 127 started treatment at 110.145; queue time was 8.845
# Patient № 128 started treatment at 110.639; queue time was 8.338
# Patient № 142 (Neuro) arrives at: 111.055
# Patient № 129 started treatment at 111.057; queue time was 8.206
# Patient № 130 started treatment at 111.712; queue time was 8.467
# Patient № 131 started treatment at 112.064; queue time was 8.765
# Patient № 132 started treatment at 112.069; queue time was 8.583
# Patient № 143 (Stroke) arrives at: 112.796
# Patient № 133 started treatment at 113.027; queue time was 8.904
# Patient № 134 started treatment at 114.099; queue time was 9.610
# Patient № 135 started treatment at 114.319; queue time was 9.739
# Patient № 144 (Neuro) arrives at: 114.639
# Patient № 136 started treatment at 114.872; queue time was 10.117
# Patient № 145 (Stroke) arrives at: 115.252
# Patient № 137 started treatment at 116.585; queue time was 11.401
# Patient № 146 (Stroke) arrives at: 116.593
# Patient № 138 started treatment at 116.671; queue time was 8.907
# Patient № 147 (Neuro) arrives at: 117.789
# Patient № 139 started treatment at 118.042; queue time was 10.156
# Patient № 140 started treatment at 118.253; queue time was 9.655
# Patient № 141 started treatment at 118.556; queue time was 9.459
# Patient № 142 started treatment at 118.770; queue time was 7.715
# Patient № 148 (Stroke) arrives at: 118.814
# Patient № 143 started treatment at 118.825; queue time was 6.029
# Patient № 144 started treatment at 119.028; queue time was 4.389
# Patient № 149 (Stroke) arrives at: 119.686
# Patient № 145 started treatment at 120.095; queue time was 4.843
# Patient № 146 started treatment at 120.124; queue time was 3.531
# Patient № 147 started treatment at 120.550; queue time was 2.761
# Patient № 148 started treatment at 120.621; queue time was 1.807
# Patient № 150 (Stroke) arrives at: 120.968
# Patient № 149 started treatment at 120.972; queue time was 1.286
# Patient № 151 (Stroke) arrives at: 121.424
# Patient № 152 (Stroke) arrives at: 121.687
# Patient № 150 started treatment at 121.759; queue time was 0.792
# Patient № 151 started treatment at 121.972; queue time was 0.548
# Patient № 152 started treatment at 122.286; queue time was 0.599
# Patient № 153 (Neuro) arrives at: 123.028
# Patient № 153 started treatment at 123.028; queue time was 0.000
# Patient № 154 (Stroke) arrives at: 124.261
# Patient № 154 started treatment at 124.261; queue time was 0.000
# Patient № 155 (Stroke) arrives at: 124.429
# Patient № 155 started treatment at 124.429; queue time was 0.000
# Patient № 156 (Stroke) arrives at: 124.654
# Patient № 156 started treatment at 124.654; queue time was 0.000
# Patient № 157 (Stroke) arrives at: 125.027
# Patient № 157 started treatment at 125.027; queue time was 0.000
# Patient № 158 (Stroke) arrives at: 126.188
# Patient № 158 started treatment at 126.188; queue time was 0.000
# Patient № 159 (Stroke) arrives at: 126.684
# Patient № 159 started treatment at 126.684; queue time was 0.000
# Patient № 160 (Neuro) arrives at: 127.367
# Patient № 160 started treatment at 127.367; queue time was 0.000
# Patient № 161 (Stroke) arrives at: 127.506
# Patient № 161 started treatment at 127.506; queue time was 0.000
# Patient № 162 (Neuro) arrives at: 128.381
# Patient № 162 started treatment at 128.381; queue time was 0.000
# Patient № 163 (Stroke) arrives at: 130.098
# Patient № 163 started treatment at 130.098; queue time was 0.000
# Patient № 164 (Neuro) arrives at: 131.685
# Patient № 164 started treatment at 131.685; queue time was 0.000
# Patient № 165 (Stroke) arrives at: 131.948
# Patient № 165 started treatment at 131.948; queue time was 0.000
# Patient № 166 (Neuro) arrives at: 132.491
# Patient № 166 started treatment at 132.491; queue time was 0.000
# Patient № 167 (Neuro) arrives at: 133.003
# Patient № 167 started treatment at 133.003; queue time was 0.000
# Patient № 168 (Neuro) arrives at: 133.032
# Patient № 168 started treatment at 133.032; queue time was 0.000
# Patient № 169 (Stroke) arrives at: 133.353
# Patient № 169 started treatment at 133.353; queue time was 0.000
# Patient № 170 (Stroke) arrives at: 133.558
# Patient № 170 started treatment at 133.558; queue time was 0.000
# Patient № 171 (Stroke) arrives at: 134.986
# Patient № 171 started treatment at 134.986; queue time was 0.000
# Patient № 172 (Stroke) arrives at: 135.531
# Patient № 173 (Stroke) arrives at: 135.679
# Patient № 174 (Stroke) arrives at: 136.159
# Patient № 175 (Stroke) arrives at: 136.243
# Patient № 172 started treatment at 136.860; queue time was 1.329
# Patient № 176 (Stroke) arrives at: 137.341
# Patient № 173 started treatment at 137.368; queue time was 1.689
# Patient № 174 started treatment at 137.818; queue time was 1.659
# Patient № 177 (Stroke) arrives at: 138.507
# Patient № 178 (Stroke) arrives at: 138.861
# Patient № 179 (Stroke) arrives at: 138.916
# Patient № 175 started treatment at 139.342; queue time was 3.098
# Patient № 176 started treatment at 139.448; queue time was 2.107
# Patient № 177 started treatment at 139.572; queue time was 1.064
# Patient № 178 started treatment at 139.892; queue time was 1.031
# Patient № 179 started treatment at 140.585; queue time was 1.669
# Patient № 180 (Neuro) arrives at: 141.000
# Patient № 180 started treatment at 141.758; queue time was 0.758
# Patient № 181 (Stroke) arrives at: 142.191
# Patient № 181 started treatment at 142.191; queue time was 0.000
# Patient № 182 (Stroke) arrives at: 143.160
# Patient № 182 started treatment at 143.230; queue time was 0.070
# Patient № 183 (TIA) arrives at: 143.431
# Patient № 183 started treatment at 143.431; queue time was 0.000
# Patient № 184 (Stroke) arrives at: 144.946
# Patient № 184 started treatment at 144.946; queue time was 0.000
# Patient № 185 (Neuro) arrives at: 145.179
# Patient № 185 started treatment at 145.179; queue time was 0.000
# Patient № 186 (Stroke) arrives at: 145.369
# Patient № 186 started treatment at 145.369; queue time was 0.000
# Patient № 187 (Neuro) arrives at: 146.212
# Patient № 187 started treatment at 146.212; queue time was 0.000
# Patient № 188 (Stroke) arrives at: 147.381
# Patient № 188 started treatment at 147.381; queue time was 0.000
# Patient № 189 (Neuro) arrives at: 147.434
# Patient № 189 started treatment at 147.573; queue time was 0.139
# Patient № 190 (Stroke) arrives at: 149.350
# Patient № 190 started treatment at 149.350; queue time was 0.000
# Patient № 191 (Stroke) arrives at: 149.462
# Patient № 191 started treatment at 149.462; queue time was 0.000
# Patient № 192 (Neuro) arrives at: 150.390
# Patient № 192 started treatment at 150.486; queue time was 0.096
# Patient № 193 (TIA) arrives at: 151.313
# Patient № 193 started treatment at 151.722; queue time was 0.409
# Patient № 194 (Neuro) arrives at: 152.505
# Patient № 194 started treatment at 152.532; queue time was 0.026
# Patient № 195 (TIA) arrives at: 155.228
# Patient № 195 started treatment at 155.228; queue time was 0.000
# Patient № 196 (TIA) arrives at: 155.647
# Patient № 197 (Stroke) arrives at: 155.980
# Patient № 196 started treatment at 156.317; queue time was 0.670
# Patient № 198 (Stroke) arrives at: 156.788
# Patient № 197 started treatment at 157.411; queue time was 1.431
# Patient № 199 (Stroke) arrives at: 158.466
# Patient № 198 started treatment at 158.602; queue time was 1.813
# Patient № 200 (Stroke) arrives at: 158.758
# Patient № 199 started treatment at 158.913; queue time was 0.447
# Patient № 201 (Stroke) arrives at: 159.939
# Patient № 200 started treatment at 160.162; queue time was 1.404
# Patient № 202 (Stroke) arrives at: 160.282
# Patient № 201 started treatment at 160.507; queue time was 0.568
# Patient № 202 started treatment at 161.825; queue time was 1.543
# Patient № 203 (Stroke) arrives at: 162.219
# Patient № 203 started treatment at 162.219; queue time was 0.000
# Patient № 204 (Stroke) arrives at: 162.775
# Patient № 204 started treatment at 162.775; queue time was 0.000
# Patient № 205 (Stroke) arrives at: 163.710
# Patient № 205 started treatment at 163.710; queue time was 0.000
# Patient № 206 (Stroke) arrives at: 164.343
# Patient № 206 started treatment at 164.343; queue time was 0.000
# Patient № 207 (Neuro) arrives at: 164.583
# Patient № 207 started treatment at 164.583; queue time was 0.000
# Patient № 208 (Stroke) arrives at: 165.247
# Patient № 209 (Stroke) arrives at: 165.814
# Patient № 210 (Neuro) arrives at: 165.956
# Patient № 211 (Neuro) arrives at: 166.010
# Patient № 212 (Neuro) arrives at: 166.019
# Patient № 208 started treatment at 166.031; queue time was 0.783
# Patient № 209 started treatment at 166.146; queue time was 0.332
# Patient № 213 (Stroke) arrives at: 166.550
# Patient № 214 (Stroke) arrives at: 166.584
# Patient № 215 (Neuro) arrives at: 167.104
# Patient № 210 started treatment at 167.236; queue time was 1.280
# Patient № 211 started treatment at 167.326; queue time was 1.316
# Patient № 212 started treatment at 168.114; queue time was 2.095
# Patient № 216 (Stroke) arrives at: 168.489
# Patient № 213 started treatment at 168.892; queue time was 2.342
# Patient № 214 started treatment at 171.479; queue time was 4.895
# Patient № 217 (Stroke) arrives at: 171.501
# Patient № 215 started treatment at 171.820; queue time was 4.716
# Patient № 218 (Stroke) arrives at: 172.198
# Patient № 216 started treatment at 172.290; queue time was 3.800
# Patient № 217 started treatment at 173.168; queue time was 1.667
# Patient № 218 started treatment at 173.393; queue time was 1.195
# Patient № 219 (Stroke) arrives at: 176.283
# Patient № 219 started treatment at 176.283; queue time was 0.000
# Patient № 220 (Stroke) arrives at: 176.485
# Patient № 220 started treatment at 176.485; queue time was 0.000
# Patient № 221 (Neuro) arrives at: 178.828
# Patient № 221 started treatment at 178.828; queue time was 0.000
# Patient № 222 (Stroke) arrives at: 179.826
# Patient № 222 started treatment at 179.826; queue time was 0.000
# Patient № 223 (Stroke) arrives at: 180.263
# Patient № 223 started treatment at 180.263; queue time was 0.000
# Patient № 224 (Stroke) arrives at: 181.066
# Patient № 224 started treatment at 181.066; queue time was 0.000
# Patient № 225 (Stroke) arrives at: 183.990
# Patient № 225 started treatment at 183.990; queue time was 0.000
# Patient № 226 (Stroke) arrives at: 184.143
# Patient № 226 started treatment at 184.143; queue time was 0.000
# Patient № 227 (Stroke) arrives at: 184.372
# Patient № 227 started treatment at 184.372; queue time was 0.000
# Patient № 228 (Neuro) arrives at: 185.784
# Patient № 228 started treatment at 185.784; queue time was 0.000
# Patient № 229 (Stroke) arrives at: 185.983
# Patient № 229 started treatment at 185.983; queue time was 0.000
# Patient № 230 (Neuro) arrives at: 186.643
# Patient № 230 started treatment at 186.643; queue time was 0.000
# Patient № 231 (Stroke) arrives at: 187.162
# Patient № 232 (Stroke) arrives at: 187.507
# Patient № 231 started treatment at 187.646; queue time was 0.485
# Patient № 232 started treatment at 187.911; queue time was 0.404
# Patient № 233 (Stroke) arrives at: 188.039
# Patient № 234 (Neuro) arrives at: 188.757
# Patient № 235 (Stroke) arrives at: 188.939
# Patient № 233 started treatment at 189.046; queue time was 1.007
# Patient № 234 started treatment at 189.090; queue time was 0.333
# Patient № 235 started treatment at 190.527; queue time was 1.588
# Patient № 236 (Stroke) arrives at: 191.219
# Patient № 237 (Neuro) arrives at: 191.453
# Patient № 238 (Stroke) arrives at: 191.649
# Patient № 239 (Stroke) arrives at: 192.567
# Patient № 236 started treatment at 192.718; queue time was 1.499
# Patient № 240 (Stroke) arrives at: 192.992
# Patient № 241 (Stroke) arrives at: 193.357
# Patient № 242 (Neuro) arrives at: 193.492
# Patient № 237 started treatment at 193.656; queue time was 2.203
# Patient № 238 started treatment at 193.724; queue time was 2.075
# Patient № 243 (Neuro) arrives at: 193.733
# Patient № 239 started treatment at 194.312; queue time was 1.745
# Patient № 240 started treatment at 194.755; queue time was 1.764
# Patient № 244 (Stroke) arrives at: 195.917
# Patient № 241 started treatment at 195.932; queue time was 2.575
# Patient № 245 (Stroke) arrives at: 196.585
# Patient № 242 started treatment at 197.356; queue time was 3.864
# Patient № 243 started treatment at 198.002; queue time was 4.269
# Patient № 246 (Stroke) arrives at: 198.192
# Patient № 244 started treatment at 198.213; queue time was 2.296
# Patient № 247 (Stroke) arrives at: 198.556
# Patient № 245 started treatment at 198.693; queue time was 2.108
# Patient № 248 (Neuro) arrives at: 198.710
# Patient № 249 (Stroke) arrives at: 198.779
# Patient № 246 started treatment at 198.860; queue time was 0.668
# Patient № 247 started treatment at 200.020; queue time was 1.464
# Patient № 250 (Stroke) arrives at: 200.150
# Patient № 248 started treatment at 200.241; queue time was 1.531
# Patient № 249 started treatment at 200.628; queue time was 1.849
# Patient № 250 started treatment at 200.816; queue time was 0.666
# Patient № 251 (Stroke) arrives at: 201.851
# Patient № 251 started treatment at 201.851; queue time was 0.000
# Patient № 252 (Stroke) arrives at: 202.992
# Patient № 252 started treatment at 202.992; queue time was 0.000
# Patient № 253 (Stroke) arrives at: 204.417
# Patient № 253 started treatment at 204.417; queue time was 0.000
# Patient № 254 (Neuro) arrives at: 205.563
# Patient № 254 started treatment at 205.563; queue time was 0.000
# Patient № 255 (Stroke) arrives at: 205.639
# Patient № 255 started treatment at 205.639; queue time was 0.000
# Patient № 256 (Stroke) arrives at: 206.950
# Patient № 256 started treatment at 206.950; queue time was 0.000
# Patient № 257 (Neuro) arrives at: 209.490
# Patient № 257 started treatment at 209.490; queue time was 0.000
# Patient № 258 (Stroke) arrives at: 209.655
# Patient № 258 started treatment at 209.655; queue time was 0.000
# Patient № 259 (Neuro) arrives at: 209.666
# Patient № 259 started treatment at 209.666; queue time was 0.000
# Patient № 260 (Neuro) arrives at: 210.911
# Patient № 260 started treatment at 210.911; queue time was 0.000
# Patient № 261 (Stroke) arrives at: 213.043
# Patient № 261 started treatment at 213.043; queue time was 0.000
# Patient № 262 (Neuro) arrives at: 213.081
# Patient № 262 started treatment at 213.081; queue time was 0.000
# Patient № 263 (Stroke) arrives at: 213.838
# Patient № 264 (Stroke) arrives at: 213.947
# Patient № 265 (TIA) arrives at: 214.650
# Patient № 263 started treatment at 214.942; queue time was 1.104
# Patient № 264 started treatment at 215.123; queue time was 1.176
# Patient № 266 (Stroke) arrives at: 215.632
# Patient № 265 started treatment at 216.388; queue time was 1.738
# Patient № 267 (Stroke) arrives at: 216.647
# Patient № 266 started treatment at 216.648; queue time was 1.017
# Patient № 267 started treatment at 216.748; queue time was 0.101
# Patient № 268 (Stroke) arrives at: 219.576
# Patient № 268 started treatment at 219.576; queue time was 0.000
# Patient № 269 (Stroke) arrives at: 220.829
# Patient № 269 started treatment at 220.829; queue time was 0.000
# Patient № 270 (Stroke) arrives at: 220.997
# Patient № 270 started treatment at 220.997; queue time was 0.000
# Patient № 271 (Neuro) arrives at: 221.185
# Patient № 271 started treatment at 221.185; queue time was 0.000
# Patient № 272 (Neuro) arrives at: 221.717
# Patient № 272 started treatment at 221.717; queue time was 0.000
# Patient № 273 (Stroke) arrives at: 222.256
# Patient № 273 started treatment at 222.256; queue time was 0.000
# Patient № 274 (Neuro) arrives at: 222.277
# Patient № 274 started treatment at 222.903; queue time was 0.626
# Patient № 275 (Stroke) arrives at: 222.943
# Patient № 276 (Stroke) arrives at: 223.081
# Patient № 277 (Stroke) arrives at: 223.410
# Patient № 275 started treatment at 224.174; queue time was 1.231
# Patient № 276 started treatment at 224.182; queue time was 1.101
# Patient № 277 started treatment at 224.498; queue time was 1.088
# Patient № 278 (Neuro) arrives at: 227.012
# Patient № 278 started treatment at 227.012; queue time was 0.000
# Patient № 279 (Stroke) arrives at: 227.581
# Patient № 279 started treatment at 227.581; queue time was 0.000
# Patient № 280 (Stroke) arrives at: 228.065
# Patient № 280 started treatment at 228.065; queue time was 0.000
# Patient № 281 (Stroke) arrives at: 228.375
# Patient № 281 started treatment at 228.375; queue time was 0.000
# Patient № 282 (Stroke) arrives at: 228.907
# Patient № 282 started treatment at 228.907; queue time was 0.000
# Patient № 283 (Neuro) arrives at: 230.442
# Patient № 283 started treatment at 230.442; queue time was 0.000
# Patient № 284 (Stroke) arrives at: 231.388
# Patient № 284 started treatment at 231.388; queue time was 0.000
# Patient № 285 (Stroke) arrives at: 232.695
# Patient № 285 started treatment at 232.695; queue time was 0.000
# Patient № 286 (Stroke) arrives at: 232.932
# Patient № 286 started treatment at 232.932; queue time was 0.000
# Patient № 287 (Stroke) arrives at: 232.942
# Patient № 287 started treatment at 233.163; queue time was 0.222
# Patient № 288 (Neuro) arrives at: 233.300
# Patient № 289 (Stroke) arrives at: 233.468
# Patient № 290 (Stroke) arrives at: 233.648
# Patient № 288 started treatment at 234.372; queue time was 1.072
# Patient № 289 started treatment at 235.479; queue time was 2.011
# Patient № 291 (Stroke) arrives at: 236.129
# Patient № 292 (Stroke) arrives at: 236.257
# Patient № 290 started treatment at 236.811; queue time was 3.163
# Patient № 293 (Stroke) arrives at: 237.078
# Patient № 294 (Neuro) arrives at: 237.604
# Patient № 295 (Neuro) arrives at: 238.248
# Patient № 296 (Stroke) arrives at: 238.299
# Patient № 291 started treatment at 238.407; queue time was 2.278
# Patient № 292 started treatment at 239.746; queue time was 3.489
# Patient № 293 started treatment at 239.997; queue time was 2.919
# Patient № 297 (Neuro) arrives at: 240.344
# Patient № 294 started treatment at 240.488; queue time was 2.884
# Patient № 295 started treatment at 241.151; queue time was 2.903
# Patient № 296 started treatment at 241.208; queue time was 2.909
# Patient № 298 (Stroke) arrives at: 241.743
# Patient № 299 (Neuro) arrives at: 241.870
# Patient № 300 (Stroke) arrives at: 242.092
# Patient № 297 started treatment at 242.451; queue time was 2.107
# Patient № 301 (Neuro) arrives at: 243.480
# Patient № 302 (Stroke) arrives at: 244.175
# Patient № 298 started treatment at 244.625; queue time was 2.882
# Patient № 299 started treatment at 244.723; queue time was 2.853
# Patient № 303 (Stroke) arrives at: 245.091
# Patient № 300 started treatment at 245.935; queue time was 3.843
# Patient № 301 started treatment at 246.079; queue time was 2.599
# Patient № 304 (Neuro) arrives at: 246.766
# Patient № 305 (Neuro) arrives at: 246.997
# Patient № 306 (Stroke) arrives at: 247.167
# Patient № 302 started treatment at 247.248; queue time was 3.074
# Patient № 303 started treatment at 247.292; queue time was 2.200
# Patient № 307 (Stroke) arrives at: 247.597
# Patient № 304 started treatment at 247.627; queue time was 0.861
# Patient № 305 started treatment at 247.894; queue time was 0.898
# Patient № 308 (Stroke) arrives at: 247.996
# Patient № 309 (Stroke) arrives at: 248.300
# Patient № 306 started treatment at 248.371; queue time was 1.204
# Patient № 310 (Neuro) arrives at: 249.157
# Patient № 307 started treatment at 249.178; queue time was 1.581
# Patient № 311 (Neuro) arrives at: 249.229
# Patient № 312 (Neuro) arrives at: 249.265
# Patient № 308 started treatment at 249.373; queue time was 1.377
# Patient № 313 (Stroke) arrives at: 249.552
# Patient № 309 started treatment at 249.689; queue time was 1.390
# Patient № 310 started treatment at 249.753; queue time was 0.596
# Patient № 311 started treatment at 249.870; queue time was 0.641
# Patient № 314 (Stroke) arrives at: 250.332
# Patient № 312 started treatment at 250.866; queue time was 1.601
# Patient № 313 started treatment at 251.283; queue time was 1.730
# Patient № 315 (Stroke) arrives at: 251.371
# Patient № 314 started treatment at 251.654; queue time was 1.322
# Patient № 315 started treatment at 252.452; queue time was 1.081
# Patient № 316 (TIA) arrives at: 252.475
# Patient № 317 (Neuro) arrives at: 252.752
# Patient № 318 (Stroke) arrives at: 252.911
# Patient № 316 started treatment at 252.985; queue time was 0.510
# Patient № 319 (Neuro) arrives at: 253.483
# Patient № 317 started treatment at 253.540; queue time was 0.788
# Patient № 318 started treatment at 254.037; queue time was 1.127
# Patient № 320 (Stroke) arrives at: 254.295
# Patient № 319 started treatment at 254.897; queue time was 1.414
# Patient № 321 (TIA) arrives at: 254.899
# Patient № 320 started treatment at 255.119; queue time was 0.823
# Patient № 322 (Stroke) arrives at: 255.550
# Patient № 321 started treatment at 255.952; queue time was 1.053
# Patient № 322 started treatment at 256.325; queue time was 0.775
# Patient № 323 (Stroke) arrives at: 257.228
# Patient № 323 started treatment at 257.228; queue time was 0.000
# Patient № 324 (Stroke) arrives at: 257.270
# Patient № 324 started treatment at 257.270; queue time was 0.000
# Patient № 325 (Stroke) arrives at: 259.076
# Patient № 325 started treatment at 259.076; queue time was 0.000
# Patient № 326 (Stroke) arrives at: 260.636
# Patient № 326 started treatment at 260.636; queue time was 0.000
# Patient № 327 (Stroke) arrives at: 261.162
# Patient № 327 started treatment at 261.162; queue time was 0.000
# Patient № 328 (Neuro) arrives at: 261.387
# Patient № 328 started treatment at 261.387; queue time was 0.000
# Patient № 329 (Stroke) arrives at: 261.450
# Patient № 329 started treatment at 261.450; queue time was 0.000
# Patient № 330 (Stroke) arrives at: 262.303
# Patient № 330 started treatment at 262.303; queue time was 0.000
# Patient № 331 (Stroke) arrives at: 264.734
# Patient № 331 started treatment at 264.734; queue time was 0.000
# Patient № 332 (Stroke) arrives at: 265.125
# Patient № 332 started treatment at 265.125; queue time was 0.000
# Patient № 333 (TIA) arrives at: 265.974
# Patient № 333 started treatment at 266.179; queue time was 0.205
# Patient № 334 (Stroke) arrives at: 266.845
# Patient № 334 started treatment at 266.845; queue time was 0.000
# Patient № 335 (Stroke) arrives at: 270.408
# Patient № 335 started treatment at 270.408; queue time was 0.000
# Patient № 336 (Stroke) arrives at: 270.886
# Patient № 336 started treatment at 270.886; queue time was 0.000
# Patient № 337 (Neuro) arrives at: 273.803
# Patient № 337 started treatment at 273.803; queue time was 0.000
# Patient № 338 (Neuro) arrives at: 273.965
# Patient № 338 started treatment at 273.965; queue time was 0.000
# Patient № 339 (Stroke) arrives at: 276.050
# Patient № 339 started treatment at 276.050; queue time was 0.000
# Patient № 340 (Stroke) arrives at: 276.122
# Patient № 340 started treatment at 276.122; queue time was 0.000
# Patient № 341 (Stroke) arrives at: 276.167
# Patient № 341 started treatment at 277.435; queue time was 1.268
# Patient № 342 (Stroke) arrives at: 278.395
# Patient № 342 started treatment at 278.395; queue time was 0.000
# Patient № 343 (Stroke) arrives at: 279.170
# Patient № 343 started treatment at 279.170; queue time was 0.000
# Patient № 344 (Stroke) arrives at: 279.897
# Patient № 344 started treatment at 279.897; queue time was 0.000
# Patient № 345 (Neuro) arrives at: 280.322
# Patient № 346 (TIA) arrives at: 280.692
# Patient № 347 (Neuro) arrives at: 280.902
# Patient № 345 started treatment at 281.124; queue time was 0.803
# Patient № 346 started treatment at 281.340; queue time was 0.648
# Patient № 347 started treatment at 281.515; queue time was 0.613
# Patient № 348 (Stroke) arrives at: 282.248
# Patient № 348 started treatment at 282.248; queue time was 0.000
# Patient № 349 (Neuro) arrives at: 282.513
# Patient № 349 started treatment at 282.513; queue time was 0.000
# Patient № 350 (Stroke) arrives at: 285.218
# Patient № 350 started treatment at 285.218; queue time was 0.000
# Patient № 351 (Stroke) arrives at: 286.207
# Patient № 351 started treatment at 286.207; queue time was 0.000
# Patient № 352 (Neuro) arrives at: 287.529
# Patient № 352 started treatment at 287.529; queue time was 0.000
# Patient № 353 (Stroke) arrives at: 288.735
# Patient № 353 started treatment at 288.735; queue time was 0.000
# Patient № 354 (Stroke) arrives at: 289.948
# Patient № 354 started treatment at 289.948; queue time was 0.000
# Patient № 355 (Stroke) arrives at: 290.549
# Patient № 355 started treatment at 290.549; queue time was 0.000
# Patient № 356 (Stroke) arrives at: 290.841
# Patient № 356 started treatment at 290.841; queue time was 0.000
# Patient № 357 (Stroke) arrives at: 292.494
# Patient № 357 started treatment at 292.494; queue time was 0.000
# Patient № 358 (Stroke) arrives at: 295.063
# Patient № 358 started treatment at 295.063; queue time was 0.000
# Patient № 359 (TIA) arrives at: 295.463
# Patient № 359 started treatment at 295.463; queue time was 0.000
# Patient № 360 (Stroke) arrives at: 298.266
# Patient № 360 started treatment at 298.266; queue time was 0.000
# Patient № 361 (Stroke) arrives at: 298.629
# Patient № 361 started treatment at 298.629; queue time was 0.000
# Patient № 362 (Stroke) arrives at: 299.860
# Patient № 362 started treatment at 299.860; queue time was 0.000
# Patient № 363 (Stroke) arrives at: 300.476
# Patient № 363 started treatment at 300.476; queue time was 0.000
# Patient № 364 (Stroke) arrives at: 302.530
# Patient № 364 started treatment at 302.530; queue time was 0.000
# Patient № 365 (Stroke) arrives at: 302.795
# Patient № 365 started treatment at 302.795; queue time was 0.000
# Patient № 366 (Stroke) arrives at: 302.866
# Patient № 366 started treatment at 302.866; queue time was 0.000
# Patient № 367 (Stroke) arrives at: 303.299
# Patient № 367 started treatment at 303.299; queue time was 0.000
# Patient № 368 (Stroke) arrives at: 303.384
# Patient № 368 started treatment at 303.384; queue time was 0.000
# Patient № 369 (Stroke) arrives at: 303.949
# Patient № 369 started treatment at 304.164; queue time was 0.215
# Patient № 370 (Stroke) arrives at: 304.534
# Patient № 371 (Stroke) arrives at: 304.670
# Patient № 372 (Neuro) arrives at: 304.910
# Patient № 370 started treatment at 305.163; queue time was 0.628
# Patient № 373 (Neuro) arrives at: 306.556
# Patient № 371 started treatment at 306.669; queue time was 1.999
# Patient № 372 started treatment at 306.801; queue time was 1.891
# Patient № 374 (TIA) arrives at: 306.836
# Patient № 373 started treatment at 308.110; queue time was 1.554
# Patient № 375 (Stroke) arrives at: 308.375
# Patient № 374 started treatment at 308.625; queue time was 1.789
# Patient № 376 (Stroke) arrives at: 308.738
# Patient № 375 started treatment at 309.440; queue time was 1.065
# Patient № 376 started treatment at 309.907; queue time was 1.170
# Patient № 377 (Stroke) arrives at: 310.174
# Patient № 378 (Stroke) arrives at: 310.415
# Patient № 379 (Stroke) arrives at: 311.025
# Patient № 377 started treatment at 311.104; queue time was 0.930
# Patient № 380 (Stroke) arrives at: 311.134
# Patient № 381 (Stroke) arrives at: 311.275
# Patient № 382 (Stroke) arrives at: 311.288
# Patient № 378 started treatment at 312.497; queue time was 2.082
# Patient № 383 (TIA) arrives at: 312.900
# Patient № 384 (Stroke) arrives at: 313.227
# Patient № 385 (Neuro) arrives at: 313.230
# Patient № 379 started treatment at 313.257; queue time was 2.232
# Patient № 380 started treatment at 313.374; queue time was 2.240
# Patient № 386 (TIA) arrives at: 313.399
# Patient № 387 (Stroke) arrives at: 313.653
# Patient № 381 started treatment at 314.187; queue time was 2.912
# Patient № 388 (Stroke) arrives at: 314.484
# Patient № 382 started treatment at 314.495; queue time was 3.206
# Patient № 383 started treatment at 314.700; queue time was 1.800
# Patient № 389 (Stroke) arrives at: 315.527
# Patient № 390 (Stroke) arrives at: 315.743
# Patient № 391 (Neuro) arrives at: 315.884
# Patient № 384 started treatment at 316.216; queue time was 2.989
# Patient № 392 (TIA) arrives at: 316.560
# Patient № 385 started treatment at 319.172; queue time was 5.942
# Patient № 393 (Stroke) arrives at: 319.262
# Patient № 386 started treatment at 319.717; queue time was 6.318
# Patient № 394 (Stroke) arrives at: 319.918
# Patient № 395 (Stroke) arrives at: 320.009
# Patient № 396 (Stroke) arrives at: 320.139
# Patient № 397 (Neuro) arrives at: 320.280
# Patient № 387 started treatment at 320.673; queue time was 7.019
# Patient № 398 (Stroke) arrives at: 320.734
# Patient № 399 (Stroke) arrives at: 320.887
# Patient № 388 started treatment at 320.909; queue time was 6.425
# Patient № 400 (Stroke) arrives at: 321.278
# Patient № 389 started treatment at 322.024; queue time was 6.497
# Patient № 401 (Stroke) arrives at: 322.170
# Patient № 402 (Stroke) arrives at: 322.220
# Patient № 403 (Stroke) arrives at: 322.651
# Patient № 404 (Neuro) arrives at: 322.672
# Patient № 390 started treatment at 322.952; queue time was 7.209
# Patient № 391 started treatment at 323.134; queue time was 7.249
# Patient № 405 (Stroke) arrives at: 324.534
# Patient № 406 (Stroke) arrives at: 324.624
# Patient № 392 started treatment at 325.360; queue time was 8.800
# Patient № 407 (Stroke) arrives at: 325.788
# Patient № 408 (Stroke) arrives at: 325.849
# Patient № 393 started treatment at 326.806; queue time was 7.544
# Patient № 394 started treatment at 326.824; queue time was 6.906
# Patient № 395 started treatment at 327.543; queue time was 7.534
# Patient № 396 started treatment at 328.997; queue time was 8.858
# Patient № 397 started treatment at 329.017; queue time was 8.738
# Patient № 409 (Stroke) arrives at: 329.063
# Patient № 398 started treatment at 329.169; queue time was 8.434
# Patient № 410 (Stroke) arrives at: 329.368
# Patient № 411 (Stroke) arrives at: 329.662
# Patient № 399 started treatment at 330.039; queue time was 9.153
# Patient № 400 started treatment at 330.756; queue time was 9.478
# Patient № 412 (Stroke) arrives at: 330.970
# Patient № 401 started treatment at 331.228; queue time was 9.058
# Patient № 402 started treatment at 333.206; queue time was 10.986
# Patient № 403 started treatment at 333.411; queue time was 10.760
# Patient № 413 (Stroke) arrives at: 333.681
# Patient № 414 (Neuro) arrives at: 333.686
# Patient № 404 started treatment at 334.723; queue time was 12.051
# Patient № 415 (Neuro) arrives at: 334.810
# Patient № 405 started treatment at 335.369; queue time was 10.834
# Patient № 406 started treatment at 336.274; queue time was 11.650
# Patient № 407 started treatment at 336.364; queue time was 10.576
# Patient № 408 started treatment at 336.966; queue time was 11.117
# Patient № 409 started treatment at 337.273; queue time was 8.210
# Patient № 416 (Stroke) arrives at: 337.506
# Patient № 410 started treatment at 337.824; queue time was 8.457
# Patient № 411 started treatment at 338.051; queue time was 8.390
# Patient № 412 started treatment at 338.146; queue time was 7.176
# Patient № 413 started treatment at 338.253; queue time was 4.572
# Patient № 414 started treatment at 338.506; queue time was 4.820
# Patient № 415 started treatment at 339.070; queue time was 4.260
# Patient № 417 (Stroke) arrives at: 339.165
# Patient № 416 started treatment at 339.821; queue time was 2.314
# Patient № 417 started treatment at 340.305; queue time was 1.141
# Patient № 418 (Stroke) arrives at: 341.238
# Patient № 418 started treatment at 341.416; queue time was 0.178
# Patient № 419 (Stroke) arrives at: 342.554
# Patient № 419 started treatment at 342.554; queue time was 0.000
# Patient № 420 (Stroke) arrives at: 342.785
# Patient № 420 started treatment at 342.785; queue time was 0.000
# Patient № 421 (Stroke) arrives at: 344.184
# Patient № 421 started treatment at 344.184; queue time was 0.000
# Patient № 422 (Stroke) arrives at: 344.384
# Patient № 422 started treatment at 344.429; queue time was 0.045
# Patient № 423 (Neuro) arrives at: 345.272
# Patient № 423 started treatment at 345.272; queue time was 0.000
# Patient № 424 (Stroke) arrives at: 345.571
# Patient № 424 started treatment at 345.816; queue time was 0.245
# Patient № 425 (Stroke) arrives at: 346.492
# Patient № 425 started treatment at 346.492; queue time was 0.000
# Patient № 426 (Stroke) arrives at: 346.921
# Patient № 426 started treatment at 347.036; queue time was 0.115
# Patient № 427 (Stroke) arrives at: 347.773
# Patient № 427 started treatment at 347.773; queue time was 0.000
# Patient № 428 (Neuro) arrives at: 348.419
# Patient № 428 started treatment at 348.419; queue time was 0.000
# Patient № 429 (Stroke) arrives at: 348.856
# Patient № 429 started treatment at 348.856; queue time was 0.000
# Patient № 430 (Stroke) arrives at: 349.134
# Patient № 430 started treatment at 349.134; queue time was 0.000
# Patient № 431 (Stroke) arrives at: 349.635
# Patient № 432 (Stroke) arrives at: 350.143
# Patient № 433 (Stroke) arrives at: 350.278
# Patient № 434 (Stroke) arrives at: 350.625
# Patient № 431 started treatment at 351.444; queue time was 1.809
# Patient № 432 started treatment at 351.483; queue time was 1.341
# Patient № 433 started treatment at 351.570; queue time was 1.293
# Patient № 435 (Stroke) arrives at: 351.856
# Patient № 436 (Stroke) arrives at: 353.291
# Patient № 434 started treatment at 353.471; queue time was 2.846
# Patient № 437 (Stroke) arrives at: 353.979
# Patient № 435 started treatment at 354.354; queue time was 2.497
# Patient № 438 (Neuro) arrives at: 354.605
# Patient № 439 (Stroke) arrives at: 354.699
# Patient № 436 started treatment at 354.774; queue time was 1.484
# Patient № 440 (Stroke) arrives at: 355.177
# Patient № 437 started treatment at 355.631; queue time was 1.652
# Patient № 438 started treatment at 355.884; queue time was 1.279
# Patient № 441 (Stroke) arrives at: 356.577
# Patient № 442 (TIA) arrives at: 356.939
# Patient № 443 (Stroke) arrives at: 357.064
# Patient № 439 started treatment at 357.754; queue time was 3.055
# Patient № 444 (Neuro) arrives at: 357.787
# Patient № 445 (Stroke) arrives at: 358.214
# Patient № 440 started treatment at 358.883; queue time was 3.706
# Patient № 446 (Stroke) arrives at: 358.982
# Patient № 447 (Stroke) arrives at: 359.702
# Patient № 441 started treatment at 359.712; queue time was 3.135
# Patient № 442 started treatment at 360.576; queue time was 3.636
# Patient № 443 started treatment at 360.618; queue time was 3.554
# Patient № 444 started treatment at 360.698; queue time was 2.911
# Patient № 448 (Neuro) arrives at: 362.071
# Patient № 445 started treatment at 362.883; queue time was 4.670
# Patient № 446 started treatment at 363.031; queue time was 4.049
# Patient № 449 (Stroke) arrives at: 363.150
# Patient № 450 (Neuro) arrives at: 363.176
# Patient № 447 started treatment at 363.229; queue time was 3.527
# Patient № 448 started treatment at 363.623; queue time was 1.551
# Patient № 449 started treatment at 363.998; queue time was 0.848
# Patient № 450 started treatment at 364.494; queue time was 1.318
# Patient № 451 (TIA) arrives at: 364.738
# Patient № 451 started treatment at 364.738; queue time was 0.000
# end of run. simulation clock time = 365
#
# Single run results
# ------------------
# Mean Queue Time: 1.91 days!
