# %% [markdown]
# # Computer Simulation Lab 2.
#
# ## Modelling more complex pathways
#
# **In the lab you will learn how to :**
#
# * design and code more complex health pathways in SimPy
# * build a computer simulation model of a minor injury unit.
# * use python functions to organisation your experimentation and scenarios.
#
#
# ## Organisation of the notebook.
#
# The main exercise in this notebook requires you to code the logic of a Minor Injury Unit. The notebook is provided with a number of classes and code to assist you in your model coding.
#
# * Distribution classes e.g. the `Exponential` distribution.
# * A `Scenario` class to enable you to pass parameters to the model.
# * Template classes to represent the Minor Injury Unit and the process patients follow.
#
# **A video introduction (~30 mins) to the notebook, MIU problem and exercises is available [here](https://recapexeter.cloud.panopto.eu/Panopto/Pages/Viewer.aspx?id=83928f04-e118-48be-a2a4-ac7c00be5d5e)**
#
# -----

# %% [markdown]
# # Imports
#
# Please use the provided `hds_stoch` environment for this work.

# %%
#!pip install simpy

import simpy
simpy.__version__
# Out:
# '4.0.1'

# %%
import numpy as np
import pandas as pd
import itertools
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem description: Modelling a minor injury unit
#
# The exercises in this notebook will focus on a model of a minor injury unit (MIU).  In the UK, the NHS provides MIU's provide assessment and treatment for non-life threatening injuries.  For example, cuts and broken bones.
#
# The process flow below displays a high level process map of a MIU.
# * Patients arrive following a Poisson process, wait for nurse triage in one **triage bay**.
# * After triage is complete the patient waits for an assessment and treatment cubicle (there are **six**) where they are attended to by a nurse (here we assume the nurse is not a rate limiting step and we do not model nurse movement or availability).
# * Around **45%** of patients require diagnostics (e.g. an x-ray or other imaging) in addition to an assessment.
# * Around **75%** of diagnostics tests are booked by the nurse at the start of consultation with the remaining beginning their wait after the initial assessment.
# * Patients who undergo diagnostics are seen by a nurse for a 2nd time following the completion of their diagnostics.
#
# The duration of activities are:
#
# | Activity 	| Activity name        	| Distribution 	| Mean (mins) 	| Standard Dev (minutes) 	|
# |----------	|----------------------	|--------------	|-------------	|------------------------	|
# | 1        	| IAT                  	| Exponential  	| 5.0          	|                        	|
# | 2        	| 1st Assessment            	| Lognormal        	| 10          	| 3                      	|
# | 3       	| Diagnostic waiting time  	| Exponential        	| 30          	|                       	|
# | 4       	| 2nd Asessment  	| Lognormal        	| 10          	| 5                      	|
#
#
# | Activity 	| Activity name        	| Distribution 	| Low 	| Mode 	| High |
# |----------	|----------------------	|--------------	|-------------	|------------------------	| |
# | 5        	| Triage                  	| Triangular  	| 2.0          	|   5.0                     	| 10.0|
# | 6        	| Diagnostics           	| Triangular        	| 10.0          	| 15.0                      	|20.0 |
#
#
#
#
# ![image](images/minor_injury_process_flow.png)

# %% [markdown]
# # Distribution classes
#
# To help you build your model, the notebook includes some pre-written distribution classes that you may wish to use to setup sampling.  You are free to use these, but you can choose not too if you have an approach you prefer.

# %%
class Exponential:
    '''
    Convenience class for the exponential distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, mean, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        mean: float
            The mean of the exponential distribution
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.mean = mean
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.exponential(self.mean, size=size)

class Triangular:
    '''
    Convenience class for the triangular distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, low, mode, high, random_seed=None):
        self.rand = np.random.default_rng(seed=random_seed)
        self.low = low
        self.high = high
        self.mode = mode
        
    def sample(self, size=None):
        return self.rand.triangular(self.low, self.mode, self.high, size=size)
    
class Bernoulli:
    '''
    Convenience class for the Bernoulli distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, p, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        p: float
            probability of drawing a 1
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.p = p
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.binomial(n=1, p=self.p, size=size)

class Lognormal:
    """
    Encapsulates a lognormal distirbution
    """
    def __init__(self, mean, stdev, random_seed=None):
        """
        Params:
        -------
        mean = mean of the lognormal distribution
        stdev = standard dev of the lognormal distribution
        """
        self.rand = np.random.default_rng(seed=random_seed)
        mu, sigma = self.normal_moments_from_lognormal(mean, stdev**2)
        self.mu = mu
        self.sigma = sigma
        
    def normal_moments_from_lognormal(self, m, v):
        '''
        Returns mu and sigma of normal distribution
        underlying a lognormal with mean m and variance v
        source: https://blogs.sas.com/content/iml/2014/06/04/simulate-lognormal
        -data-with-specified-mean-and-variance.html

        Params:
        -------
        m = mean of lognormal distribution
        v = variance of lognormal distribution
                
        Returns:
        -------
        (float, float)
        '''
        phi = math.sqrt(v + m**2)
        mu = math.log(m**2/phi)
        sigma = math.sqrt(math.log(phi**2/m**2))
        return mu, sigma
        
    def sample(self):
        """
        Sample from the normal distribution
        """
        return self.rand.lognormal(self.mu, self.sigma)

# %%
# example code to use the distributions

# each distribution has a unique constructor you can pass in a seed to control sampling
triage_dist = Triangular(2, 5, 10, random_seed=42)

# each distribution has a identical `sample` method signature
delay = triage_dist.sample()
print(delay)
# Out:
# 6.993048377881435

# %% [markdown]
# # Utility functions
#
# In the simulation the `trace` function is used instead of `print`.  You can then control if a simulation outputs a trace of events by setting `TRACE = True` or turning event tracing off by setting `TRACE = False`.

# %%
def trace(msg):
    '''
    Utility function for printing simulation
    set the TRACE constant to FALSE to 
    turn tracing off.
    
    Params:
    -------
    msg: str
        string to print to screen.
    '''
    if TRACE:
        print(msg)

# %% [markdown]
# # Model parameters and the `Scenario` class
#
# * The constants below provides hard coded data representing the base case or 'as-is' state of the minor injury unit.
# * In the cell below the parameters you will find a `Scenario` class.  This makes use of the default parameters to set up the base case scenario.  Remember that its good practice to pass all of your parameters to your simulation model in a **container**.  A class is a flexible way to achieve this aim.

# %%
# These are the parameters for a base case model run.
# Note if you change these parameters then your model will run a new 'scenario' 

# resource counts
N_CUBICLES = 6
N_BAYS = 1

# time between arrivals in minutes (exponential)
MEAN_IAT = 5

# triage (triangular)
TRIAGE_LOW = 2
TRIAGE_MODE = 5
TRIAGE_HIGH = 10

# assessment (lognormal)
ASSESS_MEAN = 10
ASSESS_STD = 3

# 2nd assessment (lognormal)
ASSESS_MEAN_2 = 15
ASSESS_STD_2 = 5

# diagnostics (bernoulli)
PROB_DIAG = 0.45 

# diagnostics waiting time (exp)
DIAG_WT_MEAN = 20

# diagnostics process time (triangular)
DIAG_PT_LOW = 10
DIAG_PT_MODE = 15
DIAG_PT_HIGH = 20

# % in parallel (bernoulli)
P_PARALLEL = 0.75

# SEEDS to reproduce results of a single run
REPRODUCIBLE_RUN = True
    
if REPRODUCIBLE_RUN:
    SEEDS = [42, 101, 1066, 1966, 2013, 999, 1444, 2016]
else:
    SEEDS = [None, None, None, None, None, None, None, None]

# %%
class Scenario:
    '''
    Parameter container class for minor injury unit model.
    '''
    def __init__(self, name=None):
        '''
        The init method sets up our defaults. 
        
        Params:
        -------
        
        name - str or None
            optional name for scenario
        '''
        # optional name
        self.name = name
        
        # triage bays
        self.triage_bays = N_BAYS
        
        # assessment and treatment cubicles
        self.minor_cubicles = N_CUBICLES
        
        # inter-arrival distribution
        self.arrival_dist = Exponential(MEAN_IAT, random_seed=SEEDS[0])
        
        # triage distribution
        self.triage_dist = Triangular(TRIAGE_LOW, TRIAGE_MODE, TRIAGE_HIGH, 
                                      random_seed=SEEDS[1])
        
        # assessment distribution
        self.assessment_dist = Lognormal(ASSESS_MEAN, ASSESS_STD, 
                                         random_seed=SEEDS[2])
        
        # diagnostics: prob that patient needs imaging etc.
        self.n_diagnostics_minor = Bernoulli(PROB_DIAG, random_seed=SEEDS[3])
        
        # waiting and process time dists for diagnostics
        self.diag_wait_dist = Exponential(DIAG_WT_MEAN, random_seed=SEEDS[4])
        self.diag_dist = Triangular(DIAG_PT_LOW, DIAG_PT_MODE, DIAG_PT_HIGH,
                                    random_seed=SEEDS[5])
        
        # prob diagnostics done in parallel to nurse assessment
        self.p_diag_parallel = Bernoulli(P_PARALLEL, random_seed=SEEDS[6])
        
        # 2nd assessment distribution
        self.assessment_dist_2 = Lognormal(ASSESS_MEAN_2, ASSESS_STD_2, 
                                           random_seed=SEEDS[7])

# %% [markdown]
# ---
# # Exercise 1 : Model building
#
# **Task:**
# * Code the logic for the process that a patient undergoes the minor injury unit.
# * Run the model using the provided script.
# * Modify the script that runs the model so that it calculates the following performance measures:
#   * Time in the system (from arrival to departure)
#   * Time to nurse (from arrival to start of assessment 1)
#   * Time to triage (from arrival to start of triage)
#   * Four hour target (if that patient spent less than 4 hours in the MIU).
#
#
# **General Hints:**
# * You have been provided with skeleton code and classes to help you complete this task.
# * The class `MinorPatient` has its `__init__` method completed for you.
#   * The method accepts `args` as a parameter.  This is an instance of `Scenario` and contains the distributions used by `MinorPatient` for sampling etc.
#   * Note that the contructor sets up some performance metrics for the patient e.g. `self.time_to_triage`
# * You have been provided with a `MinorInjuryUnit` class to use as the main model object.  This class generates patient arrivals and creates instances of `MinorPatient`.  Note that all patients are saved in list `self.patients`
# * Remember to go back to the process map at the start of the notebook to remind you about logic.
#
#
# **HINTS - Modelling the triage process:**
# * The first thing to code is a triage.  The patient needs to request a resource, wait for it to be available and then sample a triage duration from the correct distribution.
# * Remember that to request a resource you need to follow this simpy pattern:
#
# ```python
# >> with self.triage_bays.request() as req:
# >>     yield req
# ```
# * Remember that simpy works by using **python generators**. Use the **yield** keyword in combination `simpy.Environment.timeout()` method to create delays in the process. For example,
#
# ```python
# >> triage_delay = self.triage_dist.sample()
# >> yield self.env.timeout(triage_delay)
# ```
#
#
# **HINTS - Modelling assessment 1 and diagnostics processes**:
# * The tricky part of this modelling exercise is to model a percentage of diagnostics tests that occur in parallel to nurse assessment.  Some advice:
#   * For this exercise, you should assume that assessment 1 time begins the moment a patient is assigned a cubicle.
#   * Remember only 45% of patients need diagnostics and the nurse orders 75% of diagnostics tests to run in parallel to assessment 1.
#   * **Keep it simple** and build the model up incrementally.  I.e. build a simple model that runs and then add more detail to it.
#   * A first task could be to model the process where assessment is always followed by diagnostics.  You could then limit that to a percentage of patients.
#   * When diagnostics are in parallel you then you only need to model a delay that is the maximum of either assessment time or diagnostic waiting time + diagnostics duration.
# * A patient keeps their cubicle while undergoing diagnostics.  Don't allow the cubicle to be allocated to a new patient.
#
#
# **HINTS - tracking time in the model**
# * You will need to keep track of how long it takes patients to complete processes in the model e.g. time to triage and time to first nurse assessment.
# * An example of recording a time in the model is as follows:
#
# ```python
# >> arrival_time = self.env.now
# ```
#
# * When you need to calculate a **time to something** you just need to take the difference between the current time and the arrival time. E.g.
#
# ```python
# >> self.time_to_triage = self.env.now - arrival_time
# ```
#
# **HINTS - calculating end of run performance measures**:
# * In this exercise it is easiest to calculate your performance measures at the end of the model run.
# * `MinorInjuryUnit` holds a list of `MinorPatient` objects called `patients`.  Iterate (loop) over the list and access the relevant performance measure of each patient.  You can then take the mean.  For example, assume that you have an `MinorInjuryUnit`object assigned to the variable `model`.  To calculate the time to triage:
#
# ```python
#
# >> mean_time_to_triage = 0.0
# >> for patient in model.patients:
# >>     mean_time_to_triage += patient.time_to_triage
# >> mean_time_to_triage = mean_time_to_triage / len(model.patients)
# ```
#
# alternatively you could use a list comprehension, cast to a `numpy.ndarray` and call the `mean()` method.
#
# ```python
# >> mean_time_to_triage = np.array([patient.time_to_triage
#                                    for patient in model.patients]).mean()
# ```

# %%
class MinorPatient:
    '''
    Simulates the process for a minor injury patient
    '''
    def __init__(self, identifier, env, args):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env

        # triage parameters
        self.triage_bays = args.triage_bays
        self.triage_dist = args.triage_dist
    
        # minor assessment parameters
        self.minor_cubicles = args.minor_cubicles
        self.assessment_dist = args.assessment_dist
        self.assessment_dist_2 = args.assessment_dist_2
        
        # diagnostics: prob that patient needs imaging etc.
        self.n_diagnostics_dist = args.n_diagnostics_minor
        
        # prob diagnostics done in parallel to nurse assessment
        self.p_diag_parallel = args.p_diag_parallel
        
        # waiting and process time dists for diagnostics
        self.diag_wait_dist = args.diag_wait_dist 
        self.diag_dist = args.diag_dist
                
        # individual patient metrics
        self.time_to_triage = 0.0
        self.time_to_nurse = 0.0
        self.time_in_system = 0.0
        self.four_hour_target = 0.0
        
    
    

    def assessment(self):
        
        '''
        simulates the process for minor emergencies
        
        1. request and wait for triage
        2. request and wait for a minor cubicle
        3. minor assessment
        4. Diagnostics (in parallel to or after 3.)
        5. 2nd assessment if the patient has undergone diagnostics
        6. exit system.
        
        '''
        
        
        # record the time that call entered the queue
        start_wait = env.now

        # request a bay
        with self.triage_bays.request() as req:
            yield req
            
            

            #record the waiting time for a patient to reach the bay
            self.waiting_time = self.env.now - start_wait
            
            trace(f'patient number {self.identifier} arrived at the bay at ' \
                  + f'{self.env.now:.3f}')

            # sample triage delay
            triage_delay = self.triage_dist.sample()
            
            yield self.env.timeout(triage_delay)
            
            
            
            # diagnostics: prob that patient needs imaging etc.
            do_you_need_diagnostics = self.n_diagnostics_dist.sample()

            
            
            # doesn't need diagnostics, go straight to cubicle
            if do_you_need_diagnostics > 0.45:
            
                # request a cubicle
                with self.minor_cubicles.request() as req:
                    yield req
            
                    trace(f'patient number {self.identifier} arrived at a cubicle for assessment at ' \
                      + f'{self.env.now:.3f}')    
                    
                    # sample assessment 1 delay 
                    assessment_delay = self.assessment_dist.sample()
                    yield self.env.timeout(assessment_delay)
                
                # needs diagnostics
                else:
                    
                    
                    # prob diagnostics done in parallel to nurse assessment
                    are_you_lucky = self.p_diag_parallel.sample()
                    
                    # yes! diagnostics done in parallel
                    if are_you_lucky < 0.75:
                        
                        
                        # assessment 1 -> straight to diagnostics -> assessment 2 
                        
                        # request a cubicle
                        with self.minor_cubicles.request() as req:
                            yield req
            
                            trace(f'patient number {self.identifier} arrived at a cubicle for assessment at ' \
                            + f'{self.env.now:.3f}' + ' needs diagnostics. booked rightaway')    
                    
                            # sample assessment 1 delay 
                            assessment_delay = self.assessment_dist.sample()
                            yield self.env.timeout(assessment_delay)
                        
                            
                            
                            # timeout???
                            diagnostics_delay = self.diag_dist.sample()
                            yield self.env.timeout(diagnostics_delay)
                            
                            
                            
                            
                            # request a cubicle for the final assessment
                            with self.minor_cubicles.request() as req:
                                yield req
                                
                                trace(f'patient number {self.identifier} arrived at a cubicle for assessment at ' \
                                + f'{self.env.now:.3f}' + ' needs diagnostics. booked rightaway') 
                            
                                assessment_2_delay = self.assessment_dist_2.sample()
                                yield self.env.timeout(assessment2_delay)
                            
                            #свободен
                                
                        
                        
                        
                            
                            
                        # not lucky :( join the diagnostics queue
                        else:
                        
                        # assessment 1 -> diagnostics queue -> diagnostics -> assessment 2
                    
                
                
            
            trace(f'patient number {self.identifier} discharged {self.env.now:.3f}; ' \
                  + f'waiting time was {self.waiting_time:.3f}') 
        
        
        
        
        
        
        
        #pass

# %%
class MinorInjuryUnit:  
    '''
    Model of an minor injury unit
    '''
    def __init__(self, env, args):
        '''
        Contructor
        
        Params:
        -------
        env: simpy.Environment
        
        args: Scenario
            container class for simulation model inputs.
        '''
        self.env = env
        self.args = args 
        self.init_model_resources(args)
        self.patients = []
        
        
    def init_model_resources(self, args):
        '''
        Setup the simpy resource objects
        
        Params:
        ------
        args - Scenario
            Simulation Parameter Container
        '''
        args.triage_bays = simpy.Resource(self.env, 
                                          capacity=args.triage_bays)
        args.minor_cubicles = simpy.Resource(self.env, 
                                             capacity=args.minor_cubicles)
        
            
    def arrivals_generator(self):
        '''
        IAT is exponentially distributed

        Parameters:
        ------
        env: simpy.Environment

        args: Scenario
            Container class for model data inputs
        '''
        for patient_count in itertools.count(start=1):
            inter_arrival_time = self.args.arrival_dist.sample()
            yield self.env.timeout(inter_arrival_time)

            trace(f'patient {patient_count} arrives at: {self.env.now:.3f}')

            # create a new minor patient and pass in env and args
            new_patient = MinorPatient(patient_count, self.env, self.args)
            
            # keep a record of the patient for results calculation
            self.patients.append(new_patient)
            
            # init the minor injury process for this patient
            self.env.process(new_patient.assessment())

# %%
# example solution ....
class MinorPatient:
    '''
    Patient in the minor ED process
    '''
    def __init__(self, identifier, env, args):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env

        # triage parameters
        self.triage_bays = args.triage_bays
        self.triage_dist = args.triage_dist
    
        # minor assessment parameters
        self.minor_cubicles = args.minor_cubicles
        self.assessment_dist = args.assessment_dist
        self.assessment_dist_2 = args.assessment_dist_2
        
        # diagnostics: prob that patient needs imaging etc.
        self.n_diagnostics_dist = args.n_diagnostics_minor
        
        # prob diagnostics done in parallel to nurse assessment
        self.p_diag_parallel = args.p_diag_parallel
        
        # waiting and process time dists for diagnostics
        self.diag_wait_dist = args.diag_wait_dist 
        self.diag_dist = args.diag_dist
                
        # individual patient metrics
        self.time_to_triage = 0.0
        self.time_to_nurse = 0.0
        self.time_in_system = 0.0
        self.four_hour_target = 0.0
        
    
    def assessment(self):
        '''
        simulates the process for minor emergencies
        
        1. request and wait for triage
        2. request and wait for a minor cubicle
        3. minor assessment
        4. exit system.
        
        '''
        # record the time that patient entered the system
        arrival_time = self.env.now

        # request an operator 
        with self.triage_bays.request() as req:
            yield req
                        
            trace(f'minor triage {self.identifier} at {self.env.now:.3f}')
            
            # time to triage
            self.time_to_triage = self.env.now - arrival_time
            
            # sample triage duration.
            triage_duration = self.triage_dist.sample()
           
            yield self.env.timeout(triage_duration)            
            
            trace(f'triage ended {self.identifier} ended {self.env.now:.3f}; '
                      + f' waiting time was {self.env.now - arrival_time:.3f}')
            
        
        # get cubicle
        with self.minor_cubicles.request() as req:
            yield req
            
            # record time to first being seen by a nurse
            self.time_to_nurse = self.env.now - arrival_time
            
            trace(f'minor assessment {self.identifier} at {self.env.now:.3f}; '
                      + f' time to nurse was {self.time_to_nurse:.3f}')
            
            # sample for patient pathway
            assess_time, n_diagnostics, \
                parallel, diag_wt, diag_pt, assess_time_2 = self.sample_all()
            
            # patient undergoing diagnostics?
            if n_diagnostics > 0:

                #in parallel to minor assessment?
                if parallel:
                    
                    trace(f'parallel diagnostics patient {self.identifier}')
                    
                    #use the longest delay for assessment 1
                    activity_duration = max(assess_time, diag_wt + diag_pt)
                    
                else:
                    
                    trace(f'diagnostics following assessment for '
                          + f'patient {self.identifier}')
                    
                    #use the total delay for assessment 1
                    activity_duration = assess_time + diag_wt + diag_pt 
            else:
                activity_duration = assess_time
            
          
            # assessment 1 delay
            yield self.env.timeout(activity_duration)
            
            if n_diagnostics > 0:
                #assessment 2 delay
                
                trace(f'{self.identifier} enters 2nd assessment'
                      + f' at {self.env.now:.3f}')
                         
                yield self.env.timeout(assess_time_2)
                
                trace(f'{self.identifier} completes 2nd assessment'
                      + f' at {self.env.now:.3f}')
            
            # time in system for this patient
            self.time_in_system = self.env.now - arrival_time
            
            trace(f'{self.identifier} departs at {self.env.now:.3f}; '
                      + f' time in system{self.time_in_system:.3f}')
            
            if self.time_in_system <= (4 * 60):
                self.four_hour_target = 1
            
                        
    def sample_all(self):
        '''
        Sample assessment time, if the patient requires diagnostics,
        if the diags are done in parallel to assessment and 
        '''

        # sample assessment time
        assess_time = self.assessment_dist.sample()

        # will the patient need diagnostics?
        n_diagnostics = self.n_diagnostics_dist.sample()

        if n_diagnostics > 0:
            # will the diagnostics be in parallel with assessment
            parallel = self.p_diag_parallel.sample()

            # diagnostic waiting time
            diag_wt = self.diag_wait_dist.sample()

            # diagnostic process time
            diag_pt = self.diag_dist.sample()
            
            # second assessment time
            assess_time_2 = self.assessment_dist_2.sample()

            return (assess_time, n_diagnostics, parallel, diag_wt, diag_pt,
                    assess_time_2)
        else:
            return assess_time, n_diagnostics, _, _, _, 0

# %% [markdown]
# ## Script to run the model

# %%
# run length in minutes
RUN_LENGTH = 1440

# Turn off tracing
TRACE = True

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()

# create the model
model = MinorInjuryUnit(env, default_args)

# setup the process
env.process(model.arrivals_generator())

env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')

####### Your code here ######################################
# Calculate and printout Performance metrics

# Hint: loop through the collection of patients in model and calculate the 
# mean of each of the performance measures.

###################################################################
# Out:
# patient 1 arrives at: 12.021
# patient number 1 arrived at the bay at 12.021
# patient number 1 arrived at a cubicle for assessment at 20.518
# 1
# patient 2 arrives at: 23.702
# patient number 1 discharged 28.432; waiting time was 0.000
# patient number 2 arrived at the bay at 28.432
# patient number 2 arrived at a cubicle for assessment at 33.369
# 1
# patient 3 arrives at: 35.626
# patient 4 arrives at: 37.025
# patient 5 arrives at: 37.457
# patient number 2 discharged 43.921; waiting time was 4.730
# patient number 3 arrived at the bay at 43.921
# patient 6 arrives at: 44.720
# patient number 3 arrived at a cubicle for assessment at 50.987
# 1
# patient 7 arrives at: 51.770
# patient number 3 discharged 62.068; waiting time was 8.295
# patient number 4 arrived at the bay at 62.068
# patient 8 arrives at: 67.392
# patient 9 arrives at: 67.788
# patient number 4 arrived at a cubicle for assessment at 68.025
# 1
# patient 10 arrives at: 73.021
# patient 11 arrives at: 73.373
# patient 12 arrives at: 78.818
# patient number 4 discharged 81.955; waiting time was 25.044
# patient number 5 arrived at the bay at 81.955
# patient number 5 arrived at a cubicle for assessment at 86.613
# 1
# patient 13 arrives at: 87.475
# patient 14 arrives at: 89.409
# patient 15 arrives at: 95.567
# patient 16 arrives at: 96.336
# patient 17 arrives at: 96.794
# patient number 5 discharged 97.654; waiting time was 44.498
# patient number 6 arrived at the bay at 97.654
# patient 18 arrives at: 98.370
# patient 19 arrives at: 102.876
# patient 20 arrives at: 104.941
# patient number 6 arrived at a cubicle for assessment at 105.896
# 1
# patient number 6 discharged 111.162; waiting time was 52.934
# patient number 7 arrived at the bay at 111.162
# patient 21 arrives at: 111.178
# patient 22 arrives at: 112.296
# patient number 7 arrived at a cubicle for assessment at 118.876
# 1
# patient 23 arrives at: 121.485
# patient number 7 discharged 126.299; waiting time was 59.392
# patient number 8 arrived at the bay at 126.299
# patient 24 arrives at: 127.621
# patient 25 arrives at: 130.900
# patient number 8 arrived at a cubicle for assessment at 131.256
# 1
# patient 26 arrives at: 132.985
# patient 27 arrives at: 135.252
# patient 28 arrives at: 135.637
# patient 29 arrives at: 136.535
# patient 30 arrives at: 139.962
# patient number 8 discharged 140.029; waiting time was 58.908
# patient number 9 arrived at the bay at 140.029
# patient 31 arrives at: 141.905
# patient 32 arrives at: 148.226
# patient number 9 arrived at a cubicle for assessment at 148.993
# 1
# patient 33 arrives at: 151.769
# patient 34 arrives at: 152.959
# patient 35 arrives at: 155.264
# patient 36 arrives at: 158.472
# patient 37 arrives at: 160.191
# patient 38 arrives at: 161.800
# patient number 9 discharged 162.111; waiting time was 72.241
# patient number 10 arrived at the bay at 162.111
# patient 39 arrives at: 166.195
# patient number 10 arrived at a cubicle for assessment at 166.432
# 1
# patient 40 arrives at: 167.680
# patient 41 arrives at: 174.348
# patient 42 arrives at: 181.303
# patient number 10 discharged 181.331; waiting time was 89.090
# patient number 11 arrived at the bay at 181.331
# patient 43 arrives at: 186.723
# patient 44 arrives at: 187.088
# patient number 11 arrived at a cubicle for assessment at 188.542
# 1
# patient 45 arrives at: 192.759
# patient 46 arrives at: 199.530
# patient number 11 discharged 200.828; waiting time was 107.958
# patient number 12 arrived at the bay at 200.828
# patient 47 arrives at: 205.140
# patient 48 arrives at: 206.541
# patient number 12 arrived at a cubicle for assessment at 207.255
# 1
# patient 49 arrives at: 208.145
# patient 50 arrives at: 208.974
# patient 51 arrives at: 210.746
# patient 52 arrives at: 210.852
# patient 53 arrives at: 211.688
# patient number 12 discharged 213.290; waiting time was 122.010
# patient number 13 arrived at the bay at 213.290
# patient 54 arrives at: 218.264
# patient number 13 arrived at a cubicle for assessment at 218.690
# 1
# patient number 13 discharged 226.833; waiting time was 125.815
# patient number 14 arrived at the bay at 226.833
# patient number 14 arrived at a cubicle for assessment at 229.693
# 1
# patient number 14 discharged 237.125; waiting time was 137.424
# patient number 15 arrived at the bay at 237.125
# patient 55 arrives at: 238.242
# patient 56 arrives at: 241.060
# patient 57 arrives at: 242.480
# patient 58 arrives at: 244.469
# patient number 15 arrived at a cubicle for assessment at 245.074
# 1
# patient 59 arrives at: 246.276
# patient 60 arrives at: 246.924
# patient number 15 discharged 250.623; waiting time was 141.558
# patient number 16 arrived at the bay at 250.623
# patient 61 arrives at: 252.341
# patient number 16 arrived at a cubicle for assessment at 256.493
# 1
# patient 62 arrives at: 259.220
# patient number 16 discharged 265.247; waiting time was 154.287
# patient number 17 arrived at the bay at 265.247
# patient 63 arrives at: 266.759
# patient number 17 arrived at a cubicle for assessment at 270.309
# 1
# patient number 17 discharged 283.042; waiting time was 168.453
# patient number 18 arrived at the bay at 283.042
# patient number 18 arrived at a cubicle for assessment at 287.959
# 1
# patient 64 arrives at: 293.308
# patient number 18 discharged 299.399; waiting time was 184.672
# patient number 19 arrived at the bay at 299.399
# patient 65 arrives at: 303.842
# patient number 19 arrived at a cubicle for assessment at 305.668
# 1
# patient 66 arrives at: 312.066
# patient number 19 discharged 312.313; waiting time was 196.524
# patient number 20 arrived at the bay at 312.313
# patient number 20 arrived at a cubicle for assessment at 317.199
# 1
# patient 67 arrives at: 317.283
# patient 68 arrives at: 320.246
# patient 69 arrives at: 320.468
# patient number 20 discharged 324.657; waiting time was 207.372
# patient number 21 arrived at the bay at 324.657
# patient 70 arrives at: 325.251
# patient 71 arrives at: 328.358
# patient number 21 arrived at a cubicle for assessment at 330.219
# 1
# patient 72 arrives at: 335.898
# patient number 21 discharged 345.033; waiting time was 213.480
# patient number 22 arrived at the bay at 345.033
# patient 73 arrives at: 346.038
# patient 74 arrives at: 347.698
# patient 75 arrives at: 347.947
# patient number 22 arrived at a cubicle for assessment at 350.017
# 1
# patient 76 arrives at: 352.571
# patient number 22 discharged 357.169; waiting time was 232.737
# patient number 23 arrived at the bay at 357.169
# patient number 23 arrived at a cubicle for assessment at 360.320
# 1
# patient 77 arrives at: 365.338
# patient number 23 discharged 368.831; waiting time was 235.683
# patient number 24 arrived at the bay at 368.831
# patient 78 arrives at: 369.444
# patient number 24 arrived at a cubicle for assessment at 373.282
# 1
# patient 79 arrives at: 380.098
# patient number 24 discharged 380.524; waiting time was 241.210
# patient number 25 arrived at the bay at 380.524
# patient 80 arrives at: 383.863
# patient number 25 arrived at a cubicle for assessment at 388.002
# 1
# patient 81 arrives at: 390.433
# patient 82 arrives at: 391.877
# patient 83 arrives at: 392.549
# patient 84 arrives at: 393.262
# patient 85 arrives at: 393.850
# patient 86 arrives at: 394.124
# patient 87 arrives at: 402.707
# patient number 25 discharged 404.537; waiting time was 249.624
# patient number 26 arrived at the bay at 404.537
# patient 88 arrives at: 404.950
# patient 89 arrives at: 406.880
# patient 90 arrives at: 411.555
# patient number 26 arrived at a cubicle for assessment at 411.840
# 1
# patient 91 arrives at: 412.491
# patient 92 arrives at: 422.083
# patient number 26 discharged 426.418; waiting time was 271.552
# patient number 27 arrived at the bay at 426.418
# patient 93 arrives at: 428.543
# patient 94 arrives at: 430.189
# patient 95 arrives at: 431.192
# patient number 27 arrived at a cubicle for assessment at 432.770
# 1
# patient 96 arrives at: 433.847
# patient 97 arrives at: 435.371
# patient 98 arrives at: 435.750
# patient 99 arrives at: 438.268
# patient number 27 discharged 440.631; waiting time was 291.166
# patient number 28 arrived at the bay at 440.631
# patient number 28 arrived at a cubicle for assessment at 446.029
# 1
# patient 100 arrives at: 449.527
# patient 101 arrives at: 454.571
# patient number 28 discharged 457.216; waiting time was 304.993
# patient number 29 arrived at the bay at 457.216
# patient number 29 arrived at a cubicle for assessment at 466.117
# 1
# patient 102 arrives at: 469.983
# patient number 29 discharged 472.670; waiting time was 320.680
# patient number 30 arrived at the bay at 472.670
# patient number 30 arrived at a cubicle for assessment at 480.142
# 1
# patient 103 arrives at: 480.215
# patient 104 arrives at: 485.805
# patient number 30 discharged 488.449; waiting time was 332.708
# patient number 31 arrived at the bay at 488.449
# patient number 31 arrived at a cubicle for assessment at 492.874
# 1
# patient 105 arrives at: 495.058
# patient 106 arrives at: 498.693
# patient 107 arrives at: 504.032
# patient 108 arrives at: 505.933
# patient number 31 discharged 506.236; waiting time was 346.543
# patient number 32 arrived at the bay at 506.236
# patient 109 arrives at: 507.028
# patient number 32 arrived at a cubicle for assessment at 512.077
# 1
# patient 110 arrives at: 517.753
# patient 111 arrives at: 518.454
# patient number 32 discharged 519.147; waiting time was 358.009
# patient number 33 arrived at the bay at 519.147
# patient 112 arrives at: 519.394
# patient 113 arrives at: 520.945
# patient 114 arrives at: 525.782
# patient number 33 arrived at a cubicle for assessment at 527.820
# 1
# patient 115 arrives at: 527.852
# patient 116 arrives at: 531.274
# patient number 33 discharged 540.644; waiting time was 367.379
# patient number 34 arrived at the bay at 540.644
# patient 117 arrives at: 542.073
# patient number 34 arrived at a cubicle for assessment at 547.716
# 1
# patient 118 arrives at: 549.782
# patient number 34 discharged 554.352; waiting time was 387.686
# patient number 35 arrived at the bay at 554.352
# patient 119 arrives at: 555.638
# patient 120 arrives at: 556.493
# patient number 35 arrived at a cubicle for assessment at 559.330
# 1
# patient 121 arrives at: 562.440
# patient 122 arrives at: 564.712
# patient 123 arrives at: 565.331
# patient number 35 discharged 565.507; waiting time was 399.089
# patient number 36 arrived at the bay at 565.507
# patient 124 arrives at: 567.328
# patient 125 arrives at: 567.681
# patient number 36 arrived at a cubicle for assessment at 570.902
# 1
# patient 126 arrives at: 572.256
# patient 127 arrives at: 577.115
# patient 128 arrives at: 578.586
# patient 129 arrives at: 578.815
# patient number 36 discharged 588.432; waiting time was 407.035
# patient number 37 arrived at the bay at 588.432
# patient 130 arrives at: 592.462
# patient number 37 arrived at a cubicle for assessment at 594.040
# 1
# patient 131 arrives at: 596.501
# patient number 37 discharged 600.287; waiting time was 428.241
# patient number 38 arrived at the bay at 600.287
# patient 132 arrives at: 603.941
# patient 133 arrives at: 605.705
# patient number 38 arrived at a cubicle for assessment at 608.306
# 1
# patient 134 arrives at: 614.087
# patient number 38 discharged 618.649; waiting time was 438.486
# patient number 39 arrived at the bay at 618.649
# patient 135 arrives at: 622.294
# patient 136 arrives at: 622.759
# patient number 39 arrived at a cubicle for assessment at 625.269
# 1
# patient number 39 discharged 634.931; waiting time was 452.454
# patient number 40 arrived at the bay at 634.931
# patient number 40 arrived at a cubicle for assessment at 640.024
# 1
# patient number 40 discharged 649.705; waiting time was 467.251
# patient number 41 arrived at the bay at 649.705
# patient 137 arrives at: 649.917
# patient 138 arrives at: 653.285
# patient number 41 arrived at a cubicle for assessment at 655.066
# 1
# patient 139 arrives at: 660.274
# patient 140 arrives at: 661.492
# patient number 41 discharged 662.199; waiting time was 475.356
# patient number 42 arrived at the bay at 662.199
# patient number 42 arrived at a cubicle for assessment at 665.687
# 1
# patient 141 arrives at: 666.412
# patient 142 arrives at: 667.843
# patient number 42 discharged 670.609; waiting time was 480.896
# patient number 43 arrived at the bay at 670.609
# patient 143 arrives at: 675.912
# patient number 43 arrived at a cubicle for assessment at 676.102
# 1
# patient 144 arrives at: 678.228
# patient 145 arrives at: 682.123
# patient 146 arrives at: 684.764
# patient number 43 discharged 686.711; waiting time was 483.886
# patient number 44 arrived at the bay at 686.711
# patient 147 arrives at: 688.531
# patient 148 arrives at: 690.893
# patient number 44 arrived at a cubicle for assessment at 691.055
# 1
# patient 149 arrives at: 693.958
# patient 150 arrives at: 694.101
# patient number 44 discharged 699.031; waiting time was 499.622
# patient number 45 arrived at the bay at 699.031
# patient 151 arrives at: 702.039
# patient number 45 arrived at a cubicle for assessment at 702.526
# 1
# patient 152 arrives at: 714.587
# patient 153 arrives at: 717.492
# patient number 45 discharged 717.924; waiting time was 506.273
# patient number 46 arrived at the bay at 717.924
# patient number 46 arrived at a cubicle for assessment at 721.404
# 1
# patient number 46 discharged 732.822; waiting time was 518.393
# patient number 47 arrived at the bay at 732.822
# patient 154 arrives at: 734.512
# patient 155 arrives at: 735.353
# patient number 47 arrived at a cubicle for assessment at 737.098
# 1
# patient number 47 discharged 747.707; waiting time was 527.682
# patient number 48 arrived at the bay at 747.707
# patient 156 arrives at: 749.276
# patient 157 arrives at: 751.098
# patient number 48 arrived at a cubicle for assessment at 754.238
# 1
# patient 158 arrives at: 754.441
# patient number 48 discharged 761.428; waiting time was 541.167
# patient number 49 arrived at the bay at 761.428
# patient number 49 arrived at a cubicle for assessment at 765.502
# 1
# patient 159 arrives at: 766.626
# patient 160 arrives at: 767.261
# patient 161 arrives at: 768.216
# patient number 49 discharged 774.615; waiting time was 553.283
# patient number 50 arrived at the bay at 774.615
# patient 162 arrives at: 774.928
# patient 163 arrives at: 779.840
# patient number 50 arrived at a cubicle for assessment at 780.460
# 1
# patient 164 arrives at: 781.280
# patient 165 arrives at: 783.497
# patient 166 arrives at: 787.246
# patient number 50 discharged 787.545; waiting time was 565.641
# patient number 51 arrived at the bay at 787.545
# patient number 51 arrived at a cubicle for assessment at 793.558
# 1
# patient 167 arrives at: 796.745
# patient 168 arrives at: 798.536
# patient number 51 discharged 801.832; waiting time was 576.799
# patient number 52 arrived at the bay at 801.832
# patient 169 arrives at: 802.362
# patient 170 arrives at: 804.133
# patient 171 arrives at: 805.654
# patient number 52 arrived at a cubicle for assessment at 810.671
# 1
# patient 172 arrives at: 816.322
# patient 173 arrives at: 819.105
# patient number 52 discharged 821.746; waiting time was 590.981
# patient number 53 arrived at the bay at 821.746
# patient 174 arrives at: 825.802
# patient number 53 arrived at a cubicle for assessment at 827.091
# 1
# patient 175 arrives at: 827.316
# patient 176 arrives at: 828.246
# patient 177 arrives at: 833.958
# patient number 53 discharged 836.636; waiting time was 610.058
# patient number 54 arrived at the bay at 836.636
# patient 178 arrives at: 841.045
# patient number 54 arrived at a cubicle for assessment at 843.633
# 1
# patient 179 arrives at: 845.799
# patient 180 arrives at: 851.736
# patient number 54 discharged 852.011; waiting time was 618.372
# patient number 55 arrived at the bay at 852.011
# patient number 55 arrived at a cubicle for assessment at 854.926
# 1
# patient 181 arrives at: 856.830
# patient number 55 discharged 859.578; waiting time was 613.768
# patient number 56 arrived at the bay at 859.578
# patient 182 arrives at: 862.290
# patient number 56 arrived at a cubicle for assessment at 865.808
# 1
# patient number 56 discharged 872.893; waiting time was 618.518
# patient number 57 arrived at the bay at 872.893
# patient 183 arrives at: 873.564
# patient number 57 arrived at a cubicle for assessment at 882.006
# 1
# patient 184 arrives at: 887.681
# patient number 57 discharged 890.263; waiting time was 630.413
# patient number 58 arrived at the bay at 890.263
# patient 185 arrives at: 890.993
# patient 186 arrives at: 891.446
# patient number 58 arrived at a cubicle for assessment at 893.330
# 1
# patient 187 arrives at: 898.465
# patient number 58 discharged 900.358; waiting time was 645.794
# patient number 59 arrived at the bay at 900.358
# patient 188 arrives at: 902.696
# patient number 59 arrived at a cubicle for assessment at 908.436
# 1
# patient 189 arrives at: 914.898
# patient number 59 discharged 918.100; waiting time was 654.082
# patient number 60 arrived at the bay at 918.100
# patient 190 arrives at: 920.121
# patient 191 arrives at: 920.822
# patient number 60 arrived at a cubicle for assessment at 922.034
# 1
# patient 192 arrives at: 926.068
# patient 193 arrives at: 928.930
# patient 194 arrives at: 929.506
# patient 195 arrives at: 930.875
# patient number 60 discharged 931.276; waiting time was 671.177
# patient number 61 arrived at the bay at 931.276
# patient number 61 arrived at a cubicle for assessment at 937.672
# 1
# patient 196 arrives at: 948.256
# patient number 61 discharged 948.745; waiting time was 678.936
# patient number 62 arrived at the bay at 948.745
# patient 197 arrives at: 950.270
# patient number 62 arrived at a cubicle for assessment at 951.524
# 1
# patient 198 arrives at: 951.561
# patient 199 arrives at: 953.781
# patient 200 arrives at: 964.118
# patient number 62 discharged 966.973; waiting time was 689.525
# patient number 63 arrived at the bay at 966.973
# patient 201 arrives at: 969.562
# patient number 63 arrived at a cubicle for assessment at 970.187
# 1
# patient 202 arrives at: 970.551
# patient 203 arrives at: 970.591
# patient 204 arrives at: 972.781
# patient 205 arrives at: 973.535
# patient 206 arrives at: 983.872
# patient number 63 discharged 984.163; waiting time was 700.214
# patient number 64 arrived at the bay at 984.163
# patient 207 arrives at: 984.405
# patient 208 arrives at: 987.826
# patient number 64 arrived at a cubicle for assessment at 987.961
# 1
# patient 209 arrives at: 992.914
# patient number 64 discharged 998.009; waiting time was 690.855
# patient number 65 arrived at the bay at 998.009
# patient number 65 arrived at a cubicle for assessment at 1006.022
# 1
# patient 210 arrives at: 1007.264
# patient 211 arrives at: 1008.716
# patient 212 arrives at: 1017.395
# patient 213 arrives at: 1021.213
# patient number 65 discharged 1021.471; waiting time was 694.168
# patient number 66 arrived at the bay at 1021.471
# patient number 66 arrived at a cubicle for assessment at 1028.524
# 1
# patient 214 arrives at: 1029.863
# patient 215 arrives at: 1031.654
# patient 216 arrives at: 1033.318
# patient number 66 discharged 1034.274; waiting time was 709.405
# patient number 67 arrived at the bay at 1034.274
# patient 217 arrives at: 1034.582
# patient 218 arrives at: 1039.801
# patient number 67 arrived at a cubicle for assessment at 1040.596
# 1
# patient 219 arrives at: 1043.049
# patient 220 arrives at: 1047.380
# patient number 67 discharged 1048.141; waiting time was 716.991
# patient number 68 arrived at the bay at 1048.141
# patient 221 arrives at: 1053.794
# patient number 68 arrived at a cubicle for assessment at 1054.397
# 1
# patient 222 arrives at: 1059.564
# patient 223 arrives at: 1064.791
# patient number 68 discharged 1065.708; waiting time was 727.896
# patient number 69 arrived at the bay at 1065.708
# patient number 69 arrived at a cubicle for assessment at 1070.363
# 1
# patient 224 arrives at: 1071.785
# patient 225 arrives at: 1071.957
# patient number 69 discharged 1077.736; waiting time was 745.240
# patient number 70 arrived at the bay at 1077.736
# patient 226 arrives at: 1079.481
# patient number 70 arrived at a cubicle for assessment at 1083.392
# 1
# patient 227 arrives at: 1085.984
# patient 228 arrives at: 1088.177
# patient 229 arrives at: 1089.375
# patient 230 arrives at: 1092.929
# patient number 70 discharged 1094.542; waiting time was 752.485
# patient number 71 arrived at the bay at 1094.542
# patient number 71 arrived at a cubicle for assessment at 1099.990
# 1
# patient 231 arrives at: 1103.057
# patient 232 arrives at: 1104.687
# patient number 71 discharged 1108.437; waiting time was 766.184
# patient number 72 arrived at the bay at 1108.437
# patient 233 arrives at: 1111.853
# patient number 72 arrived at a cubicle for assessment at 1117.038
# 1
# patient number 72 discharged 1125.061; waiting time was 772.539
# patient number 73 arrived at the bay at 1125.061
# patient 234 arrives at: 1126.698
# patient 235 arrives at: 1128.693
# patient number 73 arrived at a cubicle for assessment at 1130.388
# 1
# patient number 73 discharged 1141.382; waiting time was 779.023
# patient number 74 arrived at the bay at 1141.382
# patient number 74 arrived at a cubicle for assessment at 1148.200
# 1
# patient 236 arrives at: 1150.206
# patient 237 arrives at: 1150.508
# patient 238 arrives at: 1150.694
# patient number 74 discharged 1153.759; waiting time was 793.683
# patient number 75 arrived at the bay at 1153.759
# patient number 75 arrived at a cubicle for assessment at 1158.693
# 1
# patient 239 arrives at: 1159.981
# patient 240 arrives at: 1163.208
# patient 241 arrives at: 1166.238
# patient number 75 discharged 1174.056; waiting time was 805.812
# patient number 76 arrived at the bay at 1174.056
# patient 242 arrives at: 1176.034
# patient number 76 arrived at a cubicle for assessment at 1182.329
# 1
# patient 243 arrives at: 1188.409
# patient number 76 discharged 1189.885; waiting time was 821.485
# patient number 77 arrived at the bay at 1189.885
# patient 244 arrives at: 1192.530
# patient number 77 arrived at a cubicle for assessment at 1197.455
# 1
# patient 245 arrives at: 1203.063
# patient number 77 discharged 1205.752; waiting time was 824.547
# patient number 78 arrived at the bay at 1205.752
# patient 246 arrives at: 1208.115
# patient 247 arrives at: 1210.623
# patient 248 arrives at: 1211.839
# patient number 78 arrived at a cubicle for assessment at 1215.182
# 1
# patient 249 arrives at: 1218.723
# patient number 78 discharged 1226.101; waiting time was 836.308
# patient number 79 arrived at the bay at 1226.101
# patient 250 arrives at: 1229.427
# patient number 79 arrived at a cubicle for assessment at 1230.436
# 1
# patient 251 arrives at: 1242.777
# patient 252 arrives at: 1244.287
# patient number 79 discharged 1245.526; waiting time was 846.003
# patient number 80 arrived at the bay at 1245.526
# patient 253 arrives at: 1249.416
# patient 254 arrives at: 1251.982
# patient number 80 arrived at a cubicle for assessment at 1253.249
# 1
# patient 255 arrives at: 1260.542
# patient 256 arrives at: 1261.646
# patient 257 arrives at: 1261.940
# patient number 80 discharged 1262.444; waiting time was 861.663
# patient number 81 arrived at the bay at 1262.444
# patient 258 arrives at: 1263.745
# patient 259 arrives at: 1264.098
# patient 260 arrives at: 1266.454
# patient number 81 arrived at a cubicle for assessment at 1267.870
# 1
# patient 261 arrives at: 1268.893
# patient 262 arrives at: 1269.460
# patient number 81 discharged 1277.557; waiting time was 872.011
# patient number 82 arrived at the bay at 1277.557
# patient number 82 arrived at a cubicle for assessment at 1283.127
# 1
# patient 263 arrives at: 1284.896
# patient 264 arrives at: 1286.407
# patient number 82 discharged 1292.336; waiting time was 885.680
# patient number 83 arrived at the bay at 1292.336
# patient 265 arrives at: 1292.391
# patient 266 arrives at: 1293.395
# patient 267 arrives at: 1295.938
# patient 268 arrives at: 1296.390
# patient 269 arrives at: 1296.979
# patient 270 arrives at: 1297.035
# patient number 83 arrived at a cubicle for assessment at 1298.055
# 1
# patient 271 arrives at: 1305.111
# patient 272 arrives at: 1306.888
# patient number 83 discharged 1308.616; waiting time was 899.787
# patient number 84 arrived at the bay at 1308.616
# patient 273 arrives at: 1310.351
# patient number 84 arrived at a cubicle for assessment at 1312.100
# 1
# patient 274 arrives at: 1314.696
# patient 275 arrives at: 1315.595
# patient number 84 discharged 1324.978; waiting time was 915.354
# patient number 85 arrived at the bay at 1324.978
# patient 276 arrives at: 1330.260
# patient number 85 arrived at a cubicle for assessment at 1332.797
# 1
# patient 277 arrives at: 1332.994
# patient 278 arrives at: 1333.371
# patient 279 arrives at: 1333.911
# patient 280 arrives at: 1336.392
# patient 281 arrives at: 1337.027
# patient 282 arrives at: 1338.659
# patient 283 arrives at: 1342.376
# patient 284 arrives at: 1342.583
# patient number 85 discharged 1344.243; waiting time was 931.128
# patient number 86 arrived at the bay at 1344.243
# patient 285 arrives at: 1344.378
# patient number 86 arrived at a cubicle for assessment at 1350.265
# 1
# patient 286 arrives at: 1352.227
# patient 287 arrives at: 1352.600
# patient number 86 discharged 1357.251; waiting time was 950.119
# patient number 87 arrived at the bay at 1357.251
# patient 288 arrives at: 1357.451
# patient 289 arrives at: 1357.704
# patient number 87 arrived at a cubicle for assessment at 1360.841
# 1
# patient number 87 discharged 1368.691; waiting time was 954.545
# patient number 88 arrived at the bay at 1368.691
# patient 290 arrives at: 1371.094
# patient 291 arrives at: 1372.365
# patient 292 arrives at: 1373.591
# patient number 88 arrived at a cubicle for assessment at 1375.461
# 1
# patient 293 arrives at: 1379.041
# patient number 88 discharged 1385.808; waiting time was 963.742
# patient number 89 arrived at the bay at 1385.808
# patient number 89 arrived at a cubicle for assessment at 1389.458
# 1
# patient 294 arrives at: 1390.338
# patient number 89 discharged 1397.178; waiting time was 978.928
# patient number 90 arrived at the bay at 1397.178
# patient number 90 arrived at a cubicle for assessment at 1402.203
# 1
# patient 295 arrives at: 1406.277
# patient 296 arrives at: 1413.185
# patient number 90 discharged 1413.351; waiting time was 985.623
# patient number 91 arrived at the bay at 1413.351
# patient number 91 arrived at a cubicle for assessment at 1419.715
# 1
# patient 297 arrives at: 1421.823
# patient 298 arrives at: 1427.308
# patient 299 arrives at: 1428.270
# patient number 91 discharged 1430.352; waiting time was 1000.860
# patient number 92 arrived at the bay at 1430.352
# patient 300 arrives at: 1434.099
# patient 301 arrives at: 1434.933
# patient number 92 arrived at a cubicle for assessment at 1435.727
# 1
# patient 302 arrives at: 1439.879
# end of run. simulation clock time = 1440

# %%
# Example solution

# run length in minutes
RUN_LENGTH = 1440

# Turn off tracing
TRACE = False

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()

# create the model
model = MinorInjuryUnit(env, default_args)

# setup the process
env.process(model.arrivals_generator())

env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')

####### Your code here ######################################
# Calculate and printout Performance metrics
# 1. mean time in system
mean_time_in_system = np.array([patient.time_in_system 
                                for patient in model.patients]).mean()


# 2. mean time to first treatment
mean_time_to_nurse = np.array([patient.time_to_nurse 
                               for patient in model.patients]).mean()

# 3. mean time to triage
mean_time_to_triage = np.array([patient.time_to_triage 
                               for patient in model.patients]).mean()

# 4. four hour target
four_hours = np.array([patient.four_hour_target 
                       for patient in 
                       model.patients]).sum() / len(model.patients)

print('\nSingle run results\n------------------')
print(f'Mean Minutes in System: {mean_time_in_system:.2f}')
print(f'Mean Minutes to Nurse: {mean_time_to_nurse:.2f}')
print(f'Mean Minutes to Triage: {mean_time_to_triage:.2f}')
print(f'Proportion discharged before 4 hrs: {four_hours:.2f}')

###################################################################
# Out:
# end of run. simulation clock time = 1440
#
# Single run results
# ------------------
# Mean Minutes in System: 144.77
# Mean Minutes to Nurse: 126.07
# Mean Minutes to Triage: 118.30
# Proportion discharged before 4 hrs: 0.61

# %% [markdown]
# ---
# # Exercise 2: Using the model for experimentation
#
# Now that you have your model you can use it for experimentation!  We are going to investigate the following scenarios
#
# * 1 extra triage bay
# * 1 extra cubicle
# * 5 extra cubicles
# * 2 extra triage bay + 1 extra cubicle
#
# ## Using functions to organise experimentation.
#
# So far we have run our model from a script.  In practice, it is a good idea to use functions to help you efficiently run scenarios.
#
# ### `single_model_run()`
#
# The function `single_model_run` has been provided to help you do that.  Take a look at it first.  Note that it is very similar to your previous script.   It accepts a parameter `scenario` which contains all of the parameters you wish to use for the run.  When the model run is complete it returns the performance desired performance measures. The separates the creation of the scenarios from your model run code.
#
# ### `get_scenarios()`
#
# A sensible way to organise experimentation is to create all of scenarios in advance, store them in a python `list` or `dict` and then loop through the passing each to the `single_model_run` function.   The function `get_scenarios` has been coded for you, and contains an example of creating scenarios.  As part of the exercise you will need to complete the code and add in the extra scenarios.
#
# > Note in practice if you are working with big complex models you may want to store all of your scenarios and parameters in a CSV file.  You can then read them in.  Here we have a simple model so we are hard coding everything for clarity.
#
# **Task**
# * Read and check you understand the functions and script provided.
# * Complete the `get_scenarios()` function so that you have results for all of the scenarios.
# * Run all of the scenarios!

# %%
def single_model_run(scenario, run_length):
    '''
    Perform a single run of the model and return the results
    
    Params:
    -------
    
    env = Simpy.Environment
    
    scenario - Scenario object
        The scenario/paramaters to run
        
    run_length - int
        The length of the simulation run.
        
        
    Returns:
        Tuple:
        (mean_time_in_system, mean_time_to_nurse, mean_time_to_triage,
         four_hours)
    '''
    env = simpy.Environment()
    # create the model and pass in scenario
    model = MinorInjuryUnit(env, scenario)

    # setup the process
    env.process(model.arrivals_generator())
    
    # run
    env.run(until=run_length)
    
    # Performance metrics

    # 1. mean time in system
    mean_time_in_system = np.array([patient.time_in_system 
                                    for patient in model.patients]).mean()


    # 2. mean time to first treatment
    mean_time_to_nurse = np.array([patient.time_to_nurse 
                                   for patient in model.patients]).mean()

    # 3. mean time to triage
    mean_time_to_triage = np.array([patient.time_to_triage 
                                   for patient in model.patients]).mean()


    # 4. four hour target
    four_hours = np.array([patient.four_hour_target 
                           for patient in 
                           model.patients]).sum() / len(model.patients)
        
    # return results.
    return (mean_time_in_system, mean_time_to_nurse, mean_time_to_triage,
            four_hours)

# %%
# setup scenarios
def get_scenarios():
    # sometime useful to store scenarios in a list or dict
    scenarios = {}
    # default scenario
    scenarios['base'] = Scenario()
    scenarios['base'].name = 'base'

    # this scenario has an extra triage bay
    scenario_1 = Scenario()
    scenario_1.triage_bays = N_BAYS + 1
    scenarios['extra_triage_capacity'] = scenario_1
    scenarios['extra_triage_capacity'].name = 'extra_triage_capacity'
    
    #################### Your code here ###############################
    
    # Scenarios to add:
    # 1. 1 extra minor cubicle
    # 2. 5 extra minor cubicles
    # 3. 1 extra triage bay
    # 4. 1 extra minor cubicle and 1 extra triage bay
    
    # your code here..
    # extra minor cubicle
    # scenario_2 = Scenario()
    # scenario_2.minor_cubicles = ...
    
    
    # your code here..
    # 5 extra minor cubicles

    
    # your code here
    # 1 extra cubicle and 1 extra triage bay

        
    return scenarios

# %%
# setup scenarios example solution
def get_scenarios():
    # sometime useful to store scenarios in a list or dict
    scenarios = {}
    # default scenario
    scenarios['base'] = Scenario()
    scenarios['base'].name = 'base'

    # this scenario has an extra triage bay
    scenario_1 = Scenario()
    scenario_1.triage_bays = N_BAYS + 1
    scenarios['extra_triage_capacity'] = scenario_1
    scenarios['extra_triage_capacity'].name = 'extra_triage_capacity'
    
    #################### Your code here ###############################
    
    # Scenarios to add:
    # 1. 1 extra minor cubicle
    # 2. 5 extra minor cubicles
    # 3. 1 extra triage bay
    # 4. 1 extra minor cubicle and 1 extra triage bay
    
    # extra minor cubicle
    scenario_2 = Scenario()
    scenario_2.minor_cubicles = N_CUBICLES + 1
    scenarios['extra_cubicle'] = scenario_2
    scenarios['extra_cubicle'].name = 'extra_cubicle'
    
    # 5 extra minor cubicles
    scenario_3 = Scenario()
    scenario_3.minor_cubicles = N_CUBICLES + 5
    scenarios['5_extra_cubicles'] = scenario_3
    scenarios['5_extra_cubicles'].name = '5_extra_cubicles'
    
    # 1 extra cubicle and 1 extra triage bay
    scenario_4 = Scenario()
    scenario_4.minor_cubicles = N_CUBICLES + 1
    scenario_4.triage_bays = N_BAYS + 1
    scenarios['combination'] = scenario_4
    scenarios['combination'].name = 'combination'
        
    return scenarios

# %% [markdown]
# ### script to run the scenarios.

# %%
RUN_LENGTH = 1440
TRACE = False

# load scenarios using your function
scenarios = get_scenarios()

# create simpy environment
env = simpy.Environment()

# loop through each scenario and store results in a dict
results = {}
for name, scenario in scenarios.items():
    print(f'simulating scenario: {name}')
    results[name] = single_model_run(scenario, RUN_LENGTH)
print('All simulations complete.\n\n')

# convert results to dataframe and printout
results = pd.DataFrame(results).T
results.columns = ['Time in System', 'Time to Nurse', 'Time to Triage', 
                   '4 Hr performance']
results
# Out:
# simulating scenario: base
# simulating scenario: extra_triage_capacity
# simulating scenario: extra_cubicle
# simulating scenario: 5_extra_cubicles
# simulating scenario: combination
# All simulations complete.
#                        Time in System  Time to Nurse  Time to Triage  \
# base                       144.768158     126.068157      118.297042
# extra_triage_capacity      100.181254      75.393956        1.834980
# extra_cubicle              140.898739     122.960667      118.297042
# 5_extra_cubicles           140.170316     122.232244      118.297042
# combination                 49.884516      22.260455        1.834980
#
#                        4 Hr performance
# base                           0.612583
# extra_triage_capacity          0.897351
# extra_cubicle                  0.629139
# 5_extra_cubicles               0.632450
# combination                    0.970199

# %% [markdown]
# # End
