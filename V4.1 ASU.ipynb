# %% [markdown]
# # Imports
#
# Please use the provided `hds_stoch` environment for this work.

# %%
import simpy
simpy.__version__
# Out:
# '4.0.1'

# %%
import numpy as np
import pandas as pd
import itertools
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Distribution classes
#
# To help you build your model, the notebook includes some pre-written distribution classes that you may wish to use to setup sampling.  You are free to use these, but you can choose not too if you have an approach you prefer.

# %%
class Exponential:
    '''
    Convenience class for the exponential distribution.
    packages up distribution parameters, seed and random generator.
    '''
    def __init__(self, mean, random_seed=None):
        '''
        Constructor
        
        Params:
        ------
        mean: float
            The mean of the exponential distribution
        
        random_seed: int, optional (default=None)
            A random seed to reproduce samples.  If set to none then a unique
            sample is created.
        '''
        self.rand = np.random.default_rng(seed=random_seed)
        self.mean = mean
        
    def sample(self, size=None):
        '''
        Generate a sample from the exponential distribution
        
        Params:
        -------
        size: int, optional (default=None)
            the number of samples to return.  If size=None then a single
            sample is returned.
        '''
        return self.rand.exponential(self.mean, size=size)

class Lognormal:
    """
    Encapsulates a lognormal distirbution
    """
    def __init__(self, mean, stdev, random_seed=None):
        """
        Params:
        -------
        mean = mean of the lognormal distribution
        stdev = standard dev of the lognormal distribution
        """
        self.rand = np.random.default_rng(seed=random_seed)
        mu, sigma = self.normal_moments_from_lognormal(mean, stdev**2)
        self.mu = mu
        self.sigma = sigma
        
    def normal_moments_from_lognormal(self, m, v):
        '''
        Returns mu and sigma of normal distribution
        underlying a lognormal with mean m and variance v
        source: https://blogs.sas.com/content/iml/2014/06/04/simulate-lognormal
        -data-with-specified-mean-and-variance.html

        Params:
        -------
        m = mean of lognormal distribution
        v = variance of lognormal distribution
                
        Returns:
        -------
        (float, float)
        '''
        phi = math.sqrt(v + m**2)
        mu = math.log(m**2/phi)
        sigma = math.sqrt(math.log(phi**2/m**2))
        return mu, sigma
        
    def sample(self):
        """
        Sample from the normal distribution
        """
        return self.rand.lognormal(self.mu, self.sigma)

# %% [markdown]
# # Utility functions

# %%
def trace(msg):
    '''
    Utility function for printing simulation
    set the TRACE constant to FALSE to 
    turn tracing off.
    
    Params:
    -------
    msg: str
        string to print to screen.
    '''
    if TRACE:
        print(msg)

# %%
def performance(ASU_model):
    '''
    Utility function for final metrics calculation.
    
    Returns numpy.float64 variable containining
    mean waiting time of the bottom 90% of the pts
    formatted to hours.
    
    Params:
    -------
    ASU_model: Class
        refer to the list of Patient objects appended 
        throughout a simulation run to the patients list
        inside of the ASU Class
    '''
    # mean time to treatment
    mean_queue = np.array([patient.queue_time 
                               for patient in model.patients])#.mean()

    # transform into hours
    mean_queue *= 24

    arr_length = np.size(mean_queue)

    # determine the number of values to be dropped
    num_to_drop = int(arr_length * 0.1)

    # sort the array in descending order
    sorted_mean_queue = np.sort(mean_queue)[::-1]

    # slice the sorted array to remove the calculated number of highest values
    patients_90_queue = sorted_mean_queue[num_to_drop:].mean()
    
    return patients_90_queue

# %% [markdown]
# # Model parameters
#
# The constants below provides hard coded data representing the base case or 'as-is' state of the minor injury unit.

# %%
# These are the parameters for a base case model run.
# Note if you change these parameters then your model will run a new 'scenario' 

# resource counts
N_BEDS = 9

# time between arrivals in minutes (exponential)
# for acute stroke, TIA and neuro respectively
MEAN_IATs = [1.2, 9.5, 3.5]

# treatment (lognormal)
# for acute stroke, TIA and neuro respectively
TREAT_MEANs = [7.4, 1.8, 2.0]
TREAT_STDs = [8.5, 2.3, 2.5]

# SEEDS to reproduce results of a single run
REPRODUCIBLE_RUN = False
    
if REPRODUCIBLE_RUN:
    SEEDS = [42, 101, 1066, 1966, 2013, 999, 1444, 2016]
else:
    SEEDS = [None, None, None, None, None, None, None, None]

# %% [markdown]
# # Scenario class
# In the cell below the parameters you will find a `Scenario` class.  This makes use of the default parameters to set up the base case scenario.  Remember that its good practice to pass all of your parameters to your simulation model in a **container**.  A class is a flexible way to achieve this aim.

# %%
class Scenario:
    '''
    Parameter container class for minor injury unit model.
    '''
    def __init__(self, name=None):
        '''
        The init method sets up our defaults. 
        
        Params:
        -------
        
        name - str or None
            optional name for scenario
        '''
        # optional name
        self.name = name
        
        # number of beds
        self.beds = N_BEDS
        
        # inter-arrival distributions
        self.arrival_dist_type1 = Exponential(MEAN_IATs[0], random_seed=SEEDS[0]) 
        self.arrival_dist_type2 = Exponential(MEAN_IATs[1], random_seed=SEEDS[1])
        self.arrival_dist_type3 = Exponential(MEAN_IATs[2], random_seed=SEEDS[2])
        
        
        # treatment distributions
        self.treatment_dist_type1 = Lognormal(TREAT_MEANs[0], TREAT_STDs[0], random_seed=SEEDS[3])
        self.treatment_dist_type2 = Lognormal(TREAT_MEANs[1], TREAT_STDs[1], random_seed=SEEDS[4])
        self.treatment_dist_type3 = Lognormal(TREAT_MEANs[2], TREAT_STDs[2], random_seed=SEEDS[5])

# %% [markdown]
# # Model building

# %%
class Patient:
    '''
    Patient in the minor ED process
    '''
    def __init__(self, identifier, env, args):
        '''
        Constructor method
        
        Params:
        -----
        identifier: int
            a numeric identifier for the patient.
            
        env: simpy.Environment
            the simulation environment
            
        args: Scenario
            The input data for the scenario
        '''
        # patient id and environment
        self.identifier = identifier
        self.env = env

        # treatment parameters
        self.beds = args.beds
        self.treatment_dist_type1 = args.treatment_dist_type1
        self.treatment_dist_type2 = args.treatment_dist_type2
        self.treatment_dist_type3 = args.treatment_dist_type3
                
        # individual patient metrics
        self.queue_time = 0.0
        
    
    def treatment_type1(self):

        # record the time that patient entered the system
        arrival_time = self.env.now
     
        # get a bed
        with self.beds.request() as req:
            yield req
            
            # record time to first being seen by a doctor
            self.queue_time = self.env.now - arrival_time

            trace(f'Patient № {self.identifier} started treatment at {self.env.now:.3f};'
                      + f' queue time was {self.queue_time:.3f}')            

            # sample for patient pathway
            treat_time = self.treatment_dist_type1.sample()
            
            activity_duration = treat_time
          
            # treatment delay
            yield self.env.timeout(activity_duration)
            
            
            
    def treatment_type2(self):

        # record the time that patient entered the system
        arrival_time = self.env.now
     
        # get a bed
        with self.beds.request() as req:
            yield req
            
            # record time to first being seen by a doctor
            self.queue_time = self.env.now - arrival_time
            
            trace(f'Patient № {self.identifier} started treatment at {self.env.now:.3f};'
                      + f' queue time was {self.queue_time:.3f}')            

            # sample for patient pathway
            treat_time = self.treatment_dist_type2.sample()
            
            activity_duration = treat_time
          
            # treatment delay
            yield self.env.timeout(activity_duration)
                                        
            
    def treatment_type3(self):

        # record the time that patient entered the system
        arrival_time = self.env.now
     
        # get a bed
        with self.beds.request() as req:
            yield req
            
            # record time to first being seen by a doctor
            self.queue_time = self.env.now - arrival_time
            
            trace(f'Patient № {self.identifier} started treatment at {self.env.now:.3f};'
                      + f' queue time was {self.queue_time:.3f}')             

            # sample for patient pathway
            treat_time = self.treatment_dist_type3.sample()
            
            activity_duration = treat_time
          
            # treatment delay
            yield self.env.timeout(activity_duration)

# %%
class ASU:  
    '''
    Model of an ASU
    '''
    def __init__(self, env, args):
        '''
        Contructor
        
        Params:
        -------
        env: simpy.Environment
        
        args: Scenario
            container class for simulation model inputs.
        '''
        self.env = env
        self.args = args 
        self.init_model_resources(args)
        self.patients = []
        self.patient_count = 0
        
        
    def init_model_resources(self, args):
        '''
        Setup the simpy resource objects
        
        Params:
        ------
        args - Scenario
            Simulation Parameter Container
        '''

        args.beds = simpy.Resource(self.env, 
                                   capacity=args.beds)
        
            
    def arrivals_generator_type1(self):
            
        while True:
            
            
                # PATIENT WITH ACUTE STROKE ARRIVES (TYPE 1)
                inter_arrival_time = self.args.arrival_dist_type1.sample()               
                
                yield self.env.timeout(inter_arrival_time)
                
                self.patient_count += 1
                
                trace(f'Patient № {self.patient_count} (Stroke) arrives at: {self.env.now:.3f}')
                
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)                

                # init the minor injury process for this patient
                self.env.process(new_patient.treatment_type1())                 
            
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)                
                
                
    def arrivals_generator_type2(self):
            
        while True:
            
                            
                # PATIENT WITH TRANSITORY ISCHEMIC ATTACK ARRIVES (TYPE 2)
                inter_arrival_time = self.args.arrival_dist_type2.sample()
           
                yield self.env.timeout(inter_arrival_time)
            
                self.patient_count += 1            
                                
                trace(f'Patient № {self.patient_count} (TIA) arrives at: {self.env.now:.3f}')   
                
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)
            
                # init the minor injury process for this patient
                self.env.process(new_patient.treatment_type2())                
                
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)                
                
    def arrivals_generator_type3(self):
            
        while True:
            
                
                # PATIENT WITH COMPLEX NEUROLOGICAL DIAGNOSIS ARRIVES (TYPE 3)
                inter_arrival_time = self.args.arrival_dist_type3.sample()
                
                yield self.env.timeout(inter_arrival_time)
                
                self.patient_count += 1
                
                trace(f'Patient № {self.patient_count} (Neuro) arrives at: {self.env.now:.3f}')
                
                # create a new patient and pass in env and args
                new_patient = Patient(self.patient_count, self.env, self.args)
            
                # init the minor injury process for this patient
                self.env.process(new_patient.treatment_type3())                
                
                # keep a record of the patient for results calculation
                self.patients.append(new_patient)

# %% [markdown]
# # Script to run the model

# %%
# run length in days
RUN_LENGTH = 365

# Turn off tracing
TRACE = True #False 

# create simpy environment
env = simpy.Environment()

# base case scenario with default parameters
default_args = Scenario()

# create the model
model = ASU(env, default_args)

# setup the processes
env.process(model.arrivals_generator_type1())
env.process(model.arrivals_generator_type2())
env.process(model.arrivals_generator_type3())


env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')


# Calculate and printout Performance metrics
results = performance(model)

print('\nSingle run results\n------------------')
print(f'Mean Queue Time of Bottom 90% of the Patients: {results:.2f} hours!')

###################################################################
# Out:
# Patient № 1 (Neuro) arrives at: 1.426
# Patient № 1 started treatment at 1.426; queue time was 0.000
# Patient № 2 (Neuro) arrives at: 2.333
# Patient № 2 started treatment at 2.333; queue time was 0.000
# Patient № 3 (Stroke) arrives at: 2.967
# Patient № 3 started treatment at 2.967; queue time was 0.000
# Patient № 4 (Stroke) arrives at: 3.504
# Patient № 4 started treatment at 3.504; queue time was 0.000
# Patient № 5 (Stroke) arrives at: 4.186
# Patient № 5 started treatment at 4.186; queue time was 0.000
# Patient № 6 (Stroke) arrives at: 4.518
# Patient № 6 started treatment at 4.518; queue time was 0.000
# Patient № 7 (TIA) arrives at: 5.073
# Patient № 7 started treatment at 5.073; queue time was 0.000
# Patient № 8 (TIA) arrives at: 5.810
# Patient № 8 started treatment at 5.810; queue time was 0.000
# Patient № 9 (Stroke) arrives at: 5.821
# Patient № 9 started treatment at 5.821; queue time was 0.000
# Patient № 10 (Stroke) arrives at: 8.074
# Patient № 10 started treatment at 8.074; queue time was 0.000
# Patient № 11 (Stroke) arrives at: 9.950
# Patient № 11 started treatment at 9.950; queue time was 0.000
# Patient № 12 (Stroke) arrives at: 10.113
# Patient № 12 started treatment at 10.113; queue time was 0.000
# Patient № 13 (Neuro) arrives at: 10.319
# Patient № 13 started treatment at 10.319; queue time was 0.000
# Patient № 14 (Stroke) arrives at: 10.853
# Patient № 14 started treatment at 10.853; queue time was 0.000
# Patient № 15 (Stroke) arrives at: 12.061
# Patient № 15 started treatment at 12.061; queue time was 0.000
# Patient № 16 (Stroke) arrives at: 12.448
# Patient № 16 started treatment at 12.448; queue time was 0.000
# Patient № 17 (TIA) arrives at: 13.035
# Patient № 17 started treatment at 13.035; queue time was 0.000
# Patient № 18 (Neuro) arrives at: 13.487
# Patient № 18 started treatment at 13.487; queue time was 0.000
# Patient № 19 (Stroke) arrives at: 14.346
# Patient № 19 started treatment at 14.346; queue time was 0.000
# Patient № 20 (Neuro) arrives at: 15.207
# Patient № 20 started treatment at 15.207; queue time was 0.000
# Patient № 21 (Stroke) arrives at: 15.499
# Patient № 21 started treatment at 15.499; queue time was 0.000
# Patient № 22 (Stroke) arrives at: 15.678
# Patient № 22 started treatment at 15.678; queue time was 0.000
# Patient № 23 (Neuro) arrives at: 17.568
# Patient № 23 started treatment at 17.568; queue time was 0.000
# Patient № 24 (Stroke) arrives at: 19.129
# Patient № 24 started treatment at 19.129; queue time was 0.000
# Patient № 25 (Stroke) arrives at: 20.765
# Patient № 25 started treatment at 20.765; queue time was 0.000
# Patient № 26 (Stroke) arrives at: 21.590
# Patient № 26 started treatment at 21.590; queue time was 0.000
# Patient № 27 (Neuro) arrives at: 22.457
# Patient № 27 started treatment at 22.457; queue time was 0.000
# Patient № 28 (Stroke) arrives at: 24.619
# Patient № 28 started treatment at 24.619; queue time was 0.000
# Patient № 29 (Neuro) arrives at: 24.928
# Patient № 29 started treatment at 24.928; queue time was 0.000
# Patient № 30 (Stroke) arrives at: 25.541
# Patient № 30 started treatment at 25.541; queue time was 0.000
# Patient № 31 (Stroke) arrives at: 26.351
# Patient № 31 started treatment at 26.351; queue time was 0.000
# Patient № 32 (Stroke) arrives at: 27.239
# Patient № 32 started treatment at 27.239; queue time was 0.000
# Patient № 33 (Neuro) arrives at: 27.752
# Patient № 33 started treatment at 27.752; queue time was 0.000
# Patient № 34 (Stroke) arrives at: 27.969
# Patient № 34 started treatment at 27.969; queue time was 0.000
# Patient № 35 (Stroke) arrives at: 28.868
# Patient № 35 started treatment at 28.868; queue time was 0.000
# Patient № 36 (Neuro) arrives at: 29.708
# Patient № 36 started treatment at 29.708; queue time was 0.000
# Patient № 37 (Stroke) arrives at: 30.731
# Patient № 37 started treatment at 30.731; queue time was 0.000
# Patient № 38 (Stroke) arrives at: 31.812
# Patient № 38 started treatment at 31.812; queue time was 0.000
# Patient № 39 (Neuro) arrives at: 34.158
# Patient № 39 started treatment at 34.158; queue time was 0.000
# Patient № 40 (Stroke) arrives at: 34.611
# Patient № 40 started treatment at 34.611; queue time was 0.000
# Patient № 41 (Stroke) arrives at: 34.723
# Patient № 41 started treatment at 34.723; queue time was 0.000
# Patient № 42 (Stroke) arrives at: 35.874
# Patient № 42 started treatment at 35.874; queue time was 0.000
# Patient № 43 (Stroke) arrives at: 36.607
# Patient № 43 started treatment at 36.607; queue time was 0.000
# Patient № 44 (Stroke) arrives at: 36.902
# Patient № 44 started treatment at 36.902; queue time was 0.000
# Patient № 45 (Stroke) arrives at: 36.970
# Patient № 45 started treatment at 36.970; queue time was 0.000
# Patient № 46 (TIA) arrives at: 37.050
# Patient № 46 started treatment at 37.050; queue time was 0.000
# Patient № 47 (Stroke) arrives at: 37.856
# Patient № 47 started treatment at 37.856; queue time was 0.000
# Patient № 48 (Stroke) arrives at: 38.707
# Patient № 48 started treatment at 38.707; queue time was 0.000
# Patient № 49 (Stroke) arrives at: 38.811
# Patient № 50 (Stroke) arrives at: 39.157
# Patient № 51 (Stroke) arrives at: 39.505
# Patient № 49 started treatment at 39.856; queue time was 1.044
# Patient № 50 started treatment at 39.904; queue time was 0.747
# Patient № 51 started treatment at 40.075; queue time was 0.569
# Patient № 52 (Stroke) arrives at: 40.178
# Patient № 52 started treatment at 40.255; queue time was 0.077
# Patient № 53 (Stroke) arrives at: 40.314
# Patient № 54 (TIA) arrives at: 40.535
# Patient № 55 (Stroke) arrives at: 40.840
# Patient № 53 started treatment at 41.275; queue time was 0.961
# Patient № 56 (Stroke) arrives at: 41.369
# Patient № 54 started treatment at 41.538; queue time was 1.003
# Patient № 57 (TIA) arrives at: 42.293
# Patient № 58 (Neuro) arrives at: 42.488
# Patient № 55 started treatment at 42.645; queue time was 1.805
# Patient № 59 (Neuro) arrives at: 43.051
# Patient № 56 started treatment at 43.314; queue time was 1.945
# Patient № 60 (Stroke) arrives at: 43.563
# Patient № 61 (Stroke) arrives at: 43.728
# Patient № 57 started treatment at 43.776; queue time was 1.483
# Patient № 58 started treatment at 44.730; queue time was 2.242
# Patient № 62 (TIA) arrives at: 45.222
# Patient № 63 (Stroke) arrives at: 45.239
# Patient № 59 started treatment at 45.707; queue time was 2.656
# Patient № 64 (Stroke) arrives at: 46.359
# Patient № 60 started treatment at 46.515; queue time was 2.952
# Patient № 61 started treatment at 46.744; queue time was 3.016
# Patient № 62 started treatment at 46.773; queue time was 1.551
# Patient № 63 started treatment at 47.079; queue time was 1.840
# Patient № 65 (Stroke) arrives at: 47.168
# Patient № 64 started treatment at 47.197; queue time was 0.837
# Patient № 65 started treatment at 47.233; queue time was 0.064
# Patient № 66 (Neuro) arrives at: 48.135
# Patient № 66 started treatment at 48.135; queue time was 0.000
# Patient № 67 (Stroke) arrives at: 48.553
# Patient № 67 started treatment at 48.854; queue time was 0.301
# Patient № 68 (Neuro) arrives at: 49.155
# Patient № 69 (Neuro) arrives at: 49.333
# Patient № 70 (Stroke) arrives at: 49.377
# Patient № 68 started treatment at 49.916; queue time was 0.762
# Patient № 69 started treatment at 50.205; queue time was 0.871
# Patient № 70 started treatment at 50.476; queue time was 1.100
# Patient № 71 (Stroke) arrives at: 50.965
# Patient № 71 started treatment at 51.288; queue time was 0.323
# Patient № 72 (Neuro) arrives at: 51.417
# Patient № 72 started treatment at 51.522; queue time was 0.105
# Patient № 73 (TIA) arrives at: 51.524
# Patient № 73 started treatment at 51.786; queue time was 0.263
# Patient № 74 (Neuro) arrives at: 52.391
# Patient № 74 started treatment at 52.391; queue time was 0.000
# Patient № 75 (Stroke) arrives at: 53.379
# Patient № 75 started treatment at 53.379; queue time was 0.000
# Patient № 76 (Neuro) arrives at: 53.808
# Patient № 76 started treatment at 53.808; queue time was 0.000
# Patient № 77 (Stroke) arrives at: 54.239
# Patient № 77 started treatment at 54.239; queue time was 0.000
# Patient № 78 (Neuro) arrives at: 54.767
# Patient № 78 started treatment at 54.767; queue time was 0.000
# Patient № 79 (Neuro) arrives at: 55.372
# Patient № 79 started treatment at 55.372; queue time was 0.000
# Patient № 80 (Stroke) arrives at: 55.816
# Patient № 80 started treatment at 55.816; queue time was 0.000
# Patient № 81 (Stroke) arrives at: 56.721
# Patient № 81 started treatment at 56.721; queue time was 0.000
# Patient № 82 (Stroke) arrives at: 57.295
# Patient № 82 started treatment at 57.295; queue time was 0.000
# Patient № 83 (Stroke) arrives at: 58.125
# Patient № 83 started treatment at 58.125; queue time was 0.000
# Patient № 84 (Neuro) arrives at: 58.591
# Patient № 84 started treatment at 58.591; queue time was 0.000
# Patient № 85 (Stroke) arrives at: 59.408
# Patient № 85 started treatment at 59.408; queue time was 0.000
# Patient № 86 (Neuro) arrives at: 60.822
# Patient № 86 started treatment at 60.822; queue time was 0.000
# Patient № 87 (Stroke) arrives at: 60.885
# Patient № 87 started treatment at 60.885; queue time was 0.000
# Patient № 88 (Stroke) arrives at: 61.762
# Patient № 88 started treatment at 61.786; queue time was 0.025
# Patient № 89 (Stroke) arrives at: 63.207
# Patient № 89 started treatment at 63.207; queue time was 0.000
# Patient № 90 (Neuro) arrives at: 64.206
# Patient № 90 started treatment at 64.206; queue time was 0.000
# Patient № 91 (Stroke) arrives at: 64.269
# Patient № 91 started treatment at 64.269; queue time was 0.000
# Patient № 92 (Stroke) arrives at: 65.179
# Patient № 92 started treatment at 65.179; queue time was 0.000
# Patient № 93 (Neuro) arrives at: 65.881
# Patient № 94 (Neuro) arrives at: 65.932
# Patient № 93 started treatment at 66.585; queue time was 0.704
# Patient № 94 started treatment at 67.603; queue time was 1.671
# Patient № 95 (Neuro) arrives at: 69.973
# Patient № 95 started treatment at 69.973; queue time was 0.000
# Patient № 96 (Stroke) arrives at: 70.538
# Patient № 96 started treatment at 70.538; queue time was 0.000
# Patient № 97 (Neuro) arrives at: 71.187
# Patient № 97 started treatment at 71.187; queue time was 0.000
# Patient № 98 (Neuro) arrives at: 72.377
# Patient № 98 started treatment at 72.377; queue time was 0.000
# Patient № 99 (Stroke) arrives at: 72.391
# Patient № 99 started treatment at 72.391; queue time was 0.000
# Patient № 100 (Stroke) arrives at: 72.616
# Patient № 100 started treatment at 72.616; queue time was 0.000
# Patient № 101 (Stroke) arrives at: 72.630
# Patient № 101 started treatment at 72.630; queue time was 0.000
# Patient № 102 (Neuro) arrives at: 72.699
# Patient № 102 started treatment at 73.361; queue time was 0.662
# Patient № 103 (Stroke) arrives at: 73.576
# Patient № 103 started treatment at 73.611; queue time was 0.035
# Patient № 104 (TIA) arrives at: 73.727
# Patient № 104 started treatment at 73.727; queue time was 0.000
# Patient № 105 (Neuro) arrives at: 74.011
# Patient № 105 started treatment at 74.011; queue time was 0.000
# Patient № 106 (Neuro) arrives at: 74.556
# Patient № 106 started treatment at 74.556; queue time was 0.000
# Patient № 107 (Neuro) arrives at: 75.048
# Patient № 107 started treatment at 75.048; queue time was 0.000
# Patient № 108 (TIA) arrives at: 75.279
# Patient № 108 started treatment at 75.279; queue time was 0.000
# Patient № 109 (Stroke) arrives at: 75.844
# Patient № 109 started treatment at 75.844; queue time was 0.000
# Patient № 110 (TIA) arrives at: 76.947
# Patient № 110 started treatment at 76.947; queue time was 0.000
# Patient № 111 (Stroke) arrives at: 77.753
# Patient № 111 started treatment at 77.753; queue time was 0.000
# Patient № 112 (Stroke) arrives at: 78.091
# Patient № 112 started treatment at 78.091; queue time was 0.000
# Patient № 113 (Stroke) arrives at: 78.504
# Patient № 113 started treatment at 78.504; queue time was 0.000
# Patient № 114 (Stroke) arrives at: 80.614
# Patient № 114 started treatment at 80.614; queue time was 0.000
# Patient № 115 (Stroke) arrives at: 80.827
# Patient № 115 started treatment at 80.827; queue time was 0.000
# Patient № 116 (Stroke) arrives at: 81.136
# Patient № 116 started treatment at 81.136; queue time was 0.000
# Patient № 117 (Neuro) arrives at: 81.253
# Patient № 117 started treatment at 81.899; queue time was 0.646
# Patient № 118 (Neuro) arrives at: 81.925
# Patient № 118 started treatment at 82.669; queue time was 0.744
# Patient № 119 (Stroke) arrives at: 82.730
# Patient № 119 started treatment at 82.734; queue time was 0.004
# Patient № 120 (Stroke) arrives at: 83.424
# Patient № 120 started treatment at 83.424; queue time was 0.000
# Patient № 121 (Stroke) arrives at: 83.678
# Patient № 122 (Stroke) arrives at: 84.272
# Patient № 123 (Stroke) arrives at: 84.419
# Patient № 124 (Neuro) arrives at: 84.700
# Patient № 121 started treatment at 84.754; queue time was 1.076
# Patient № 125 (Stroke) arrives at: 84.909
# Patient № 122 started treatment at 85.208; queue time was 0.936
# Patient № 123 started treatment at 85.320; queue time was 0.901
# Patient № 124 started treatment at 85.968; queue time was 1.268
# Patient № 126 (Stroke) arrives at: 86.067
# Patient № 125 started treatment at 87.230; queue time was 2.320
# Patient № 127 (Stroke) arrives at: 87.871
# Patient № 126 started treatment at 88.479; queue time was 2.411
# Patient № 128 (Stroke) arrives at: 88.775
# Patient № 127 started treatment at 89.050; queue time was 1.179
# Patient № 128 started treatment at 90.357; queue time was 1.582
# Patient № 129 (Stroke) arrives at: 91.133
# Patient № 129 started treatment at 91.133; queue time was 0.000
# Patient № 130 (Neuro) arrives at: 91.632
# Patient № 130 started treatment at 91.632; queue time was 0.000
# Patient № 131 (Stroke) arrives at: 93.452
# Patient № 131 started treatment at 93.452; queue time was 0.000
# Patient № 132 (Stroke) arrives at: 93.740
# Patient № 132 started treatment at 93.740; queue time was 0.000
# Patient № 133 (Neuro) arrives at: 94.056
# Patient № 133 started treatment at 94.056; queue time was 0.000
# Patient № 134 (Stroke) arrives at: 95.118
# Patient № 134 started treatment at 95.118; queue time was 0.000
# Patient № 135 (Neuro) arrives at: 95.588
# Patient № 135 started treatment at 95.588; queue time was 0.000
# Patient № 136 (Stroke) arrives at: 95.607
# Patient № 136 started treatment at 95.607; queue time was 0.000
# Patient № 137 (TIA) arrives at: 95.683
# Patient № 137 started treatment at 95.683; queue time was 0.000
# Patient № 138 (TIA) arrives at: 96.199
# Patient № 139 (Stroke) arrives at: 96.688
# Patient № 138 started treatment at 96.700; queue time was 0.501
# Patient № 139 started treatment at 97.262; queue time was 0.574
# Patient № 140 (Stroke) arrives at: 97.617
# Patient № 141 (Stroke) arrives at: 98.233
# Patient № 140 started treatment at 98.942; queue time was 1.325
# Patient № 142 (Stroke) arrives at: 99.201
# Patient № 141 started treatment at 99.306; queue time was 1.073
# Patient № 142 started treatment at 99.825; queue time was 0.624
# Patient № 143 (Neuro) arrives at: 101.143
# Patient № 144 (Neuro) arrives at: 101.518
# Patient № 143 started treatment at 101.858; queue time was 0.716
# Patient № 145 (Stroke) arrives at: 101.915
# Patient № 146 (Stroke) arrives at: 102.028
# Patient № 147 (Stroke) arrives at: 102.135
# Patient № 144 started treatment at 102.234; queue time was 0.717
# Patient № 145 started treatment at 102.830; queue time was 0.914
# Patient № 148 (Stroke) arrives at: 103.443
# Patient № 146 started treatment at 104.515; queue time was 2.487
# Patient № 147 started treatment at 104.937; queue time was 2.802
# Patient № 149 (Neuro) arrives at: 105.339
# Patient № 148 started treatment at 105.764; queue time was 2.320
# Patient № 149 started treatment at 105.847; queue time was 0.508
# Patient № 150 (Stroke) arrives at: 106.533
# Patient № 151 (TIA) arrives at: 106.784
# Patient № 150 started treatment at 107.629; queue time was 1.096
# Patient № 151 started treatment at 108.193; queue time was 1.409
# Patient № 152 (Stroke) arrives at: 108.282
# Patient № 152 started treatment at 108.282; queue time was 0.000
# Patient № 153 (Stroke) arrives at: 108.307
# Patient № 153 started treatment at 108.499; queue time was 0.192
# Patient № 154 (Stroke) arrives at: 108.615
# Patient № 154 started treatment at 108.623; queue time was 0.008
# Patient № 155 (TIA) arrives at: 109.100
# Patient № 156 (Neuro) arrives at: 109.472
# Patient № 155 started treatment at 110.142; queue time was 1.042
# Patient № 156 started treatment at 110.346; queue time was 0.874
# Patient № 157 (Stroke) arrives at: 110.674
# Patient № 157 started treatment at 110.674; queue time was 0.000
# Patient № 158 (Stroke) arrives at: 111.030
# Patient № 158 started treatment at 112.145; queue time was 1.115
# Patient № 159 (Stroke) arrives at: 112.636
# Patient № 160 (Stroke) arrives at: 112.663
# Patient № 161 (Stroke) arrives at: 112.775
# Patient № 162 (Neuro) arrives at: 112.951
# Patient № 159 started treatment at 112.971; queue time was 0.335
# Patient № 163 (Stroke) arrives at: 113.708
# Patient № 160 started treatment at 113.933; queue time was 1.270
# Patient № 164 (Stroke) arrives at: 114.182
# Patient № 165 (Stroke) arrives at: 114.701
# Patient № 161 started treatment at 115.017; queue time was 2.242
# Patient № 162 started treatment at 115.843; queue time was 2.892
# Patient № 166 (Neuro) arrives at: 116.521
# Patient № 167 (Stroke) arrives at: 116.767
# Patient № 168 (Neuro) arrives at: 116.803
# Patient № 163 started treatment at 117.409; queue time was 3.701
# Patient № 164 started treatment at 117.735; queue time was 3.552
# Patient № 169 (Neuro) arrives at: 117.865
# Patient № 170 (Stroke) arrives at: 118.350
# Patient № 165 started treatment at 118.684; queue time was 3.983
# Patient № 166 started treatment at 118.821; queue time was 2.300
# Patient № 167 started treatment at 118.854; queue time was 2.087
# Patient № 171 (Stroke) arrives at: 119.266
# Patient № 168 started treatment at 119.338; queue time was 2.535
# Patient № 169 started treatment at 119.690; queue time was 1.825
# Patient № 170 started treatment at 119.784; queue time was 1.433
# Patient № 171 started treatment at 119.796; queue time was 0.530
# Patient № 172 (Stroke) arrives at: 120.572
# Patient № 173 (Stroke) arrives at: 120.944
# Patient № 174 (Stroke) arrives at: 121.087
# Patient № 175 (Stroke) arrives at: 121.359
# Patient № 176 (Stroke) arrives at: 121.542
# Patient № 177 (Stroke) arrives at: 121.649
# Patient № 178 (Neuro) arrives at: 122.629
# Patient № 179 (Stroke) arrives at: 122.659
# Patient № 172 started treatment at 122.765; queue time was 2.193
# Patient № 180 (Stroke) arrives at: 123.486
# Patient № 181 (Stroke) arrives at: 124.308
# Patient № 173 started treatment at 124.460; queue time was 3.516
# Patient № 174 started treatment at 124.640; queue time was 3.553
# Patient № 182 (Stroke) arrives at: 125.409
# Patient № 175 started treatment at 125.921; queue time was 4.562
# Patient № 176 started treatment at 126.554; queue time was 5.012
# Patient № 177 started treatment at 126.955; queue time was 5.306
# Patient № 183 (Stroke) arrives at: 127.450
# Patient № 178 started treatment at 127.506; queue time was 4.877
# Patient № 184 (Stroke) arrives at: 128.204
# Patient № 185 (Stroke) arrives at: 128.850
# Patient № 186 (Neuro) arrives at: 129.226
# Patient № 179 started treatment at 129.326; queue time was 6.668
# Patient № 180 started treatment at 129.386; queue time was 5.901
# Patient № 181 started treatment at 129.856; queue time was 5.548
# Patient № 182 started treatment at 129.880; queue time was 4.471
# Patient № 183 started treatment at 130.384; queue time was 2.934
# Patient № 187 (Neuro) arrives at: 130.529
# Patient № 184 started treatment at 131.021; queue time was 2.817
# Patient № 188 (Stroke) arrives at: 132.466
# Patient № 189 (Stroke) arrives at: 132.921
# Patient № 190 (Stroke) arrives at: 132.931
# Patient № 185 started treatment at 133.010; queue time was 4.161
# Patient № 186 started treatment at 133.081; queue time was 3.855
# Patient № 191 (Stroke) arrives at: 133.411
# Patient № 187 started treatment at 134.025; queue time was 3.496
# Patient № 192 (Stroke) arrives at: 134.531
# Patient № 188 started treatment at 134.738; queue time was 2.273
# Patient № 189 started treatment at 134.847; queue time was 1.926
# Patient № 190 started treatment at 135.243; queue time was 2.312
# Patient № 191 started treatment at 136.239; queue time was 2.828
# Patient № 192 started treatment at 136.840; queue time was 2.309
# Patient № 193 (Stroke) arrives at: 137.319
# Patient № 193 started treatment at 137.325; queue time was 0.007
# Patient № 194 (TIA) arrives at: 137.346
# Patient № 195 (Stroke) arrives at: 137.767
# Patient № 196 (Stroke) arrives at: 138.307
# Patient № 197 (Stroke) arrives at: 139.067
# Patient № 194 started treatment at 139.466; queue time was 2.120
# Patient № 198 (Stroke) arrives at: 140.466
# Patient № 195 started treatment at 140.968; queue time was 3.201
# Patient № 196 started treatment at 141.164; queue time was 2.857
# Patient № 199 (Stroke) arrives at: 141.212
# Patient № 197 started treatment at 142.274; queue time was 3.207
# Patient № 198 started treatment at 142.424; queue time was 1.957
# Patient № 199 started treatment at 142.595; queue time was 1.384
# Patient № 200 (Stroke) arrives at: 143.665
# Patient № 200 started treatment at 143.665; queue time was 0.000
# Patient № 201 (TIA) arrives at: 143.713
# Patient № 202 (TIA) arrives at: 144.061
# Patient № 203 (Stroke) arrives at: 144.465
# Patient № 201 started treatment at 144.548; queue time was 0.835
# Patient № 204 (Stroke) arrives at: 144.607
# Patient № 202 started treatment at 144.628; queue time was 0.567
# Patient № 205 (Stroke) arrives at: 144.687
# Patient № 203 started treatment at 144.897; queue time was 0.432
# Patient № 206 (Neuro) arrives at: 144.947
# Patient № 207 (Stroke) arrives at: 144.976
# Patient № 208 (Stroke) arrives at: 145.055
# Patient № 209 (Stroke) arrives at: 145.509
# Patient № 210 (TIA) arrives at: 145.645
# Patient № 211 (Stroke) arrives at: 145.802
# Patient № 204 started treatment at 145.803; queue time was 1.196
# Patient № 205 started treatment at 145.812; queue time was 1.125
# Patient № 206 started treatment at 145.872; queue time was 0.925
# Patient № 207 started treatment at 146.342; queue time was 1.366
# Patient № 208 started treatment at 147.169; queue time was 2.114
# Patient № 209 started treatment at 148.348; queue time was 2.839
# Patient № 210 started treatment at 148.384; queue time was 2.739
# Patient № 211 started treatment at 148.440; queue time was 2.638
# Patient № 212 (Stroke) arrives at: 148.450
# Patient № 212 started treatment at 148.523; queue time was 0.073
# Patient № 213 (Stroke) arrives at: 150.932
# Patient № 213 started treatment at 150.932; queue time was 0.000
# Patient № 214 (Stroke) arrives at: 151.962
# Patient № 214 started treatment at 151.962; queue time was 0.000
# Patient № 215 (Stroke) arrives at: 152.569
# Patient № 215 started treatment at 152.569; queue time was 0.000
# Patient № 216 (Neuro) arrives at: 153.616
# Patient № 216 started treatment at 153.616; queue time was 0.000
# Patient № 217 (Stroke) arrives at: 154.925
# Patient № 217 started treatment at 154.925; queue time was 0.000
# Patient № 218 (Stroke) arrives at: 155.153
# Patient № 218 started treatment at 155.153; queue time was 0.000
# Patient № 219 (Neuro) arrives at: 156.169
# Patient № 219 started treatment at 156.169; queue time was 0.000
# Patient № 220 (Stroke) arrives at: 156.820
# Patient № 220 started treatment at 156.820; queue time was 0.000
# Patient № 221 (TIA) arrives at: 156.857
# Patient № 221 started treatment at 156.857; queue time was 0.000
# Patient № 222 (Stroke) arrives at: 157.298
# Patient № 222 started treatment at 157.298; queue time was 0.000
# Patient № 223 (Stroke) arrives at: 158.093
# Patient № 223 started treatment at 158.093; queue time was 0.000
# Patient № 224 (Stroke) arrives at: 158.993
# Patient № 224 started treatment at 158.993; queue time was 0.000
# Patient № 225 (Stroke) arrives at: 159.042
# Patient № 225 started treatment at 159.042; queue time was 0.000
# Patient № 226 (Stroke) arrives at: 160.382
# Patient № 226 started treatment at 160.382; queue time was 0.000
# Patient № 227 (Stroke) arrives at: 160.850
# Patient № 227 started treatment at 160.850; queue time was 0.000
# Patient № 228 (Stroke) arrives at: 161.117
# Patient № 228 started treatment at 161.117; queue time was 0.000
# Patient № 229 (Stroke) arrives at: 162.352
# Patient № 229 started treatment at 162.352; queue time was 0.000
# Patient № 230 (Stroke) arrives at: 163.532
# Patient № 230 started treatment at 163.532; queue time was 0.000
# Patient № 231 (Stroke) arrives at: 163.948
# Patient № 231 started treatment at 163.948; queue time was 0.000
# Patient № 232 (Stroke) arrives at: 164.135
# Patient № 232 started treatment at 164.135; queue time was 0.000
# Patient № 233 (Neuro) arrives at: 164.591
# Patient № 233 started treatment at 164.806; queue time was 0.215
# Patient № 234 (Stroke) arrives at: 165.439
# Patient № 234 started treatment at 165.439; queue time was 0.000
# Patient № 235 (Stroke) arrives at: 166.658
# Patient № 235 started treatment at 166.658; queue time was 0.000
# Patient № 236 (Neuro) arrives at: 167.169
# Patient № 236 started treatment at 167.169; queue time was 0.000
# Patient № 237 (Stroke) arrives at: 168.260
# Patient № 237 started treatment at 168.260; queue time was 0.000
# Patient № 238 (Stroke) arrives at: 170.700
# Patient № 238 started treatment at 170.700; queue time was 0.000
# Patient № 239 (Stroke) arrives at: 171.771
# Patient № 239 started treatment at 171.771; queue time was 0.000
# Patient № 240 (Stroke) arrives at: 172.094
# Patient № 240 started treatment at 172.094; queue time was 0.000
# Patient № 241 (Neuro) arrives at: 173.027
# Patient № 241 started treatment at 173.027; queue time was 0.000
# Patient № 242 (Neuro) arrives at: 173.532
# Patient № 242 started treatment at 173.532; queue time was 0.000
# Patient № 243 (Stroke) arrives at: 174.330
# Patient № 243 started treatment at 174.330; queue time was 0.000
# Patient № 244 (Neuro) arrives at: 174.456
# Patient № 244 started treatment at 174.456; queue time was 0.000
# Patient № 245 (TIA) arrives at: 174.743
# Patient № 245 started treatment at 174.743; queue time was 0.000
# Patient № 246 (Neuro) arrives at: 175.227
# Patient № 246 started treatment at 175.227; queue time was 0.000
# Patient № 247 (Stroke) arrives at: 176.313
# Patient № 247 started treatment at 176.313; queue time was 0.000
# Patient № 248 (Stroke) arrives at: 176.434
# Patient № 248 started treatment at 176.434; queue time was 0.000
# Patient № 249 (Stroke) arrives at: 177.497
# Patient № 249 started treatment at 177.497; queue time was 0.000
# Patient № 250 (Stroke) arrives at: 178.105
# Patient № 250 started treatment at 178.105; queue time was 0.000
# Patient № 251 (Stroke) arrives at: 178.600
# Patient № 251 started treatment at 178.600; queue time was 0.000
# Patient № 252 (Stroke) arrives at: 178.670
# Patient № 252 started treatment at 178.670; queue time was 0.000
# Patient № 253 (Stroke) arrives at: 180.031
# Patient № 253 started treatment at 180.031; queue time was 0.000
# Patient № 254 (Stroke) arrives at: 180.243
# Patient № 254 started treatment at 180.243; queue time was 0.000
# Patient № 255 (Neuro) arrives at: 181.849
# Patient № 255 started treatment at 181.849; queue time was 0.000
# Patient № 256 (Stroke) arrives at: 181.885
# Patient № 256 started treatment at 181.885; queue time was 0.000
# Patient № 257 (Stroke) arrives at: 181.958
# Patient № 258 (Stroke) arrives at: 182.005
# Patient № 257 started treatment at 182.187; queue time was 0.229
# Patient № 259 (Neuro) arrives at: 182.527
# Patient № 258 started treatment at 182.588; queue time was 0.583
# Patient № 259 started treatment at 182.743; queue time was 0.217
# Patient № 260 (Stroke) arrives at: 182.791
# Patient № 260 started treatment at 182.791; queue time was 0.000
# Patient № 261 (Stroke) arrives at: 183.016
# Patient № 261 started treatment at 183.326; queue time was 0.310
# Patient № 262 (Stroke) arrives at: 186.497
# Patient № 262 started treatment at 186.497; queue time was 0.000
# Patient № 263 (Neuro) arrives at: 187.351
# Patient № 263 started treatment at 187.351; queue time was 0.000
# Patient № 264 (Stroke) arrives at: 187.892
# Patient № 264 started treatment at 187.892; queue time was 0.000
# Patient № 265 (Stroke) arrives at: 189.434
# Patient № 265 started treatment at 189.434; queue time was 0.000
# Patient № 266 (Stroke) arrives at: 190.330
# Patient № 266 started treatment at 190.330; queue time was 0.000
# Patient № 267 (Neuro) arrives at: 190.709
# Patient № 267 started treatment at 190.709; queue time was 0.000
# Patient № 268 (Neuro) arrives at: 190.831
# Patient № 268 started treatment at 190.831; queue time was 0.000
# Patient № 269 (TIA) arrives at: 191.227
# Patient № 269 started treatment at 191.227; queue time was 0.000
# Patient № 270 (Stroke) arrives at: 194.336
# Patient № 270 started treatment at 194.336; queue time was 0.000
# Patient № 271 (TIA) arrives at: 194.589
# Patient № 271 started treatment at 194.589; queue time was 0.000
# Patient № 272 (Stroke) arrives at: 194.769
# Patient № 272 started treatment at 194.769; queue time was 0.000
# Patient № 273 (TIA) arrives at: 194.913
# Patient № 273 started treatment at 194.913; queue time was 0.000
# Patient № 274 (Neuro) arrives at: 196.933
# Patient № 274 started treatment at 196.933; queue time was 0.000
# Patient № 275 (Stroke) arrives at: 197.655
# Patient № 275 started treatment at 197.655; queue time was 0.000
# Patient № 276 (Stroke) arrives at: 197.911
# Patient № 276 started treatment at 197.911; queue time was 0.000
# Patient № 277 (Stroke) arrives at: 198.912
# Patient № 277 started treatment at 198.912; queue time was 0.000
# Patient № 278 (Neuro) arrives at: 199.200
# Patient № 278 started treatment at 199.200; queue time was 0.000
# Patient № 279 (Stroke) arrives at: 199.902
# Patient № 279 started treatment at 199.902; queue time was 0.000
# Patient № 280 (Stroke) arrives at: 204.897
# Patient № 280 started treatment at 204.897; queue time was 0.000
# Patient № 281 (Stroke) arrives at: 205.561
# Patient № 281 started treatment at 205.561; queue time was 0.000
# Patient № 282 (TIA) arrives at: 205.964
# Patient № 282 started treatment at 205.964; queue time was 0.000
# Patient № 283 (Stroke) arrives at: 206.494
# Patient № 283 started treatment at 206.494; queue time was 0.000
# Patient № 284 (Stroke) arrives at: 208.162
# Patient № 284 started treatment at 208.162; queue time was 0.000
# Patient № 285 (Neuro) arrives at: 208.937
# Patient № 285 started treatment at 208.937; queue time was 0.000
# Patient № 286 (Stroke) arrives at: 209.001
# Patient № 286 started treatment at 209.001; queue time was 0.000
# Patient № 287 (Stroke) arrives at: 209.580
# Patient № 287 started treatment at 209.580; queue time was 0.000
# Patient № 288 (Neuro) arrives at: 209.724
# Patient № 288 started treatment at 209.724; queue time was 0.000
# Patient № 289 (Neuro) arrives at: 210.186
# Patient № 289 started treatment at 210.686; queue time was 0.499
# Patient № 290 (Stroke) arrives at: 212.029
# Patient № 290 started treatment at 212.029; queue time was 0.000
# Patient № 291 (Neuro) arrives at: 212.089
# Patient № 292 (Neuro) arrives at: 212.488
# Patient № 293 (Neuro) arrives at: 212.722
# Patient № 294 (Stroke) arrives at: 212.728
# Patient № 295 (Neuro) arrives at: 212.879
# Patient № 296 (Stroke) arrives at: 213.553
# Patient № 297 (Neuro) arrives at: 213.582
# Patient № 291 started treatment at 214.656; queue time was 2.567
# Patient № 292 started treatment at 214.859; queue time was 2.371
# Patient № 298 (TIA) arrives at: 214.920
# Patient № 293 started treatment at 215.034; queue time was 2.312
# Patient № 299 (Stroke) arrives at: 215.076
# Patient № 294 started treatment at 215.329; queue time was 2.601
# Patient № 300 (Stroke) arrives at: 215.379
# Patient № 295 started treatment at 215.496; queue time was 2.618
# Patient № 296 started treatment at 215.647; queue time was 2.094
# Patient № 297 started treatment at 215.966; queue time was 2.384
# Patient № 301 (Stroke) arrives at: 216.051
# Patient № 302 (TIA) arrives at: 216.514
# Patient № 298 started treatment at 216.994; queue time was 2.073
# Patient № 299 started treatment at 217.136; queue time was 2.060
# Patient № 300 started treatment at 217.143; queue time was 1.763
# Patient № 301 started treatment at 217.168; queue time was 1.118
# Patient № 302 started treatment at 217.169; queue time was 0.655
# Patient № 303 (Stroke) arrives at: 218.682
# Patient № 303 started treatment at 218.682; queue time was 0.000
# Patient № 304 (Stroke) arrives at: 219.106
# Patient № 304 started treatment at 219.106; queue time was 0.000
# Patient № 305 (Stroke) arrives at: 220.708
# Patient № 305 started treatment at 220.708; queue time was 0.000
# Patient № 306 (Stroke) arrives at: 222.480
# Patient № 306 started treatment at 222.480; queue time was 0.000
# Patient № 307 (Neuro) arrives at: 223.513
# Patient № 307 started treatment at 223.513; queue time was 0.000
# Patient № 308 (Stroke) arrives at: 223.727
# Patient № 308 started treatment at 224.139; queue time was 0.412
# Patient № 309 (Stroke) arrives at: 224.839
# Patient № 309 started treatment at 224.839; queue time was 0.000
# Patient № 310 (Stroke) arrives at: 227.059
# Patient № 310 started treatment at 227.059; queue time was 0.000
# Patient № 311 (Stroke) arrives at: 229.587
# Patient № 311 started treatment at 229.587; queue time was 0.000
# Patient № 312 (Stroke) arrives at: 229.624
# Patient № 312 started treatment at 229.624; queue time was 0.000
# Patient № 313 (Stroke) arrives at: 229.674
# Patient № 313 started treatment at 229.674; queue time was 0.000
# Patient № 314 (Stroke) arrives at: 231.476
# Patient № 314 started treatment at 231.476; queue time was 0.000
# Patient № 315 (TIA) arrives at: 231.629
# Patient № 315 started treatment at 231.629; queue time was 0.000
# Patient № 316 (Stroke) arrives at: 231.633
# Patient № 316 started treatment at 231.633; queue time was 0.000
# Patient № 317 (Stroke) arrives at: 231.920
# Patient № 317 started treatment at 231.920; queue time was 0.000
# Patient № 318 (Neuro) arrives at: 232.970
# Patient № 318 started treatment at 232.970; queue time was 0.000
# Patient № 319 (Neuro) arrives at: 233.747
# Patient № 319 started treatment at 233.747; queue time was 0.000
# Patient № 320 (Stroke) arrives at: 234.355
# Patient № 320 started treatment at 234.355; queue time was 0.000
# Patient № 321 (Stroke) arrives at: 235.371
# Patient № 321 started treatment at 235.371; queue time was 0.000
# Patient № 322 (Stroke) arrives at: 236.144
# Patient № 322 started treatment at 236.144; queue time was 0.000
# Patient № 323 (Stroke) arrives at: 236.924
# Patient № 323 started treatment at 236.924; queue time was 0.000
# Patient № 324 (Stroke) arrives at: 238.454
# Patient № 324 started treatment at 238.454; queue time was 0.000
# Patient № 325 (Neuro) arrives at: 239.204
# Patient № 325 started treatment at 239.204; queue time was 0.000
# Patient № 326 (TIA) arrives at: 239.503
# Patient № 326 started treatment at 239.609; queue time was 0.106
# Patient № 327 (Stroke) arrives at: 242.572
# Patient № 327 started treatment at 242.572; queue time was 0.000
# Patient № 328 (Stroke) arrives at: 244.129
# Patient № 328 started treatment at 244.129; queue time was 0.000
# Patient № 329 (Stroke) arrives at: 245.305
# Patient № 329 started treatment at 245.305; queue time was 0.000
# Patient № 330 (Stroke) arrives at: 246.014
# Patient № 330 started treatment at 246.014; queue time was 0.000
# Patient № 331 (TIA) arrives at: 246.802
# Patient № 331 started treatment at 246.802; queue time was 0.000
# Patient № 332 (Neuro) arrives at: 247.783
# Patient № 332 started treatment at 247.783; queue time was 0.000
# Patient № 333 (Stroke) arrives at: 249.521
# Patient № 333 started treatment at 249.521; queue time was 0.000
# Patient № 334 (Neuro) arrives at: 249.772
# Patient № 334 started treatment at 249.772; queue time was 0.000
# Patient № 335 (Stroke) arrives at: 250.647
# Patient № 335 started treatment at 250.647; queue time was 0.000
# Patient № 336 (Stroke) arrives at: 251.213
# Patient № 336 started treatment at 251.213; queue time was 0.000
# Patient № 337 (Stroke) arrives at: 251.310
# Patient № 337 started treatment at 251.310; queue time was 0.000
# Patient № 338 (Stroke) arrives at: 251.911
# Patient № 338 started treatment at 251.911; queue time was 0.000
# Patient № 339 (Stroke) arrives at: 254.280
# Patient № 339 started treatment at 254.280; queue time was 0.000
# Patient № 340 (Neuro) arrives at: 254.303
# Patient № 340 started treatment at 254.303; queue time was 0.000
# Patient № 341 (TIA) arrives at: 254.664
# Patient № 341 started treatment at 254.664; queue time was 0.000
# Patient № 342 (Stroke) arrives at: 256.353
# Patient № 342 started treatment at 256.353; queue time was 0.000
# Patient № 343 (Stroke) arrives at: 256.758
# Patient № 343 started treatment at 256.758; queue time was 0.000
# Patient № 344 (Stroke) arrives at: 256.917
# Patient № 344 started treatment at 256.917; queue time was 0.000
# Patient № 345 (Stroke) arrives at: 258.260
# Patient № 345 started treatment at 258.260; queue time was 0.000
# Patient № 346 (Neuro) arrives at: 259.179
# Patient № 346 started treatment at 259.179; queue time was 0.000
# Patient № 347 (Stroke) arrives at: 259.561
# Patient № 347 started treatment at 259.561; queue time was 0.000
# Patient № 348 (TIA) arrives at: 259.576
# Patient № 348 started treatment at 259.576; queue time was 0.000
# Patient № 349 (Stroke) arrives at: 259.716
# Patient № 349 started treatment at 259.716; queue time was 0.000
# Patient № 350 (TIA) arrives at: 260.016
# Patient № 350 started treatment at 260.016; queue time was 0.000
# Patient № 351 (TIA) arrives at: 261.316
# Patient № 351 started treatment at 261.316; queue time was 0.000
# Patient № 352 (Stroke) arrives at: 262.099
# Patient № 352 started treatment at 262.099; queue time was 0.000
# Patient № 353 (Stroke) arrives at: 262.449
# Patient № 353 started treatment at 262.449; queue time was 0.000
# Patient № 354 (Stroke) arrives at: 263.925
# Patient № 354 started treatment at 263.925; queue time was 0.000
# Patient № 355 (Stroke) arrives at: 264.107
# Patient № 355 started treatment at 264.107; queue time was 0.000
# Patient № 356 (Stroke) arrives at: 264.680
# Patient № 356 started treatment at 264.680; queue time was 0.000
# Patient № 357 (Stroke) arrives at: 266.674
# Patient № 357 started treatment at 266.674; queue time was 0.000
# Patient № 358 (Stroke) arrives at: 266.887
# Patient № 358 started treatment at 266.887; queue time was 0.000
# Patient № 359 (Neuro) arrives at: 267.775
# Patient № 359 started treatment at 267.775; queue time was 0.000
# Patient № 360 (Neuro) arrives at: 268.122
# Patient № 360 started treatment at 268.122; queue time was 0.000
# Patient № 361 (Neuro) arrives at: 268.501
# Patient № 361 started treatment at 268.501; queue time was 0.000
# Patient № 362 (Stroke) arrives at: 268.751
# Patient № 362 started treatment at 268.962; queue time was 0.211
# Patient № 363 (Stroke) arrives at: 270.267
# Patient № 363 started treatment at 270.267; queue time was 0.000
# Patient № 364 (Stroke) arrives at: 271.236
# Patient № 364 started treatment at 271.236; queue time was 0.000
# Patient № 365 (Stroke) arrives at: 271.371
# Patient № 366 (Stroke) arrives at: 271.653
# Patient № 365 started treatment at 271.705; queue time was 0.334
# Patient № 367 (Stroke) arrives at: 271.793
# Patient № 368 (Stroke) arrives at: 271.946
# Patient № 366 started treatment at 272.362; queue time was 0.710
# Patient № 369 (Neuro) arrives at: 272.416
# Patient № 370 (TIA) arrives at: 272.448
# Patient № 367 started treatment at 272.829; queue time was 1.036
# Patient № 371 (Stroke) arrives at: 272.939
# Patient № 372 (Stroke) arrives at: 272.948
# Patient № 368 started treatment at 273.014; queue time was 1.068
# Patient № 373 (Stroke) arrives at: 273.403
# Patient № 374 (Stroke) arrives at: 273.522
# Patient № 375 (Stroke) arrives at: 274.174
# Patient № 369 started treatment at 274.548; queue time was 2.133
# Patient № 370 started treatment at 274.552; queue time was 2.104
# Patient № 371 started treatment at 274.611; queue time was 1.672
# Patient № 376 (Stroke) arrives at: 274.627
# Patient № 372 started treatment at 274.662; queue time was 1.714
# Patient № 377 (Stroke) arrives at: 274.664
# Patient № 378 (Stroke) arrives at: 274.791
# Patient № 379 (Stroke) arrives at: 274.935
# Patient № 373 started treatment at 275.474; queue time was 2.071
# Patient № 380 (Stroke) arrives at: 275.823
# Patient № 374 started treatment at 276.286; queue time was 2.763
# Patient № 375 started treatment at 276.572; queue time was 2.399
# Patient № 381 (Stroke) arrives at: 276.724
# Patient № 376 started treatment at 277.017; queue time was 2.390
# Patient № 377 started treatment at 277.412; queue time was 2.748
# Patient № 378 started treatment at 277.589; queue time was 2.798
# Patient № 382 (Stroke) arrives at: 277.621
# Patient № 379 started treatment at 278.716; queue time was 3.781
# Patient № 383 (Stroke) arrives at: 279.281
# Patient № 384 (Stroke) arrives at: 279.450
# Patient № 380 started treatment at 279.521; queue time was 3.698
# Patient № 385 (Stroke) arrives at: 280.183
# Patient № 381 started treatment at 281.481; queue time was 4.757
# Patient № 386 (Stroke) arrives at: 281.563
# Patient № 382 started treatment at 282.056; queue time was 4.435
# Patient № 387 (Stroke) arrives at: 282.835
# Patient № 383 started treatment at 282.906; queue time was 3.625
# Patient № 388 (Stroke) arrives at: 283.735
# Patient № 389 (Neuro) arrives at: 284.274
# Patient № 384 started treatment at 284.945; queue time was 5.495
# Patient № 385 started treatment at 284.966; queue time was 4.783
# Patient № 386 started treatment at 285.113; queue time was 3.550
# Patient № 390 (TIA) arrives at: 285.203
# Patient № 387 started treatment at 285.476; queue time was 2.641
# Patient № 391 (Stroke) arrives at: 285.900
# Patient № 392 (Stroke) arrives at: 286.661
# Patient № 388 started treatment at 287.761; queue time was 4.026
# Patient № 393 (Stroke) arrives at: 287.915
# Patient № 389 started treatment at 287.945; queue time was 3.670
# Patient № 394 (TIA) arrives at: 288.309
# Patient № 395 (Stroke) arrives at: 288.550
# Patient № 396 (Stroke) arrives at: 288.778
# Patient № 390 started treatment at 289.022; queue time was 3.819
# Patient № 391 started treatment at 289.121; queue time was 3.221
# Patient № 392 started treatment at 289.445; queue time was 2.784
# Patient № 397 (Stroke) arrives at: 290.118
# Patient № 398 (Stroke) arrives at: 290.296
# Patient № 393 started treatment at 290.553; queue time was 2.638
# Patient № 399 (Stroke) arrives at: 290.711
# Patient № 394 started treatment at 291.527; queue time was 3.218
# Patient № 400 (TIA) arrives at: 291.599
# Patient № 401 (Stroke) arrives at: 291.821
# Patient № 402 (Stroke) arrives at: 291.922
# Patient № 395 started treatment at 292.159; queue time was 3.608
# Patient № 403 (Stroke) arrives at: 292.160
# Patient № 404 (TIA) arrives at: 292.460
# Patient № 396 started treatment at 292.671; queue time was 3.893
# Patient № 397 started treatment at 292.718; queue time was 2.601
# Patient № 398 started treatment at 292.967; queue time was 2.671
# Patient № 405 (Stroke) arrives at: 293.081
# Patient № 406 (Stroke) arrives at: 293.839
# Patient № 399 started treatment at 294.102; queue time was 3.391
# Patient № 400 started treatment at 294.332; queue time was 2.733
# Patient № 401 started treatment at 294.835; queue time was 3.014
# Patient № 402 started treatment at 295.151; queue time was 3.229
# Patient № 407 (Neuro) arrives at: 295.328
# Patient № 403 started treatment at 295.781; queue time was 3.622
# Patient № 404 started treatment at 296.667; queue time was 4.207
# Patient № 405 started treatment at 297.744; queue time was 4.662
# Patient № 408 (Stroke) arrives at: 298.149
# Patient № 409 (Neuro) arrives at: 298.468
# Patient № 410 (Stroke) arrives at: 298.835
# Patient № 411 (Stroke) arrives at: 298.918
# Patient № 406 started treatment at 299.125; queue time was 5.286
# Patient № 412 (TIA) arrives at: 299.416
# Patient № 407 started treatment at 299.816; queue time was 4.487
# Patient № 408 started treatment at 299.957; queue time was 1.809
# Patient № 413 (Stroke) arrives at: 300.003
# Patient № 409 started treatment at 301.188; queue time was 2.720
# Patient № 414 (Neuro) arrives at: 301.390
# Patient № 410 started treatment at 301.549; queue time was 2.714
# Patient № 411 started treatment at 301.812; queue time was 2.894
# Patient № 412 started treatment at 302.055; queue time was 2.639
# Patient № 415 (Stroke) arrives at: 302.082
# Patient № 416 (Stroke) arrives at: 302.165
# Patient № 417 (Neuro) arrives at: 302.984
# Patient № 413 started treatment at 303.260; queue time was 3.256
# Patient № 418 (Neuro) arrives at: 303.373
# Patient № 419 (Neuro) arrives at: 303.563
# Patient № 414 started treatment at 303.565; queue time was 2.175
# Patient № 420 (Stroke) arrives at: 303.814
# Patient № 415 started treatment at 304.934; queue time was 2.853
# Patient № 416 started treatment at 305.763; queue time was 3.598
# Patient № 417 started treatment at 307.620; queue time was 4.636
# Patient № 418 started treatment at 307.633; queue time was 4.260
# Patient № 419 started treatment at 307.757; queue time was 4.194
# Patient № 420 started treatment at 308.142; queue time was 4.328
# Patient № 421 (Neuro) arrives at: 309.633
# Patient № 421 started treatment at 309.633; queue time was 0.000
# Patient № 422 (Stroke) arrives at: 310.090
# Patient № 422 started treatment at 310.090; queue time was 0.000
# Patient № 423 (TIA) arrives at: 310.496
# Patient № 423 started treatment at 310.496; queue time was 0.000
# Patient № 424 (Stroke) arrives at: 310.821
# Patient № 424 started treatment at 310.824; queue time was 0.003
# Patient № 425 (Neuro) arrives at: 311.514
# Patient № 425 started treatment at 311.514; queue time was 0.000
# Patient № 426 (Stroke) arrives at: 311.762
# Patient № 426 started treatment at 311.762; queue time was 0.000
# Patient № 427 (Stroke) arrives at: 312.194
# Patient № 427 started treatment at 312.194; queue time was 0.000
# Patient № 428 (Neuro) arrives at: 312.716
# Patient № 428 started treatment at 312.716; queue time was 0.000
# Patient № 429 (Stroke) arrives at: 312.844
# Patient № 430 (Stroke) arrives at: 314.522
# Patient № 429 started treatment at 314.910; queue time was 2.066
# Patient № 430 started treatment at 315.151; queue time was 0.629
# Patient № 431 (Stroke) arrives at: 315.468
# Patient № 431 started treatment at 315.603; queue time was 0.136
# Patient № 432 (Stroke) arrives at: 315.788
# Patient № 433 (Stroke) arrives at: 316.436
# Patient № 432 started treatment at 316.681; queue time was 0.893
# Patient № 433 started treatment at 316.874; queue time was 0.438
# Patient № 434 (Stroke) arrives at: 318.951
# Patient № 434 started treatment at 318.951; queue time was 0.000
# Patient № 435 (Stroke) arrives at: 320.297
# Patient № 435 started treatment at 320.297; queue time was 0.000
# Patient № 436 (Stroke) arrives at: 320.458
# Patient № 436 started treatment at 320.458; queue time was 0.000
# Patient № 437 (Stroke) arrives at: 321.479
# Patient № 437 started treatment at 321.479; queue time was 0.000
# Patient № 438 (Stroke) arrives at: 321.970
# Patient № 438 started treatment at 321.970; queue time was 0.000
# Patient № 439 (Stroke) arrives at: 323.106
# Patient № 439 started treatment at 323.106; queue time was 0.000
# Patient № 440 (Stroke) arrives at: 323.871
# Patient № 440 started treatment at 323.871; queue time was 0.000
# Patient № 441 (Stroke) arrives at: 324.384
# Patient № 441 started treatment at 324.384; queue time was 0.000
# Patient № 442 (Stroke) arrives at: 324.484
# Patient № 442 started treatment at 324.484; queue time was 0.000
# Patient № 443 (Stroke) arrives at: 324.842
# Patient № 443 started treatment at 324.842; queue time was 0.000
# Patient № 444 (Stroke) arrives at: 325.218
# Patient № 444 started treatment at 325.218; queue time was 0.000
# Patient № 445 (Stroke) arrives at: 326.412
# Patient № 445 started treatment at 326.412; queue time was 0.000
# Patient № 446 (Stroke) arrives at: 326.610
# Patient № 446 started treatment at 326.610; queue time was 0.000
# Patient № 447 (Stroke) arrives at: 327.005
# Patient № 447 started treatment at 327.005; queue time was 0.000
# Patient № 448 (Stroke) arrives at: 329.186
# Patient № 448 started treatment at 329.186; queue time was 0.000
# Patient № 449 (Neuro) arrives at: 331.942
# Patient № 449 started treatment at 331.942; queue time was 0.000
# Patient № 450 (Stroke) arrives at: 332.028
# Patient № 450 started treatment at 332.028; queue time was 0.000
# Patient № 451 (Stroke) arrives at: 332.146
# Patient № 451 started treatment at 332.146; queue time was 0.000
# Patient № 452 (Stroke) arrives at: 332.505
# Patient № 452 started treatment at 332.505; queue time was 0.000
# Patient № 453 (Neuro) arrives at: 332.579
# Patient № 453 started treatment at 332.579; queue time was 0.000
# Patient № 454 (Stroke) arrives at: 333.978
# Patient № 454 started treatment at 333.978; queue time was 0.000
# Patient № 455 (TIA) arrives at: 334.704
# Patient № 455 started treatment at 334.704; queue time was 0.000
# Patient № 456 (Stroke) arrives at: 335.132
# Patient № 456 started treatment at 335.132; queue time was 0.000
# Patient № 457 (Stroke) arrives at: 337.005
# Patient № 457 started treatment at 337.005; queue time was 0.000
# Patient № 458 (Neuro) arrives at: 337.169
# Patient № 458 started treatment at 337.169; queue time was 0.000
# Patient № 459 (Stroke) arrives at: 337.237
# Patient № 459 started treatment at 337.237; queue time was 0.000
# Patient № 460 (Stroke) arrives at: 337.951
# Patient № 460 started treatment at 337.951; queue time was 0.000
# Patient № 461 (Neuro) arrives at: 338.110
# Patient № 461 started treatment at 338.110; queue time was 0.000
# Patient № 462 (Stroke) arrives at: 339.007
# Patient № 462 started treatment at 339.007; queue time was 0.000
# Patient № 463 (Stroke) arrives at: 340.174
# Patient № 463 started treatment at 340.174; queue time was 0.000
# Patient № 464 (Neuro) arrives at: 340.616
# Patient № 464 started treatment at 340.616; queue time was 0.000
# Patient № 465 (Stroke) arrives at: 342.224
# Patient № 465 started treatment at 342.224; queue time was 0.000
# Patient № 466 (Stroke) arrives at: 342.226
# Patient № 466 started treatment at 342.226; queue time was 0.000
# Patient № 467 (Stroke) arrives at: 342.302
# Patient № 467 started treatment at 342.302; queue time was 0.000
# Patient № 468 (Neuro) arrives at: 342.959
# Patient № 468 started treatment at 342.959; queue time was 0.000
# Patient № 469 (Neuro) arrives at: 343.100
# Patient № 469 started treatment at 343.100; queue time was 0.000
# Patient № 470 (Stroke) arrives at: 343.302
# Patient № 470 started treatment at 343.302; queue time was 0.000
# Patient № 471 (Stroke) arrives at: 343.545
# Patient № 471 started treatment at 343.545; queue time was 0.000
# Patient № 472 (Stroke) arrives at: 344.518
# Patient № 472 started treatment at 344.518; queue time was 0.000
# Patient № 473 (Stroke) arrives at: 345.163
# Patient № 473 started treatment at 345.163; queue time was 0.000
# Patient № 474 (Neuro) arrives at: 349.848
# Patient № 474 started treatment at 349.848; queue time was 0.000
# Patient № 475 (TIA) arrives at: 350.216
# Patient № 475 started treatment at 350.216; queue time was 0.000
# Patient № 476 (Stroke) arrives at: 350.272
# Patient № 476 started treatment at 350.272; queue time was 0.000
# Patient № 477 (Stroke) arrives at: 350.993
# Patient № 477 started treatment at 350.993; queue time was 0.000
# Patient № 478 (Stroke) arrives at: 351.825
# Patient № 478 started treatment at 351.825; queue time was 0.000
# Patient № 479 (Stroke) arrives at: 352.730
# Patient № 479 started treatment at 352.730; queue time was 0.000
# Patient № 480 (Stroke) arrives at: 353.337
# Patient № 480 started treatment at 353.337; queue time was 0.000
# Patient № 481 (Neuro) arrives at: 354.285
# Patient № 481 started treatment at 354.285; queue time was 0.000
# Patient № 482 (Stroke) arrives at: 354.598
# Patient № 482 started treatment at 354.598; queue time was 0.000
# Patient № 483 (Stroke) arrives at: 354.923
# Patient № 483 started treatment at 354.923; queue time was 0.000
# Patient № 484 (Stroke) arrives at: 355.932
# Patient № 484 started treatment at 355.932; queue time was 0.000
# Patient № 485 (Stroke) arrives at: 356.089
# Patient № 485 started treatment at 356.089; queue time was 0.000
# Patient № 486 (Stroke) arrives at: 358.787
# Patient № 486 started treatment at 358.787; queue time was 0.000
# Patient № 487 (Stroke) arrives at: 358.873
# Patient № 487 started treatment at 358.873; queue time was 0.000
# Patient № 488 (TIA) arrives at: 359.301
# Patient № 488 started treatment at 359.301; queue time was 0.000
# Patient № 489 (Stroke) arrives at: 360.719
# Patient № 489 started treatment at 360.719; queue time was 0.000
# Patient № 490 (Stroke) arrives at: 361.862
# Patient № 490 started treatment at 361.862; queue time was 0.000
# Patient № 491 (Neuro) arrives at: 362.194
# Patient № 491 started treatment at 362.194; queue time was 0.000
# Patient № 492 (Stroke) arrives at: 362.384
# Patient № 492 started treatment at 362.384; queue time was 0.000
# Patient № 493 (Stroke) arrives at: 362.829
# Patient № 493 started treatment at 362.829; queue time was 0.000
# Patient № 494 (Stroke) arrives at: 362.862
# Patient № 494 started treatment at 362.862; queue time was 0.000
# Patient № 495 (Stroke) arrives at: 363.363
# Patient № 496 (Stroke) arrives at: 363.476
# Patient № 495 started treatment at 363.549; queue time was 0.186
# Patient № 496 started treatment at 363.597; queue time was 0.121
# Patient № 497 (Stroke) arrives at: 364.933
# Patient № 497 started treatment at 364.933; queue time was 0.000
# end of run. simulation clock time = 365
#
# Single run results
# ------------------
# Mean Queue Time of Bottom 90% of the Patients: 11.41 hours!
